# %%
from ensembles import VanillaEnsemble
from datasets import make_dataset, make_cross_validation_dataset
from plot import plot_dataset, plot_prediction
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12, 4]
from evaluation import evaluate_model
import tensorflow as tf

# %% [markdown]
# # Preparations

# %%
num_epochs = 20
params = {'num_neurons':[10,10,10],
          'num_epochs':num_epochs,
          'learning_rate':0.001,
          'seed':1011}#43 is cool 101
          #'optimizer':tf.train.AdamOptimizer}

# %%
data = make_dataset(train_p=0.8)

X = data['X']
y = data['y']
X_test = data['X_test']
y_test = data['y_test']
generate_sinoid = data['generating']
#sorted_index = data['train_index']
sorted_index = data['shuffle_index']
#test_index = data['test_ind']

# %%
#X_test[:10],X[:10]

# %%
#len(X), len(sorted_index),len(data['test_ind']),len(X_test)

# %%
plot_dataset(X,y,sorted_index,generating_func=generate_sinoid)

# %% [markdown]
# # initialise Networks

# %%
from estimators import GaussianLossEstimator,GaussianLearningRateEstimator, EnsembleNetwork

gauss = GaussianLossEstimator(**params)
gauss_lr = GaussianLearningRateEstimator(**params)
vanilla = EnsembleNetwork(**params)

# %%
gauss_preds = gauss.predict(X)
gauss_var = gauss.predict_var(X)


lr_preds = gauss_lr.predict(X)
lr_var = gauss_lr.predict_var(X)

vanilla_preds = vanilla.predict(X)

# %%
plot_prediction(X,
                gauss_preds,
                sorted_index,
                gauss_var,
                generating_func=generate_sinoid)
plot_prediction(X,
                lr_preds,
                sorted_index,
                lr_var)
plot_prediction(X,vanilla_preds,sorted_index)
plt.plot(X,y,'x')

# %%
evaluate_model(X,y,gauss_preds)
# Out:
# RSME is 22.14910422835996

# %%
evaluate_model(X,y,lr_preds)
# Out:
# RSME is 22.29461124898754

# %%
evaluate_model(X,y,vanilla_preds)
# Out:
# RSME is 22.14910422835996

# %% [markdown]
# # Training

# %%
for i in range(100):
    gauss.train(X,y)
    #gauss_lr.train(X,y)
    #vanilla.train(X,y)
    if i%20 ==0:
        gauss_preds = gauss.predict(X)
        gauss_var = gauss.predict_var(X)

        #lr_preds = gauss_lr.predict(X)
        #lr_var = gauss_lr.predict_var(X)

        #vanilla_preds = vanilla.predict(X)
        plot_prediction(X,gauss_preds,sorted_index,gauss_var,generating_func=generate_sinoid)
        plt.plot(X,y,'x')
        plt.show()
        evaluate_model(X,y,gauss_preds,var=gauss_var)
# Out:
# RSME is 12.132057680132144
# COVERAGE PROBABILITY is 0.83
# COVERAGE/MEAN_VAR is 0.05062222690128958
# RSME is 4.65296958842703
# COVERAGE PROBABILITY is 0.95
# COVERAGE/MEAN_VAR is 0.08423524306267571
# RSME is 3.6734544832711378
# COVERAGE PROBABILITY is 0.83
# COVERAGE/MEAN_VAR is 0.10459025219391012
# RSME is 3.5548671146788124
# COVERAGE PROBABILITY is 0.83
# COVERAGE/MEAN_VAR is 0.11147509042032844
# RSME is 3.518519841123231
# COVERAGE PROBABILITY is 0.84
# COVERAGE/MEAN_VAR is 0.11577813861164372

# %% [markdown]
# # IDEE
# If var <0.1 don't teach at all

# %%
for i in range(100):
    gauss_lr.train(X,y)
    #gauss_lr.train(X,y)
    #vanilla.train(X,y)
    if i%20 ==0:
        gauss_preds = gauss_lr.predict(X)
        gauss_var = gauss_lr.predict_var(X)

        #3lr_preds = gauss_lr.predict(X)
        #lr_var = gauss_lr.predict_var(X)

        #vanilla_preds = vanilla.predict(X)
        plot_prediction(X,gauss_preds,sorted_index,gauss_var,generating_func=generate_sinoid)
        plt.plot(X,y,'x')
        plt.show()
        evaluate_model(X,y,gauss_preds,var=gauss_var)
# Out:
# RSME is 6.727726947735256
# COVERAGE PROBABILITY is 0.99
# COVERAGE/MEAN_VAR is 0.07697684377439382
# RSME is 3.850118287755453
# COVERAGE PROBABILITY is 0.85
# COVERAGE/MEAN_VAR is 0.1151491129293563
# RSME is 3.7694855952592072
# COVERAGE PROBABILITY is 0.84
# COVERAGE/MEAN_VAR is 0.125588044777475
# RSME is 3.711529383764483
# COVERAGE PROBABILITY is 0.82
# COVERAGE/MEAN_VAR is 0.12929285347007366

# %% [markdown]
# # Idee
# if error > EPSIOLN std +1?

# %%
for i in range(100):
    vanilla.train(X,y)
    #gauss_lr.train(X,y)
    #vanilla.train(X,y)
    if i%20 ==0:
        gauss_preds = vanilla.predict(X)
        #gauss_var = vanilla.predict_var(X)

        #3lr_preds = gauss_lr.predict(X)
        #lr_var = gauss_lr.predict_var(X)

        #vanilla_preds = vanilla.predict(X)
        plot_prediction(X,gauss_preds,sorted_index,generating_func=generate_sinoid)
        plt.plot(X,y,'x')
        plt.show()
        evaluate_model(X,y,gauss_preds)

# %%
gauss.train(X,y)
gauss_lr.train(X,y)
vanilla.train(X,y)

# %%
gauss_preds = gauss.predict(X)
gauss_var = gauss.predict_var(X)

lr_preds = gauss_lr.predict(X)
lr_var = gauss_lr.predict_var(X)

vanilla_preds = vanilla.predict(X)

# %%
plot_prediction(X,gauss_preds,sorted_index,gauss_var,generating_func=generate_sinoid)
plt.plot(X,y,'x')

# %%
plot_prediction(X,lr_preds,sorted_index,lr_var,generating_func=generate_sinoid)
plt.plot(X,y,'x')

# %%
plot_prediction(X,vanilla_preds,sorted_index,generating_func=generate_sinoid)
plt.plot(X,y,'x')

# %%
evaluate_model(X,y,gauss_preds,var=gauss_var)

# %%
evaluate_model(X,y,lr_preds,var=lr_var)

# %%
evaluate_model(X,y,vanilla_preds)

# %% [markdown]
# # IDEE
# Coverage Probability * 1/mean(var) as loss function

# %%
from estimators import GaussianCovProbInvMeanVarEstimator

# %%
new_thing = GaussianCovProbInvMeanVarEstimator()

# %% [markdown]
# #
