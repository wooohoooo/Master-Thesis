# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork

# %%
num_meta_epochs = 3# 100#100#10
num_epochs = 10#15#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 200
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons,
               'l2':True}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:09:45.008596
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 14.82585096359253 seconds. That means the whole run will probably take 44.47755289077759 more seconds and 0.7412925481796264 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 44.706247091293335 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.361970  0.788889  0.906375  0.014552
# std    0.521842  0.069389  0.018693  0.005096
# min    0.002474  0.733333  0.895067  0.008741
# 25%    0.062698  0.750000  0.895587  0.012698
# 50%    0.122921  0.766667  0.896106  0.016654
# 75%    0.541718  0.816667  0.912029  0.017457
# max    0.960515  0.866667  0.927952  0.018260
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.361970 &  0.788889 &  0.906375 &  0.014552 \\
# std   &  0.521842 &  0.069389 &  0.018693 &  0.005096 \\
# min   &  0.002474 &  0.733333 &  0.895067 &  0.008741 \\
# 25\%   &  0.062698 &  0.750000 &  0.895587 &  0.012698 \\
# 50\%   &  0.122921 &  0.766667 &  0.896106 &  0.016654 \\
# 75\%   &  0.541718 &  0.816667 &  0.912029 &  0.017457 \\
# max   &  0.960515 &  0.866667 &  0.927952 &  0.018260 \\
# \bottomrule
# \end{tabular}

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed,
               'l2':True}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:10:40.994341
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 15.997975826263428 seconds. That means the whole run will probably take 47.99392747879028 more seconds and 0.7998987913131714 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 57.36979293823242 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.255652  0.161111 -0.111536  0.327199
# std    0.156805  0.069389  0.476692  0.156724
# min    0.121260  0.083333 -0.651091  0.211969
# 25%    0.169513  0.133333 -0.293582  0.237968
# 50%    0.217767  0.183333  0.063927  0.263967
# 75%    0.322848  0.200000  0.158242  0.384814
# max    0.427929  0.216667  0.252558  0.505660
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.255652 &  0.161111 & -0.111536 &  0.327199 \\
# std   &  0.156805 &  0.069389 &  0.476692 &  0.156724 \\
# min   &  0.121260 &  0.083333 & -0.651091 &  0.211969 \\
# 25\%   &  0.169513 &  0.133333 & -0.293582 &  0.237968 \\
# 50\%   &  0.217767 &  0.183333 &  0.063927 &  0.263967 \\
# 75\%   &  0.322848 &  0.200000 &  0.158242 &  0.384814 \\
# max   &  0.427929 &  0.216667 &  0.252558 &  0.505660 \\
# \bottomrule
# \end{tabular}

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}


pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:11:52.868132
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 18.59483504295349 seconds. That means the whole run will probably take 55.784505128860474 more seconds and 0.9297417521476745 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 54.66292214393616 seconds with 3 experiments
#              cobeau  coverage       nlpd        rsme
# count  3.000000e+00  3.000000   3.000000    3.000000
# mean   4.700845e-08  0.838889 -51.975176  433.429090
# std    5.703902e-08  0.025459  39.786273   36.400443
# min    1.849387e-12  0.816667 -96.902724  399.120887
# 25%    1.528035e-08  0.825000 -67.362905  414.337732
# 50%    3.055885e-08  0.833333 -37.823087  429.554577
# 75%    7.051175e-08  0.850000 -29.511402  450.583192
# max    1.104647e-07  0.866667 -21.199716  471.611807
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &       nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &   3.000000 &    3.000000 \\
# mean  &  4.700845e-08 &  0.838889 & -51.975176 &  433.429090 \\
# std   &  5.703902e-08 &  0.025459 &  39.786273 &   36.400443 \\
# min   &  1.849387e-12 &  0.816667 & -96.902724 &  399.120887 \\
# 25\%   &  1.528035e-08 &  0.825000 & -67.362905 &  414.337732 \\
# 50\%   &  3.055885e-08 &  0.833333 & -37.823087 &  429.554577 \\
# 75\%   &  7.051175e-08 &  0.850000 & -29.511402 &  450.583192 \\
# max   &  1.104647e-07 &  0.866667 & -21.199716 &  471.611807 \\
# \bottomrule
# \end{tabular}
