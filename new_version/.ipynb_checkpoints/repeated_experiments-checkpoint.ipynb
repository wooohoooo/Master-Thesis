# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline
import tensorflow as tf

from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3, ForcedDiversityBootstrapThroughTime
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 10#10
num_epochs = 10#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'initialisation_scheme':tf.keras.initializers.he_normal}

dataset_params = {'seed':seed,'num_samples':50}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 17:57:54.508044
# experiment number 1 took 8.188201904296875 seconds. That means the whole run will probably take 81.88201904296875 more seconds and 1.3647003173828125 more minutes.
# overall, it took 73.31258797645569 seconds with 10 experiments
#              cobeau   coverage       nlpd       rsme
# count  1.000000e+01  10.000000  10.000000  10.000000
# mean   1.249945e-03   0.886667   0.594385   0.062898
# std    1.911185e-03   0.177917   0.280115   0.038344
# min    4.774382e-07   0.533333   0.261063   0.012778
# 25%    1.737413e-06   0.866667   0.365283   0.027146
# 50%    1.060608e-04   1.000000   0.496001   0.075167
# 75%    2.436123e-03   1.000000   0.833463   0.094606
# max    4.672540e-03   1.000000   1.027366   0.110087
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  1.000000e+01 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &  1.249945e-03 &   0.886667 &   0.594385 &   0.062898 \\
# std   &  1.911185e-03 &   0.177917 &   0.280115 &   0.038344 \\
# min   &  4.774382e-07 &   0.533333 &   0.261063 &   0.012778 \\
# 25\%   &  1.737413e-06 &   0.866667 &   0.365283 &   0.027146 \\
# 50\%   &  1.060608e-04 &   1.000000 &   0.496001 &   0.075167 \\
# 75\%   &  2.436123e-03 &   1.000000 &   0.833463 &   0.094606 \\
# max   &  4.672540e-03 &   1.000000 &   1.027366 &   0.110087 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 17:59:11.365086
# experiment number 1 took 14.574850797653198 seconds. That means the whole run will probably take 145.74850797653198 more seconds and 2.4291417996088662 more minutes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-474f8e6affd1> in <module>()
# ----> 1 pd1 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
#
# ~/Documents/Master-Thesis/new_version/evaluation.py in repeat_experiment(model_creator, dataset_creator, num_meta_epochs, plot, model_params, dataset_params, seed)
#      94         #dataset = dataset_creator(**datset_params)  #create a dataset
#      95
# ---> 96         model.fit(X_train, y_train)  #,shuffle=True)
#      97         y_pred, y_var = model.get_mean_and_std(X_test)
#      98         pred_list.append({
#
# ~/Documents/Master-Thesis/new_version/ensembles.py in fit(self, X, y, X_test, y_test)
#     168             self.model.load(self.checkpoints[-1])  #load most recent model
#     169             rsme_before = self.model.compute_rsme(X, y)
# --> 170             self.model.fit(X, y)  #train most recent model
#     171             rsme_after = self.model.compute_rsme(X, y)
#     172             if rsme_before > rsme_after:
#
# ~/Documents/Master-Thesis/new_version/base.py in fit(self, X, y, shuffle, online)
#     218                 X = self.check_input_dimensions(X)
#     219                 y = self.check_input_dimensions(y)
# --> 220                 self.train_one_epoch(X, y, shuffle)
#     221         else:
#     222             X, y, _ = self.shuffle_data(X, y)
#
# ~/Documents/Master-Thesis/new_version/base.py in train_one_epoch(self, epoch_X, epoch_y, shuffle)
#     234         epoch_y = self.check_input_dimensions(epoch_y)
#     235         for batch_X, batch_y in zip(epoch_X, epoch_y):
# --> 236             self.train_one(batch_X, batch_y)
#     237             if self.adversarial:
#     238                 self.train_one(batch_X + 0.05, batch_y)
#
# ~/Documents/Master-Thesis/new_version/base.py in train_one(self, batch_X, batch_y)
#     246         self.session.run(self.train_graph,
#     247                          feed_dict={self.X: batch_X,
# --> 248                                     self.y: batch_y})
#     249
#     250     def train_and_evaluate(self, X, y, shuffle=False):
#
# ~/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)

# %% [markdown]
# # Nonlinear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 3]}

dataset_params = {'num_samples':50,'seed':seed}
importlib.reload(dataset_creation)

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)

# %%
pd22 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)

# %% [markdown]
# # X3

# %%
dataset_params = {'seed':seed,'num_samples':50,'scope':25}

# %%
pd111 = repeat_experiment(BootstrapEnsemble, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)

# %%
pd222 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)

# %%
pd333 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
