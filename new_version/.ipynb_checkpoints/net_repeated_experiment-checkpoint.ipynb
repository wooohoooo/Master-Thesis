# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#100#10
num_epochs = 10#3#50#50#15#5#25#50
seed = 42#45#42

num_samples = 150
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]

learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,num_neurons=num_neurons}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:21:52.515194
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 3.53348708152771 seconds. That means the whole run will probably take 10.60046124458313 more seconds and 0.1766743540763855 more minutes.
# overall, it took 10.383223056793213 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   4.504099e-03  0.785185       inf  0.005584
# std    7.763508e-03  0.067890       NaN  0.001463
# min    2.002268e-09  0.711111       inf  0.004658
# 25%    2.185341e-05  0.755556       inf  0.004741
# 50%    4.370482e-05  0.800000       NaN  0.004823
# 75%    6.756148e-03  0.822222       inf  0.006047
# max    1.346859e-02  0.844444       inf  0.007270
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  4.504099e-03 &  0.785185 &       inf &  0.005584 \\
# std   &  7.763508e-03 &  0.067890 &       NaN &  0.001463 \\
# min   &  2.002268e-09 &  0.711111 &       inf &  0.004658 \\
# 25\%   &  2.185341e-05 &  0.755556 &       inf &  0.004741 \\
# 50\%   &  4.370482e-05 &  0.800000 &       NaN &  0.004823 \\
# 75\%   &  6.756148e-03 &  0.822222 &       inf &  0.006047 \\
# max   &  1.346859e-02 &  0.844444 &       inf &  0.007270 \\
# \bottomrule
# \end{tabular}
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:22:06.553145
# experiment number 1 took 4.102197170257568 seconds. That means the whole run will probably take 12.306591510772705 more seconds and 0.2051098585128784 more minutes.
# overall, it took 13.653514862060547 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   2.726244e-01  0.118519  1.914362  0.007768
# std    4.720612e-01  0.186367  0.801981  0.007627
# min    4.159349e-10  0.000000  1.259882  0.001098
# 25%    7.969278e-05  0.011111  1.467054  0.003611
# 50%    1.593851e-04  0.022222  1.674226  0.006125
# 75%    4.089365e-01  0.177778  2.241602  0.011104
# max    8.177137e-01  0.333333  2.808977  0.016083
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  2.726244e-01 &  0.118519 &  1.914362 &  0.007768 \\
# std   &  4.720612e-01 &  0.186367 &  0.801981 &  0.007627 \\
# min   &  4.159349e-10 &  0.000000 &  1.259882 &  0.001098 \\
# 25\%   &  7.969278e-05 &  0.011111 &  1.467054 &  0.003611 \\
# 50\%   &  1.593851e-04 &  0.022222 &  1.674226 &  0.006125 \\
# 75\%   &  4.089365e-01 &  0.177778 &  2.241602 &  0.011104 \\
# max   &  8.177137e-01 &  0.333333 &  2.808977 &  0.016083 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:22:24.149515
# experiment number 1 took 3.5165889263153076 seconds. That means the whole run will probably take 10.549766778945923 more seconds and 0.1758294463157654 more minutes.
# overall, it took 11.546941995620728 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.685701  0.044444  2.744897  0.000895
# std    0.249510  0.022222  0.048864  0.000014
# min    0.399430  0.022222  2.690006  0.000881
# 25%    0.600066  0.033333  2.725518  0.000889
# 50%    0.800703  0.044444  2.761031  0.000897
# 75%    0.828837  0.055556  2.772342  0.000903
# max    0.856971  0.066667  2.783654  0.000909
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.685701 &  0.044444 &  2.744897 &  0.000895 \\
# std   &  0.249510 &  0.022222 &  0.048864 &  0.000014 \\
# min   &  0.399430 &  0.022222 &  2.690006 &  0.000881 \\
# 25\%   &  0.600066 &  0.033333 &  2.725518 &  0.000889 \\
# 50\%   &  0.800703 &  0.044444 &  2.761031 &  0.000897 \\
# 75\%   &  0.828837 &  0.055556 &  2.772342 &  0.000903 \\
# max   &  0.856971 &  0.066667 &  2.783654 &  0.000909 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:22:39.341938
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 3.05698299407959 seconds. That means the whole run will probably take 9.17094898223877 more seconds and 0.1528491497039795 more minutes.
# overall, it took 10.175266027450562 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.880672  0.237037       inf  0.092820
# std    0.115279  0.046259       NaN  0.016721
# min    0.762242  0.200000       inf  0.080335
# 25%    0.824749  0.211111       inf  0.083321
# 50%    0.887255  0.222222       NaN  0.086308
# 75%    0.939886  0.255556       inf  0.099063
# max    0.992517  0.288889       inf  0.111818
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.880672 &  0.237037 &       inf &  0.092820 \\
# std   &  0.115279 &  0.046259 &       NaN &  0.016721 \\
# min   &  0.762242 &  0.200000 &       inf &  0.080335 \\
# 25\%   &  0.824749 &  0.211111 &       inf &  0.083321 \\
# 50\%   &  0.887255 &  0.222222 &       NaN &  0.086308 \\
# 75\%   &  0.939886 &  0.255556 &       inf &  0.099063 \\
# max   &  0.992517 &  0.288889 &       inf &  0.111818 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:22:53.680312
# experiment number 1 took 4.241555213928223 seconds. That means the whole run will probably take 12.724665641784668 more seconds and 0.21207776069641113 more minutes.
# overall, it took 12.668948888778687 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   1.618170e-01  0.214815  0.872099  0.113135
# std    2.788241e-01  0.064150  0.689471  0.131272
# min    5.088771e-10  0.177778  0.238419  0.006378
# 25%    8.385760e-04  0.177778  0.504988  0.039850
# 50%    1.677151e-03  0.177778  0.771557  0.073322
# 75%    2.427255e-01  0.233333  1.188939  0.166513
# max    4.837739e-01  0.288889  1.606322  0.259704
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  1.618170e-01 &  0.214815 &  0.872099 &  0.113135 \\
# std   &  2.788241e-01 &  0.064150 &  0.689471 &  0.131272 \\
# min   &  5.088771e-10 &  0.177778 &  0.238419 &  0.006378 \\
# 25\%   &  8.385760e-04 &  0.177778 &  0.504988 &  0.039850 \\
# 50\%   &  1.677151e-03 &  0.177778 &  0.771557 &  0.073322 \\
# 75\%   &  2.427255e-01 &  0.233333 &  1.188939 &  0.166513 \\
# max   &  4.837739e-01 &  0.288889 &  1.606322 &  0.259704 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:23:10.874372
# experiment number 1 took 3.7590219974517822 seconds. That means the whole run will probably take 11.277065992355347 more seconds and 0.18795109987258912 more minutes.
# overall, it took 12.583083868026733 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.018839  0.207407  0.830384  0.070891
# std    0.022129  0.033945  0.105018  0.017453
# min    0.003643  0.177778  0.710146  0.058006
# 25%    0.006144  0.188889  0.793505  0.060960
# 50%    0.008646  0.200000  0.876864  0.063914
# 75%    0.026437  0.222222  0.890503  0.077334
# max    0.044227  0.244444  0.904141  0.090754
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.018839 &  0.207407 &  0.830384 &  0.070891 \\
# std   &  0.022129 &  0.033945 &  0.105018 &  0.017453 \\
# min   &  0.003643 &  0.177778 &  0.710146 &  0.058006 \\
# 25\%   &  0.006144 &  0.188889 &  0.793505 &  0.060960 \\
# 50\%   &  0.008646 &  0.200000 &  0.876864 &  0.063914 \\
# 75\%   &  0.026437 &  0.222222 &  0.890503 &  0.077334 \\
# max   &  0.044227 &  0.244444 &  0.904141 &  0.090754 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:23:27.663844
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 2.6924469470977783 seconds. That means the whole run will probably take 8.077340841293335 more seconds and 0.13462234735488893 more minutes.
# overall, it took 8.897972822189331 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.062652  0.562963       inf  0.012888
# std    0.108232  0.194153       NaN  0.003503
# min    0.000010  0.400000       inf  0.010141
# 25%    0.000164  0.455556       inf  0.010916
# 50%    0.000319  0.511111       NaN  0.011691
# 75%    0.093974  0.644444       inf  0.014262
# max    0.187628  0.777778       inf  0.016833
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.062652 &  0.562963 &       inf &  0.012888 \\
# std   &  0.108232 &  0.194153 &       NaN &  0.003503 \\
# min   &  0.000010 &  0.400000 &       inf &  0.010141 \\
# 25\%   &  0.000164 &  0.455556 &       inf &  0.010916 \\
# 50\%   &  0.000319 &  0.511111 &       NaN &  0.011691 \\
# 75\%   &  0.093974 &  0.644444 &       inf &  0.014262 \\
# max   &  0.187628 &  0.777778 &       inf &  0.016833 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:23:41.203729
# experiment number 1 took 4.282526969909668 seconds. That means the whole run will probably take 12.847580909729004 more seconds and 0.2141263484954834 more minutes.
# overall, it took 13.269389867782593 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.295571  0.088889  1.598921  0.014581
# std    0.459991  0.044444  0.329695  0.007225
# min    0.000060  0.044444  1.249115  0.008322
# 25%    0.030580  0.066667  1.446421  0.010627
# 50%    0.061100  0.088889  1.643728  0.012933
# 75%    0.443326  0.111111  1.773824  0.017710
# max    0.825552  0.133333  1.903921  0.022488
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.295571 &  0.088889 &  1.598921 &  0.014581 \\
# std   &  0.459991 &  0.044444 &  0.329695 &  0.007225 \\
# min   &  0.000060 &  0.044444 &  1.249115 &  0.008322 \\
# 25\%   &  0.030580 &  0.066667 &  1.446421 &  0.010627 \\
# 50\%   &  0.061100 &  0.088889 &  1.643728 &  0.012933 \\
# 75\%   &  0.443326 &  0.111111 &  1.773824 &  0.017710 \\
# max   &  0.825552 &  0.133333 &  1.903921 &  0.022488 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 15:23:59.432016
# experiment number 1 took 5.3886120319366455 seconds. That means the whole run will probably take 16.165836095809937 more seconds and 0.2694306015968323 more minutes.
# overall, it took 17.400367975234985 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.512538  0.044444  2.012136  0.006434
# std    0.469041  0.022222  0.249872  0.002577
# min    0.002254  0.022222  1.861771  0.003507
# 25%    0.306375  0.033333  1.867915  0.005469
# 50%    0.610496  0.044444  1.874060  0.007432
# 75%    0.767680  0.055556  2.087318  0.007897
# max    0.924863  0.066667  2.300576  0.008362
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.512538 &  0.044444 &  2.012136 &  0.006434 \\
# std   &  0.469041 &  0.022222 &  0.249872 &  0.002577 \\
# min   &  0.002254 &  0.022222 &  1.861771 &  0.003507 \\
# 25\%   &  0.306375 &  0.033333 &  1.867915 &  0.005469 \\
# 50\%   &  0.610496 &  0.044444 &  1.874060 &  0.007432 \\
# 75\%   &  0.767680 &  0.055556 &  2.087318 &  0.007897 \\
# max   &  0.924863 &  0.066667 &  2.300576 &  0.008362 \\
# \bottomrule
# \end{tabular}
