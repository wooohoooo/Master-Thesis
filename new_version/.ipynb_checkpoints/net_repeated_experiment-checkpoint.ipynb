# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 10#10
num_epochs = 50#15#5#25#50
seed = 42#45#42

num_samples = 150
dataset_params = {'seed':seed,'num_samples':num_samples}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:41:18.842264
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 4.366873025894165 seconds. That means the whole run will probably take 43.66873025894165 more seconds and 0.7278121709823608 more minutes.
# overall, it took 43.18824815750122 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.350761   0.364444        inf   0.020818
# std     0.274649   0.071970        NaN   0.023236
# min     0.000027   0.200000  -6.128510   0.005284
# 25%     0.172944   0.333333        inf   0.009010
# 50%     0.274644   0.377778        inf   0.011908
# 75%     0.474434   0.411111        inf   0.021583
# max     0.831901   0.444444        inf   0.083666
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.350761 &   0.364444 &        inf &   0.020818 \\
# std   &   0.274649 &   0.071970 &        NaN &   0.023236 \\
# min   &   0.000027 &   0.200000 &  -6.128510 &   0.005284 \\
# 25\%   &   0.172944 &   0.333333 &        inf &   0.009010 \\
# 50\%   &   0.274644 &   0.377778 &        inf &   0.011908 \\
# 75\%   &   0.474434 &   0.411111 &        inf &   0.021583 \\
# max   &   0.831901 &   0.444444 &        inf &   0.083666 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:42:06.200751
# experiment number 1 took 5.662255048751831 seconds. That means the whole run will probably take 56.62255048751831 more seconds and 0.9437091747919718 more minutes.
# overall, it took 55.116060972213745 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.183954   0.202222   1.266737   0.029312
# std     0.266094   0.323297   0.746618   0.037778
# min     0.003015   0.022222   0.089080   0.005647
# 25%     0.014502   0.044444   0.535457   0.006416
# 50%     0.071785   0.055556   1.619050   0.012074
# 75%     0.163847   0.116667   1.884310   0.026324
# max     0.716976   0.977778   1.991730   0.106465
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.183954 &   0.202222 &   1.266737 &   0.029312 \\
# std   &   0.266094 &   0.323297 &   0.746618 &   0.037778 \\
# min   &   0.003015 &   0.022222 &   0.089080 &   0.005647 \\
# 25\%   &   0.014502 &   0.044444 &   0.535457 &   0.006416 \\
# 50\%   &   0.071785 &   0.055556 &   1.619050 &   0.012074 \\
# 75\%   &   0.163847 &   0.116667 &   1.884310 &   0.026324 \\
# max   &   0.716976 &   0.977778 &   1.991730 &   0.106465 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:43:05.289371
# experiment number 1 took 4.764974117279053 seconds. That means the whole run will probably take 47.64974117279053 more seconds and 0.7941623528798422 more minutes.
# overall, it took 45.64857292175293 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.349436   0.160000   1.572109   0.009791
# std     0.380934   0.081009   0.775141   0.004594
# min     0.000104   0.044444  -0.589967   0.005601
# 25%     0.024507   0.116667   1.648828   0.006220
# 50%     0.250363   0.166667   1.816336   0.007969
# 75%     0.621061   0.194444   1.909625   0.011865
# max     0.993634   0.333333   2.031676   0.017679
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.349436 &   0.160000 &   1.572109 &   0.009791 \\
# std   &   0.380934 &   0.081009 &   0.775141 &   0.004594 \\
# min   &   0.000104 &   0.044444 &  -0.589967 &   0.005601 \\
# 25\%   &   0.024507 &   0.116667 &   1.648828 &   0.006220 \\
# 50\%   &   0.250363 &   0.166667 &   1.816336 &   0.007969 \\
# 75\%   &   0.621061 &   0.194444 &   1.909625 &   0.011865 \\
# max   &   0.993634 &   0.333333 &   2.031676 &   0.017679 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:43:54.911366
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 16.208677053451538 seconds. That means the whole run will probably take 81.04338526725769 more seconds and 1.3507230877876282 more minutes.
# overall, it took 82.45093703269958 seconds with 5 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage       nlpd      rsme
# count  5.000000  5.000000   5.000000  5.000000
# mean   0.543297  0.422222        inf  0.045878
# std    0.324663  0.156347        NaN  0.031277
# min    0.007414  0.200000 -30.461780  0.026760
# 25%    0.478288  0.355556        NaN  0.028531
# 50%    0.676448  0.466667        NaN  0.029134
# 75%    0.737744  0.466667        NaN  0.044637
# max    0.816589  0.622222        inf  0.100328
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  5.000000 &  5.000000 &   5.000000 &  5.000000 \\
# mean  &  0.543297 &  0.422222 &        inf &  0.045878 \\
# std   &  0.324663 &  0.156347 &        NaN &  0.031277 \\
# min   &  0.007414 &  0.200000 & -30.461780 &  0.026760 \\
# 25\%   &  0.478288 &  0.355556 &        NaN &  0.028531 \\
# 50\%   &  0.676448 &  0.466667 &        NaN &  0.029134 \\
# 75\%   &  0.737744 &  0.466667 &        NaN &  0.044637 \\
# max   &  0.816589 &  0.622222 &        inf &  0.100328 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:45:22.931928
# experiment number 1 took 28.949108123779297 seconds. That means the whole run will probably take 144.74554061889648 more seconds and 2.412425676981608 more minutes.
# overall, it took 131.4035198688507 seconds with 5 experiments
#              cobeau  coverage      nlpd      rsme
# count  5.000000e+00  5.000000  5.000000  5.000000
# mean   5.123235e-01  0.177778  0.753319  0.129327
# std    4.113107e-01  0.136987  0.774652  0.213209
# min    5.555405e-11  0.111111 -0.184747  0.021263
# 25%    2.142421e-01  0.111111  0.007026  0.025511
# 50%    5.405098e-01  0.111111  1.206119  0.044184
# 75%    8.068658e-01  0.133333  1.365232  0.045443
# max    1.000000e+00  0.422222  1.372963  0.510234
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  5.000000e+00 &  5.000000 &  5.000000 &  5.000000 \\
# mean  &  5.123235e-01 &  0.177778 &  0.753319 &  0.129327 \\
# std   &  4.113107e-01 &  0.136987 &  0.774652 &  0.213209 \\
# min   &  5.555405e-11 &  0.111111 & -0.184747 &  0.021263 \\
# 25\%   &  2.142421e-01 &  0.111111 &  0.007026 &  0.025511 \\
# 50\%   &  5.405098e-01 &  0.111111 &  1.206119 &  0.044184 \\
# 75\%   &  8.068658e-01 &  0.133333 &  1.365232 &  0.045443 \\
# max   &  1.000000e+00 &  0.422222 &  1.372963 &  0.510234 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:47:39.184954
# experiment number 1 took 20.60844397544861 seconds. That means the whole run will probably take 103.04221987724304 more seconds and 1.717370331287384 more minutes.
# overall, it took 100.56904888153076 seconds with 5 experiments
#              cobeau  coverage      nlpd      rsme
# count  5.000000e+00  5.000000  5.000000  5.000000
# mean   2.621988e-01  0.128889  0.756637  0.023927
# std    2.715582e-01  0.042745  0.826680  0.011924
# min    3.613478e-12  0.066667 -0.528189  0.014569
# 25%    4.285042e-02  0.111111  0.583667  0.016014
# 50%    2.834008e-01  0.133333  0.763799  0.017512
# 75%    3.030236e-01  0.155556  1.463451  0.028809
# max    6.817193e-01  0.177778  1.500454  0.042731
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  5.000000e+00 &  5.000000 &  5.000000 &  5.000000 \\
# mean  &  2.621988e-01 &  0.128889 &  0.756637 &  0.023927 \\
# std   &  2.715582e-01 &  0.042745 &  0.826680 &  0.011924 \\
# min   &  3.613478e-12 &  0.066667 & -0.528189 &  0.014569 \\
# 25\%   &  4.285042e-02 &  0.111111 &  0.583667 &  0.016014 \\
# 50\%   &  2.834008e-01 &  0.133333 &  0.763799 &  0.017512 \\
# 75\%   &  3.030236e-01 &  0.155556 &  1.463451 &  0.028809 \\
# max   &  6.817193e-01 &  0.177778 &  1.500454 &  0.042731 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:49:24.642336
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 16.740416049957275 seconds. That means the whole run will probably take 83.70208024978638 more seconds and 1.395034670829773 more minutes.
# overall, it took 81.01405620574951 seconds with 5 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd       rsme
# count  5.000000  5.000000  5.000000   5.000000
# mean   0.001502  0.315556       inf  46.313559
# std    0.003202  0.069211       NaN   9.521769
# min    0.000004  0.244444       inf  34.530004
# 25%    0.000004  0.266667       NaN  39.949793
# 50%    0.000065  0.288889       NaN  45.373983
# 75%    0.000207  0.377778       NaN  55.490201
# max    0.007228  0.400000       inf  56.223812
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  5.000000 &  5.000000 &  5.000000 &   5.000000 \\
# mean  &  0.001502 &  0.315556 &       inf &  46.313559 \\
# std   &  0.003202 &  0.069211 &       NaN &   9.521769 \\
# min   &  0.000004 &  0.244444 &       inf &  34.530004 \\
# 25\%   &  0.000004 &  0.266667 &       NaN &  39.949793 \\
# 50\%   &  0.000065 &  0.288889 &       NaN &  45.373983 \\
# 75\%   &  0.000207 &  0.377778 &       NaN &  55.490201 \\
# max   &  0.007228 &  0.400000 &       inf &  56.223812 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:50:50.627299
# experiment number 1 took 24.689461946487427 seconds. That means the whole run will probably take 123.44730973243713 more seconds and 2.0574551622072854 more minutes.
# overall, it took 121.64205312728882 seconds with 5 experiments
#              cobeau  coverage          nlpd        rsme
# count  5.000000e+00  5.000000      5.000000    5.000000
# mean   3.572584e-04  0.933333  -4455.492827  180.092187
# std    7.931349e-04  0.136987   9955.146710  148.142298
# min    9.336235e-13  0.688889 -22263.800523   49.156942
# 25%    1.241183e-07  0.977778     -5.274718   67.957534
# 50%    1.355894e-06  1.000000     -3.496092  113.325672
# 75%    8.765738e-06  1.000000     -2.493565  282.051567
# max    1.776046e-03  1.000000     -2.399236  387.969220
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &          nlpd &        rsme \\
# \midrule
# count &  5.000000e+00 &  5.000000 &      5.000000 &    5.000000 \\
# mean  &  3.572584e-04 &  0.933333 &  -4455.492827 &  180.092187 \\
# std   &  7.931349e-04 &  0.136987 &   9955.146710 &  148.142298 \\
# min   &  9.336235e-13 &  0.688889 & -22263.800523 &   49.156942 \\
# 25\%   &  1.241183e-07 &  0.977778 &     -5.274718 &   67.957534 \\
# 50\%   &  1.355894e-06 &  1.000000 &     -3.496092 &  113.325672 \\
# 75\%   &  8.765738e-06 &  1.000000 &     -2.493565 &  282.051567 \\
# max   &  1.776046e-03 &  1.000000 &     -2.399236 &  387.969220 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:52:57.078292
# experiment number 1 took 20.274386882781982 seconds. That means the whole run will probably take 101.37193441390991 more seconds and 1.6895322402318318 more minutes.
# overall, it took 100.02912402153015 seconds with 5 experiments
#          cobeau  coverage      nlpd       rsme
# count  5.000000  5.000000  5.000000   5.000000
# mean   0.098169  0.982222 -2.112910  26.232374
# std    0.200010  0.018592  0.430713  15.703497
# min    0.000033  0.955556 -2.757004   8.891072
# 25%    0.000147  0.977778 -2.296191  16.997115
# 50%    0.000148  0.977778 -2.002993  19.494315
# 75%    0.035619  1.000000 -1.864074  42.723681
# max    0.454899  1.000000 -1.644289  43.055686
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  5.000000 &  5.000000 &  5.000000 &   5.000000 \\
# mean  &  0.098169 &  0.982222 & -2.112910 &  26.232374 \\
# std   &  0.200010 &  0.018592 &  0.430713 &  15.703497 \\
# min   &  0.000033 &  0.955556 & -2.757004 &   8.891072 \\
# 25\%   &  0.000147 &  0.977778 & -2.296191 &  16.997115 \\
# 50\%   &  0.000148 &  0.977778 & -2.002993 &  19.494315 \\
# 75\%   &  0.035619 &  1.000000 & -1.864074 &  42.723681 \\
# max   &  0.454899 &  1.000000 & -1.644289 &  43.055686 \\
# \bottomrule
# \end{tabular}
