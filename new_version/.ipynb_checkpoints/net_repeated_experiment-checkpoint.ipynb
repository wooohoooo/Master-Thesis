# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed}

datset_params = {'num_samples':num_epochs,'seed':seed,'n_samples':50}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:36:33.147579
# experiment number 1 took 30.93867516517639 seconds. That means the whole run will probably take 92.81602549552917 more seconds and 1.5469337582588196 more minutes.
# overall, it took 63.43782091140747 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   5.386849e-13  0.316667  1.178818  0.029163
# std    8.813953e-13  0.132288  0.034898  0.009604
# min    4.539256e-15  0.216667  1.146404  0.018135
# 25%    3.002384e-14  0.241667  1.160348  0.025897
# 50%    5.550842e-14  0.266667  1.174293  0.033658
# 75%    8.057577e-13  0.366667  1.195026  0.034676
# max    1.556007e-12  0.466667  1.215758  0.035695
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  5.386849e-13 &  0.316667 &  1.178818 &  0.029163 \\
# std   &  8.813953e-13 &  0.132288 &  0.034898 &  0.009604 \\
# min   &  4.539256e-15 &  0.216667 &  1.146404 &  0.018135 \\
# 25\%   &  3.002384e-14 &  0.241667 &  1.160348 &  0.025897 \\
# 50\%   &  5.550842e-14 &  0.266667 &  1.174293 &  0.033658 \\
# 75\%   &  8.057577e-13 &  0.366667 &  1.195026 &  0.034676 \\
# max   &  1.556007e-12 &  0.466667 &  1.215758 &  0.035695 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:37:42.166956
# experiment number 1 took 25.259518146514893 seconds. That means the whole run will probably take 75.77855443954468 more seconds and 1.2629759073257447 more minutes.
# overall, it took 71.84445786476135 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.515826  0.261111  1.690082  0.005770
# std    0.320230  0.193170  0.274176  0.001084
# min    0.289610  0.133333  1.402736  0.004802
# 25%    0.332616  0.150000  1.560698  0.005184
# 50%    0.375622  0.166667  1.718660  0.005566
# 75%    0.628934  0.325000  1.833755  0.006253
# max    0.882246  0.483333  1.948850  0.006941
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.515826 &  0.261111 &  1.690082 &  0.005770 \\
# std   &  0.320230 &  0.193170 &  0.274176 &  0.001084 \\
# min   &  0.289610 &  0.133333 &  1.402736 &  0.004802 \\
# 25\%   &  0.332616 &  0.150000 &  1.560698 &  0.005184 \\
# 50\%   &  0.375622 &  0.166667 &  1.718660 &  0.005566 \\
# 75\%   &  0.628934 &  0.325000 &  1.833755 &  0.006253 \\
# max   &  0.882246 &  0.483333 &  1.948850 &  0.006941 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:39:00.604095
# experiment number 1 took 20.780237913131714 seconds. That means the whole run will probably take 62.34071373939514 more seconds and 1.0390118956565857 more minutes.
# overall, it took 60.180092096328735 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.749735  0.966667  0.229917  0.005447
# std    0.174448  0.057735  0.355526  0.000763
# min    0.572528  0.900000  0.013783  0.004945
# 25%    0.663959  0.950000  0.024752  0.005008
# 50%    0.755391  1.000000  0.035720  0.005071
# 75%    0.838339  1.000000  0.337984  0.005698
# max    0.921288  1.000000  0.640247  0.006326
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.749735 &  0.966667 &  0.229917 &  0.005447 \\
# std   &  0.174448 &  0.057735 &  0.355526 &  0.000763 \\
# min   &  0.572528 &  0.900000 &  0.013783 &  0.004945 \\
# 25\%   &  0.663959 &  0.950000 &  0.024752 &  0.005008 \\
# 50\%   &  0.755391 &  1.000000 &  0.035720 &  0.005071 \\
# 75\%   &  0.838339 &  1.000000 &  0.337984 &  0.005698 \\
# max   &  0.921288 &  1.000000 &  0.640247 &  0.006326 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 3]}

datset_params = {'num_samples':num_epochs,'seed':seed,'n_samples':50}

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:40:04.883153
# experiment number 1 took 15.712723970413208 seconds. That means the whole run will probably take 47.138171911239624 more seconds and 0.7856361985206604 more minutes.

# %%
pd22 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
