# %%
import evaluation 
import importlib
importlib.reload(evaluation)
# Out:
# <module 'evaluation' from '/Users/thomas/Documents/Master-Thesis/new_version/evaluation.py'>

# %%
from shallow_models.shallow_ensembles import RegressionEnsemble as ShallowEnsemble
import shallow_models
importlib.reload(shallow_models)
# Out:
# <module 'shallow_models' from '/Users/thomas/Documents/Master-Thesis/new_version/shallow_models/__init__.py'>

# %%
import ensembles
import networks
import dataset_creation
import tensorflow as tf
import base
import numpy as np
#from shallow_models.shallow_ensembles import BootstrapEnsemble as ShallowBootstrap

# %%
trials = 3

num_neurons = [[10,10,10],[5,10,5],[10,5,10]]
seeds = [50,100,150,200]
num_layers = len(num_neurons[0])
learning_rates = np.arange(0.01,0.1,0.005)#np.arange(0.1,0.01,0.001)#

#learning_rates   = (learning_rates-min(learning_rates))/(max(learning_rates)-min(learning_rates))

activations = [[tf.nn.tanh]*num_layers,[tf.nn.leaky_relu]*num_layers, [tf.sigmoid]*num_layers]
initialisation_schemes = [tf.keras.initializers.he_normal, tf.contrib.layers.xavier_initializer] 
param_grid = {'num_neurons': num_neurons,
              'activations':activations,
             'initialisation_scheme':initialisation_schemes,
             #'learning_rate':learning_rates,
             'seed':seeds,
             'l2':[True,False]
             }


model_num_neurons = [30,10,10,3]
model_params = {
    'seed':650,
    'learning_rate':0.2,
    'num_neurons':model_num_neurons,
    'activations':[tf.nn.leaky_relu]*len(model_num_neurons),
    'initialisation_scheme':tf.keras.initializers.he_normal
}
#thompson_model = networks.DropoutNetwork
#thompson_model = ensembles.BootstrapThroughTimeBobStrap,
thompson_model=ensembles.BootstrapEnsemble,

# %%
learning_rates
# Out:
# array([0.01 , 0.015, 0.02 , 0.025, 0.03 , 0.035, 0.04 , 0.045, 0.05 ,
#        0.055, 0.06 , 0.065, 0.07 , 0.075, 0.08 , 0.085, 0.09 , 0.095])

# %%
tg = evaluation.ThompsonGridSearch(param_grid=param_grid, 
                                   dataset_creator=dataset_creation.LinearDataset, 
                                   thompson_model=thompson_model,
                                   test_model=base.EnsembleNetwork,
                                  model_params=model_params)
# Out:
# initialising Network <class 'networks.DropoutNetwork'>

# %%
tg.plot_sample_grid()

# %%
tg.goforit(1)
tg.plot_sample_grid()
# Out:
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28115b48>
# <zip object at 0x1a28115b48>
# mean probability is 0.5
# (1,)
# (14, 1)

# %%
a = np.array([[1,2],[3,4],[5,6]])

# %%
a.T[[True,False]].T
# Out:
# array([[1],
#        [3],
#        [5]])

# %%
tg.goforit(10)
tg.plot_sample_grid()
# Out:
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a285b5948>
# <zip object at 0x1a285b5948>
# mean probability is 1.0
# (3,)
# (14, 3)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a27ae8cc8>
# <zip object at 0x1a27ae8cc8>
# mean probability is 1.0
# (4,)
# (14, 4)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a288e5948>
# <zip object at 0x1a288e5948>
# mean probability is 1.0
# (5,)
# (14, 5)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28a2b8c8>
# <zip object at 0x1a28a2b8c8>
# mean probability is 1.0
# (6,)
# (14, 6)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a27828688>
# <zip object at 0x1a27828688>
# mean probability is 0.8571428571428571
# (6,)
# (14, 6)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28419f48>
# <zip object at 0x1a28419f48>
# mean probability is 1.0
# (8,)
# (14, 8)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28413488>
# <zip object at 0x1a28413488>
# mean probability is 0.8888888888888888
# (8,)
# (14, 8)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28c23188>
# <zip object at 0x1a28c23188>
# mean probability is 0.7
# (7,)
# (14, 7)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28cd4088>
# <zip object at 0x1a28cd4088>
# mean probability is 0.8181818181818182
# (9,)
# (14, 9)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a269ddcc8>
# <zip object at 0x1a269ddcc8>
# mean probability is 0.9166666666666666
# (11,)
# (14, 11)

# %%
tg.goforit(10)
tg.plot_sample_grid()
# Out:
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a283bbe48>
# <zip object at 0x1a283bbe48>
# mean probability is 1.0
# (13,)
# (14, 13)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28b3ec08>
# <zip object at 0x1a28b3ec08>
# mean probability is 0.7857142857142857
# (11,)
# (14, 11)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a26c2f508>
# <zip object at 0x1a26c2f508>
# mean probability is 0.8666666666666667
# (13,)
# (14, 13)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a281b7c48>
# <zip object at 0x1a281b7c48>
# mean probability is 0.9375
# (15,)
# (14, 15)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28aa67c8>
# <zip object at 0x1a28aa67c8>
# mean probability is 0.8823529411764706
# (15,)
# (14, 15)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28ce0048>
# <zip object at 0x1a28ce0048>
# mean probability is 0.8888888888888888
# (16,)
# (14, 16)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a27c96688>
# <zip object at 0x1a27c96688>
# mean probability is 0.7894736842105263
# (15,)
# (14, 15)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28338448>
# <zip object at 0x1a28338448>
# mean probability is 0.85
# (17,)
# (14, 17)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a2888ca08>
# <zip object at 0x1a2888ca08>
# mean probability is 0.9047619047619048
# (19,)
# (14, 19)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28b1fd88>
# <zip object at 0x1a28b1fd88>
# mean probability is 0.8636363636363636
# (19,)
# (14, 19)

# %%
tg.goforit(10)
tg.plot_sample_grid()
# Out:
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28577a08>
# <zip object at 0x1a28577a08>
# mean probability is 0.9130434782608695
# (21,)
# (14, 21)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a2789ecc8>
# <zip object at 0x1a2789ecc8>
# mean probability is 0.9166666666666666
# (22,)
# (14, 22)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28a90cc8>
# <zip object at 0x1a28a90cc8>
# mean probability is 0.8
# (20,)
# (14, 20)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28c236c8>
# <zip object at 0x1a28c236c8>
# mean probability is 0.9230769230769231
# (24,)
# (14, 24)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a288c1f48>
# <zip object at 0x1a288c1f48>
# mean probability is 0.8888888888888888
# (24,)
# (14, 24)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28c81148>
# <zip object at 0x1a28c81148>
# mean probability is 0.8214285714285714
# (23,)
# (14, 23)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a280ed288>
# <zip object at 0x1a280ed288>
# mean probability is 0.8620689655172413
# (25,)
# (14, 25)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a282e4548>
# <zip object at 0x1a282e4548>
# mean probability is 0.9333333333333333
# (28,)
# (14, 28)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a282dd8c8>
# <zip object at 0x1a282dd8c8>
# mean probability is 0.967741935483871
# (30,)
# (14, 30)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28b4d048>
# <zip object at 0x1a28b4d048>
# mean probability is 0.875
# (28,)
# (14, 28)

# %%
tg.goforit(10)
tg.plot_sample_grid()
# Out:
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a278d0548>
# <zip object at 0x1a278d0548>
# mean probability is 0.8787878787878788
# (29,)
# (14, 29)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a2843d948>
# <zip object at 0x1a2843d948>
# mean probability is 0.8235294117647058
# (28,)
# (14, 28)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28117988>
# <zip object at 0x1a28117988>
# mean probability is 0.7714285714285715
# (27,)
# (14, 27)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a28bd7cc8>
# <zip object at 0x1a28bd7cc8>
# mean probability is 0.8333333333333334
# (30,)
# (14, 30)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a285d2b08>
# <zip object at 0x1a285d2b08>
# mean probability is 0.7567567567567568
# (28,)
# (14, 28)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a2821a048>
# <zip object at 0x1a2821a048>
# mean probability is 0.7631578947368421
# (29,)
# (14, 29)
# initialising Network <class 'base.EnsembleNetwork'>
# <zip object at 0x1a288dec88>
# <zip object at 0x1a288dec88>
# mean probability is 0.8717948717948718
# (34,)
# (14, 34)
# initialising Network <class 'base.EnsembleNetwork'>

# %%
tg.goforit(10)
tg.plot_sample_grid()

# %%
tg.goforit(10)
tg.plot_sample_grid()

# %%
tg.goforit(10)
tg.plot_sample_grid()

# %%
tg.goforit(10)
tg.plot_sample_grid()

# %%
tg.goforit(10)
tg.plot_sample_grid()

# %%
tg.goforit(10)
tg.plot_sample_grid()

# %%
tg.goforit(10)
tg.plot_sample_grid()
