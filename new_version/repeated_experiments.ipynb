# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline
import tensorflow as tf

from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'initialisation_scheme':tf.keras.initializers.he_normal}

datset_params = {'num_samples':num_epochs,'seed':seed,'n_samples':50}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 13:24:13.930506
# experiment number 1 took 26.20513606071472 seconds. That means the whole run will probably take 78.61540818214417 more seconds and 1.310256803035736 more minutes.
# overall, it took 71.50457215309143 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   1.896775e-07  0.850000  0.731633  0.027443
# std    3.176263e-07  0.044096  0.033279  0.006398
# min    4.250262e-11  0.816667  0.693363  0.020650
# 25%    6.331830e-09  0.825000  0.720561  0.024488
# 50%    1.262116e-08  0.833333  0.747759  0.028326
# 75%    2.844950e-07  0.866667  0.750769  0.030840
# max    5.563689e-07  0.900000  0.753778  0.033354
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  1.896775e-07 &  0.850000 &  0.731633 &  0.027443 \\
# std   &  3.176263e-07 &  0.044096 &  0.033279 &  0.006398 \\
# min   &  4.250262e-11 &  0.816667 &  0.693363 &  0.020650 \\
# 25\%   &  6.331830e-09 &  0.825000 &  0.720561 &  0.024488 \\
# 50\%   &  1.262116e-08 &  0.833333 &  0.747759 &  0.028326 \\
# 75\%   &  2.844950e-07 &  0.866667 &  0.750769 &  0.030840 \\
# max   &  5.563689e-07 &  0.900000 &  0.753778 &  0.033354 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 13:25:34.198538
# experiment number 1 took 44.07906413078308 seconds. That means the whole run will probably take 132.23719239234924 more seconds and 2.203953206539154 more minutes.
# overall, it took 103.81024694442749 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.711743  0.166667  1.802610  0.005139
# std    0.331864  0.033333  0.067479  0.000649
# min    0.328803  0.133333  1.728009  0.004677
# 25%    0.609866  0.150000  1.774220  0.004768
# 50%    0.890930  0.166667  1.820430  0.004860
# 75%    0.903214  0.183333  1.839910  0.005371
# max    0.915497  0.200000  1.859390  0.005882
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.711743 &  0.166667 &  1.802610 &  0.005139 \\
# std   &  0.331864 &  0.033333 &  0.067479 &  0.000649 \\
# min   &  0.328803 &  0.133333 &  1.728009 &  0.004677 \\
# 25\%   &  0.609866 &  0.150000 &  1.774220 &  0.004768 \\
# 50\%   &  0.890930 &  0.166667 &  1.820430 &  0.004860 \\
# 75\%   &  0.903214 &  0.183333 &  1.839910 &  0.005371 \\
# max   &  0.915497 &  0.200000 &  1.859390 &  0.005882 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 13:27:24.204493
# experiment number 1 took 26.65678596496582 seconds. That means the whole run will probably take 79.97035789489746 more seconds and 1.332839298248291 more minutes.
# overall, it took 75.61929988861084 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.370291  0.972222  0.236122  0.006750
# std    0.399041  0.048113  0.366506  0.000710
# min    0.009627  0.916667  0.012640  0.005937
# 25%    0.155952  0.958333  0.024633  0.006503
# 50%    0.302277  1.000000  0.036625  0.007068
# 75%    0.550623  1.000000  0.347863  0.007156
# max    0.798968  1.000000  0.659100  0.007245
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.370291 &  0.972222 &  0.236122 &  0.006750 \\
# std   &  0.399041 &  0.048113 &  0.366506 &  0.000710 \\
# min   &  0.009627 &  0.916667 &  0.012640 &  0.005937 \\
# 25\%   &  0.155952 &  0.958333 &  0.024633 &  0.006503 \\
# 50\%   &  0.302277 &  1.000000 &  0.036625 &  0.007068 \\
# 75\%   &  0.550623 &  1.000000 &  0.347863 &  0.007156 \\
# max   &  0.798968 &  1.000000 &  0.659100 &  0.007245 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 3]}

datset_params = {'num_samples':num_epochs,'seed':seed,'n_samples':50}

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 13:28:45.312896
# experiment number 1 took 19.686617851257324 seconds. That means the whole run will probably take 59.05985355377197 more seconds and 0.9843308925628662 more minutes.
# overall, it took 52.64451313018799 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.264429  0.077778 -1.031439  0.453085
# std    0.225280  0.025459  0.692085  0.053695
# min    0.079188  0.050000 -1.435579  0.391365
# 25%    0.139038  0.066667 -1.431006  0.435103
# 50%    0.198888  0.083333 -1.426432  0.478842
# 75%    0.357050  0.091667 -0.829369  0.483946
# max    0.515212  0.100000 -0.232306  0.489050
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.264429 &  0.077778 & -1.031439 &  0.453085 \\
# std   &  0.225280 &  0.025459 &  0.692085 &  0.053695 \\
# min   &  0.079188 &  0.050000 & -1.435579 &  0.391365 \\
# 25\%   &  0.139038 &  0.066667 & -1.431006 &  0.435103 \\
# 50\%   &  0.198888 &  0.083333 & -1.426432 &  0.478842 \\
# 75\%   &  0.357050 &  0.091667 & -0.829369 &  0.483946 \\
# max   &  0.515212 &  0.100000 & -0.232306 &  0.489050 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 13:29:42.032204
# experiment number 1 took 19.598741054534912 seconds. That means the whole run will probably take 58.796223163604736 more seconds and 0.9799370527267456 more minutes.
# overall, it took 58.11190986633301 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.317971  0.238889  0.952231  0.050247
# std    0.402177  0.091793  0.156595  0.010487
# min    0.046644  0.150000  0.846573  0.039087
# 25%    0.086943  0.191667  0.862277  0.045423
# 50%    0.127242  0.233333  0.877981  0.051758
# 75%    0.453634  0.283333  1.005061  0.055827
# max    0.780027  0.333333  1.132140  0.059897
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.317971 &  0.238889 &  0.952231 &  0.050247 \\
# std   &  0.402177 &  0.091793 &  0.156595 &  0.010487 \\
# min   &  0.046644 &  0.150000 &  0.846573 &  0.039087 \\
# 25\%   &  0.086943 &  0.191667 &  0.862277 &  0.045423 \\
# 50\%   &  0.127242 &  0.233333 &  0.877981 &  0.051758 \\
# 75\%   &  0.453634 &  0.283333 &  1.005061 &  0.055827 \\
# max   &  0.780027 &  0.333333 &  1.132140 &  0.059897 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 13:30:44.294946
# experiment number 1 took 20.442466974258423 seconds. That means the whole run will probably take 61.32740092277527 more seconds and 1.022123348712921 more minutes.
# overall, it took 59.14725685119629 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.138748  0.905556  0.269686  0.047736
# std    0.168706  0.149381  0.289304  0.013349
# min    0.005977  0.733333 -0.007304  0.033845
# 25%    0.043829  0.858333  0.119577  0.041370
# 50%    0.081680  0.983333  0.246457  0.048894
# 75%    0.205133  0.991667  0.408180  0.054681
# max    0.328586  1.000000  0.569903  0.060468
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.138748 &  0.905556 &  0.269686 &  0.047736 \\
# std   &  0.168706 &  0.149381 &  0.289304 &  0.013349 \\
# min   &  0.005977 &  0.733333 & -0.007304 &  0.033845 \\
# 25\%   &  0.043829 &  0.858333 &  0.119577 &  0.041370 \\
# 50\%   &  0.081680 &  0.983333 &  0.246457 &  0.048894 \\
# 75\%   &  0.205133 &  0.991667 &  0.408180 &  0.054681 \\
# max   &  0.328586 &  1.000000 &  0.569903 &  0.060468 \\
# \bottomrule
# \end{tabular}
