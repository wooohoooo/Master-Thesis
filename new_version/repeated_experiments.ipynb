# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline
import tensorflow as tf

from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3, ForcedDiversityBootstrapThroughTime
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#10
num_epochs = 10#50#15#50
seed = 42
num_samples = 150

model_params = {'num_epochs':num_epochs,'seed':seed,'initialisation_scheme':tf.keras.initializers.he_normal}

dataset_params = {'seed':seed,'num_samples':num_samples}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:42:04.875742
# experiment number 1 took 29.430211067199707 seconds. That means the whole run will probably take 88.29063320159912 more seconds and 1.4715105533599853 more minutes.
# overall, it took 86.26233410835266 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00       3.0  3.000000  3.000000
# mean   4.146495e-10       1.0  0.757478  0.016204
# std    4.544204e-10       0.0  0.003467  0.001226
# min    1.073719e-13       1.0  0.753479  0.014806
# 25%    1.717176e-10       1.0  0.756393  0.015758
# 50%    3.433278e-10       1.0  0.759308  0.016711
# 75%    6.219206e-10       1.0  0.759477  0.016903
# max    9.005134e-10       1.0  0.759646  0.017095
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &       3.0 &  3.000000 &  3.000000 \\
# mean  &  4.146495e-10 &       1.0 &  0.757478 &  0.016204 \\
# std   &  4.544204e-10 &       0.0 &  0.003467 &  0.001226 \\
# min   &  1.073719e-13 &       1.0 &  0.753479 &  0.014806 \\
# 25\%   &  1.717176e-10 &       1.0 &  0.756393 &  0.015758 \\
# 50\%   &  3.433278e-10 &       1.0 &  0.759308 &  0.016711 \\
# 75\%   &  6.219206e-10 &       1.0 &  0.759477 &  0.016903 \\
# max   &  9.005134e-10 &       1.0 &  0.759646 &  0.017095 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:43:40.171560
# experiment number 1 took 49.39553499221802 seconds. That means the whole run will probably take 148.18660497665405 more seconds and 2.469776749610901 more minutes.
# overall, it took 143.28449487686157 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00       3.0  3.000000  3.000000
# mean   2.886970e-06       1.0  0.344725  0.146771
# std    5.000378e-06       0.0  0.634445  0.227964
# min    1.736937e-22       1.0 -0.387251  0.013302
# 25%    1.689179e-16       1.0  0.148699  0.015160
# 50%    3.378357e-16       1.0  0.684649  0.017019
# 75%    4.330454e-06       1.0  0.710713  0.213506
# max    8.660909e-06       1.0  0.736777  0.409993
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &       3.0 &  3.000000 &  3.000000 \\
# mean  &  2.886970e-06 &       1.0 &  0.344725 &  0.146771 \\
# std   &  5.000378e-06 &       0.0 &  0.634445 &  0.227964 \\
# min   &  1.736937e-22 &       1.0 & -0.387251 &  0.013302 \\
# 25\%   &  1.689179e-16 &       1.0 &  0.148699 &  0.015160 \\
# 50\%   &  3.378357e-16 &       1.0 &  0.684649 &  0.017019 \\
# 75\%   &  4.330454e-06 &       1.0 &  0.710713 &  0.213506 \\
# max   &  8.660909e-06 &       1.0 &  0.736777 &  0.409993 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:46:09.188641
# experiment number 1 took 36.756125926971436 seconds. That means the whole run will probably take 110.2683777809143 more seconds and 1.8378062963485717 more minutes.
# overall, it took 110.97076606750488 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000       3.0  3.000000  3.000000
# mean   0.422509       1.0  0.361720  0.000891
# std    0.330502       0.0  0.598931  0.000129
# min    0.052312       1.0 -0.329541  0.000803
# 25%    0.289814       1.0  0.179723  0.000816
# 50%    0.527316       1.0  0.688988  0.000829
# 75%    0.607608       1.0  0.707350  0.000934
# max    0.687900       1.0  0.725713  0.001039
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &       3.0 &  3.000000 &  3.000000 \\
# mean  &  0.422509 &       1.0 &  0.361720 &  0.000891 \\
# std   &  0.330502 &       0.0 &  0.598931 &  0.000129 \\
# min   &  0.052312 &       1.0 & -0.329541 &  0.000803 \\
# 25\%   &  0.289814 &       1.0 &  0.179723 &  0.000816 \\
# 50\%   &  0.527316 &       1.0 &  0.688988 &  0.000829 \\
# 75\%   &  0.607608 &       1.0 &  0.707350 &  0.000934 \\
# max   &  0.687900 &       1.0 &  0.725713 &  0.001039 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 3#10
#num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 3]}

dataset_params = {'num_samples':num_samples,'seed':seed}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:48:04.413375
# experiment number 1 took 32.60734009742737 seconds. That means the whole run will probably take 97.8220202922821 more seconds and 1.6303670048713683 more minutes.
# overall, it took 75.65177297592163 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.212298  0.407407  0.590649  0.074905
# std    0.330850  0.012830  0.007833  0.003386
# min    0.000343  0.400000  0.583278  0.071942
# 25%    0.021679  0.400000  0.586537  0.073060
# 50%    0.043015  0.400000  0.589796  0.074179
# 75%    0.318275  0.411111  0.594335  0.076387
# max    0.593535  0.422222  0.598873  0.078596
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.212298 &  0.407407 &  0.590649 &  0.074905 \\
# std   &  0.330850 &  0.012830 &  0.007833 &  0.003386 \\
# min   &  0.000343 &  0.400000 &  0.583278 &  0.071942 \\
# 25\%   &  0.021679 &  0.400000 &  0.586537 &  0.073060 \\
# 50\%   &  0.043015 &  0.400000 &  0.589796 &  0.074179 \\
# 75\%   &  0.318275 &  0.411111 &  0.594335 &  0.076387 \\
# max   &  0.593535 &  0.422222 &  0.598873 &  0.078596 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:49:24.805104
# experiment number 1 took 39.76470994949341 seconds. That means the whole run will probably take 119.29412984848022 more seconds and 1.9882354974746703 more minutes.
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# overall, it took 108.24540114402771 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   6.061586e-01  0.414815       inf  0.241551
# std    5.327372e-01  0.521315       NaN  0.176854
# min    4.401016e-08  0.000000 -0.315454  0.040796
# 25%    4.092380e-01  0.122222  0.367457  0.175156
# 50%    8.184759e-01  0.244444       NaN  0.309516
# 75%    9.092379e-01  0.622222       inf  0.341928
# max    1.000000e+00  1.000000       inf  0.374340
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  6.061586e-01 &  0.414815 &       inf &  0.241551 \\
# std   &  5.327372e-01 &  0.521315 &       NaN &  0.176854 \\
# min   &  4.401016e-08 &  0.000000 & -0.315454 &  0.040796 \\
# 25\%   &  4.092380e-01 &  0.122222 &  0.367457 &  0.175156 \\
# 50\%   &  8.184759e-01 &  0.244444 &       NaN &  0.309516 \\
# 75\%   &  9.092379e-01 &  0.622222 &       inf &  0.341928 \\
# max   &  1.000000e+00 &  1.000000 &       inf &  0.374340 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:51:17.757641
# experiment number 1 took 31.752254962921143 seconds. That means the whole run will probably take 95.25676488876343 more seconds and 1.5876127481460571 more minutes.
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# overall, it took 95.98651194572449 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   5.360028e-01  0.666667       inf  0.107507
# std    5.038736e-01  0.577350       NaN  0.146046
# min    9.763789e-09  0.000000 -0.208538  0.005956
# 25%    3.040042e-01  0.500000 -0.031220  0.023821
# 50%    6.080085e-01  1.000000       NaN  0.041685
# 75%    8.040042e-01  1.000000       inf  0.158283
# max    1.000000e+00  1.000000       inf  0.274880
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  5.360028e-01 &  0.666667 &       inf &  0.107507 \\
# std   &  5.038736e-01 &  0.577350 &       NaN &  0.146046 \\
# min   &  9.763789e-09 &  0.000000 & -0.208538 &  0.005956 \\
# 25\%   &  3.040042e-01 &  0.500000 & -0.031220 &  0.023821 \\
# 50\%   &  6.080085e-01 &  1.000000 &       NaN &  0.041685 \\
# 75\%   &  8.040042e-01 &  1.000000 &       inf &  0.158283 \\
# max   &  1.000000e+00 &  1.000000 &       inf &  0.274880 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(BootstrapEnsemble, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:52:57.959559
# experiment number 1 took 18.272446870803833 seconds. That means the whole run will probably take 54.8173406124115 more seconds and 0.9136223435401917 more minutes.
# overall, it took 55.78597712516785 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   8.433754e-09  0.837037  0.717454  0.032640
# std    1.456494e-08  0.046259  0.022545  0.006232
# min    3.133228e-12  0.800000  0.694940  0.025494
# 25%    2.469040e-11  0.811111  0.706165  0.030488
# 50%    4.624758e-11  0.822222  0.717390  0.035482
# 75%    1.264906e-08  0.855556  0.728710  0.036213
# max    2.525188e-08  0.888889  0.740031  0.036944
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  8.433754e-09 &  0.837037 &  0.717454 &  0.032640 \\
# std   &  1.456494e-08 &  0.046259 &  0.022545 &  0.006232 \\
# min   &  3.133228e-12 &  0.800000 &  0.694940 &  0.025494 \\
# 25\%   &  2.469040e-11 &  0.811111 &  0.706165 &  0.030488 \\
# 50\%   &  4.624758e-11 &  0.822222 &  0.717390 &  0.035482 \\
# 75\%   &  1.264906e-08 &  0.855556 &  0.728710 &  0.036213 \\
# max   &  2.525188e-08 &  0.888889 &  0.740031 &  0.036944 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:53:57.967415
# experiment number 1 took 30.74599313735962 seconds. That means the whole run will probably take 92.23797941207886 more seconds and 1.5372996568679809 more minutes.
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# overall, it took 98.59574794769287 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   3.333338e-01  0.666667       inf  0.408271
# std    5.773499e-01  0.577350       NaN  0.255480
# min    2.583581e-14  0.000000 -0.490915  0.255898
# 25%    6.911784e-07  0.500000 -0.306316  0.260797
# 50%    1.382357e-06  1.000000       NaN  0.265696
# 75%    5.000007e-01  1.000000       inf  0.484458
# max    1.000000e+00  1.000000       inf  0.703220
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  3.333338e-01 &  0.666667 &       inf &  0.408271 \\
# std   &  5.773499e-01 &  0.577350 &       NaN &  0.255480 \\
# min   &  2.583581e-14 &  0.000000 & -0.490915 &  0.255898 \\
# 25\%   &  6.911784e-07 &  0.500000 & -0.306316 &  0.260797 \\
# 50\%   &  1.382357e-06 &  1.000000 &       NaN &  0.265696 \\
# 75\%   &  5.000007e-01 &  1.000000 &       inf &  0.484458 \\
# max   &  1.000000e+00 &  1.000000 &       inf &  0.703220 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 14:55:41.452458
# experiment number 1 took 34.39041590690613 seconds. That means the whole run will probably take 103.17124772071838 more seconds and 1.7195207953453064 more minutes.
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# overall, it took 97.19419980049133 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.395514  0.666667       inf  0.096213
# std    0.526674  0.577350       NaN  0.154962
# min    0.035544  0.000000 -0.301671  0.006626
# 25%    0.093271  0.500000 -0.131696  0.006745
# 50%    0.150997  1.000000       NaN  0.006865
# 75%    0.575498  1.000000       inf  0.141007
# max    1.000000  1.000000       inf  0.275148
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.395514 &  0.666667 &       inf &  0.096213 \\
# std   &  0.526674 &  0.577350 &       NaN &  0.154962 \\
# min   &  0.035544 &  0.000000 & -0.301671 &  0.006626 \\
# 25\%   &  0.093271 &  0.500000 & -0.131696 &  0.006745 \\
# 50\%   &  0.150997 &  1.000000 &       NaN &  0.006865 \\
# 75\%   &  0.575498 &  1.000000 &       inf &  0.141007 \\
# max   &  1.000000 &  1.000000 &       inf &  0.275148 \\
# \bottomrule
# \end{tabular}
