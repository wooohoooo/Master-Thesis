# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]

# %matplotlib inline
import tensorflow as tf

from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3, ForcedDiversityBootstrapThroughTime,BootstrapThroughTimeBobStrap

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#10
num_epochs = 10#15
seed = 42
num_samples =200
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]


model_params = {'num_epochs':num_epochs,'seed':seed,'initialisation_scheme':tf.keras.initializers.he_normal,'num_neurons':num_neurons,'l2':True}

dataset_params = {'seed':seed,'num_samples':num_samples}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 12:52:40.630739
# experiment number 1 took 23.398223161697388 seconds. That means the whole run will probably take 70.19466948509216 more seconds and 1.1699111580848693 more minutes.
# overall, it took 94.43183708190918 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   5.435413e-09  0.005556  0.460171  0.009189
# std    9.414388e-09  0.009623  1.351071  0.000853
# min    6.740911e-15  0.000000 -0.989524  0.008622
# 25%    1.348433e-14  0.000000 -0.151842  0.008698
# 50%    2.022775e-14  0.000000  0.685839  0.008774
# 75%    8.153116e-09  0.008333  1.185019  0.009472
# max    1.630621e-08  0.016667  1.684199  0.010170
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  5.435413e-09 &  0.005556 &  0.460171 &  0.009189 \\
# std   &  9.414388e-09 &  0.009623 &  1.351071 &  0.000853 \\
# min   &  6.740911e-15 &  0.000000 & -0.989524 &  0.008622 \\
# 25\%   &  1.348433e-14 &  0.000000 & -0.151842 &  0.008698 \\
# 50\%   &  2.022775e-14 &  0.000000 &  0.685839 &  0.008774 \\
# 75\%   &  8.153116e-09 &  0.008333 &  1.185019 &  0.009472 \\
# max   &  1.630621e-08 &  0.016667 &  1.684199 &  0.010170 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 12:54:23.396838
# doing a burn in of 3 epochs
# experiment number 1 took 89.24680995941162 seconds. That means the whole run will probably take 267.74042987823486 more seconds and 4.462340497970581 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 246.03422784805298 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   2.950607e-01  0.011111 -3.976327  0.008362
# std    5.014406e-01  0.019245  4.675896  0.002092
# min    2.095453e-07  0.000000 -7.287311  0.006963
# 25%    5.571736e-03  0.000000 -6.650829  0.007160
# 50%    1.114326e-02  0.000000 -6.014348  0.007357
# 75%    4.425910e-01  0.016667 -2.320835  0.009062
# max    8.740387e-01  0.033333  1.372679  0.010767
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  2.950607e-01 &  0.011111 & -3.976327 &  0.008362 \\
# std   &  5.014406e-01 &  0.019245 &  4.675896 &  0.002092 \\
# min   &  2.095453e-07 &  0.000000 & -7.287311 &  0.006963 \\
# 25\%   &  5.571736e-03 &  0.000000 & -6.650829 &  0.007160 \\
# 50\%   &  1.114326e-02 &  0.000000 & -6.014348 &  0.007357 \\
# 75\%   &  4.425910e-01 &  0.016667 & -2.320835 &  0.009062 \\
# max   &  8.740387e-01 &  0.033333 &  1.372679 &  0.010767 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 12:58:37.714049
# doing a burn in of 3 epochs
# experiment number 1 took 76.84023380279541 seconds. That means the whole run will probably take 230.52070140838623 more seconds and 3.8420116901397705 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 186.54055285453796 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.374721  0.022222 -1.122455  0.007704
# std    0.349522  0.019245  3.139132  0.001022
# min    0.000041  0.000000 -4.746982  0.006787
# 25%    0.216095  0.016667 -2.046269  0.007153
# 50%    0.432148  0.033333  0.654444  0.007519
# 75%    0.562060  0.033333  0.689809  0.008162
# max    0.691973  0.033333  0.725174  0.008806
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.374721 &  0.022222 & -1.122455 &  0.007704 \\
# std   &  0.349522 &  0.019245 &  3.139132 &  0.001022 \\
# min   &  0.000041 &  0.000000 & -4.746982 &  0.006787 \\
# 25\%   &  0.216095 &  0.016667 & -2.046269 &  0.007153 \\
# 50\%   &  0.432148 &  0.033333 &  0.654444 &  0.007519 \\
# 75\%   &  0.562060 &  0.033333 &  0.689809 &  0.008162 \\
# max   &  0.691973 &  0.033333 &  0.725174 &  0.008806 \\
# \bottomrule
# \end{tabular}

# %%
pd3 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:01:48.810624
# doing a burn in of 3 epochs
# experiment number 1 took 49.60470700263977 seconds. That means the whole run will probably take 148.8141210079193 more seconds and 2.4802353501319887 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 143.95272707939148 seconds with 3 experiments
#          cobeau  coverage       nlpd      rsme
# count  3.000000       3.0   3.000000  3.000000
# mean   0.628093       0.0  -6.684853  0.007882
# std    0.283442       0.0   6.286623  0.001183
# min    0.355795       0.0 -12.598858  0.006517
# 25%    0.481390       0.0  -9.986130  0.007514
# 50%    0.606985       0.0  -7.373403  0.008511
# 75%    0.764243       0.0  -3.727851  0.008564
# max    0.921500       0.0  -0.082300  0.008616
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000 &       3.0 &   3.000000 &  3.000000 \\
# mean  &  0.628093 &       0.0 &  -6.684853 &  0.007882 \\
# std   &  0.283442 &       0.0 &   6.286623 &  0.001183 \\
# min   &  0.355795 &       0.0 & -12.598858 &  0.006517 \\
# 25\%   &  0.481390 &       0.0 &  -9.986130 &  0.007514 \\
# 50\%   &  0.606985 &       0.0 &  -7.373403 &  0.008511 \\
# 75\%   &  0.764243 &       0.0 &  -3.727851 &  0.008564 \\
# max   &  0.921500 &       0.0 &  -0.082300 &  0.008616 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 3#10
#num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':num_neurons_nonlinear,'l2':True}

dataset_params = {'num_samples':num_samples,'seed':seed}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:04:17.068284
# experiment number 1 took 34.66362500190735 seconds. That means the whole run will probably take 103.99087500572205 more seconds and 1.7331812500953674 more minutes.
# overall, it took 86.77099704742432 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.040518  0.027778  0.188389  0.118725
# std    0.069340  0.019245  0.277131  0.005064
# min    0.000121  0.016667 -0.081969  0.113908
# 25%    0.000485  0.016667  0.046668  0.116085
# 50%    0.000848  0.016667  0.175306  0.118263
# 75%    0.060716  0.033333  0.323568  0.121133
# max    0.120584  0.050000  0.471830  0.124004
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.040518 &  0.027778 &  0.188389 &  0.118725 \\
# std   &  0.069340 &  0.019245 &  0.277131 &  0.005064 \\
# min   &  0.000121 &  0.016667 & -0.081969 &  0.113908 \\
# 25\%   &  0.000485 &  0.016667 &  0.046668 &  0.116085 \\
# 50\%   &  0.000848 &  0.016667 &  0.175306 &  0.118263 \\
# 75\%   &  0.060716 &  0.033333 &  0.323568 &  0.121133 \\
# max   &  0.120584 &  0.050000 &  0.471830 &  0.124004 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:05:48.251609
# doing a burn in of 3 epochs
# experiment number 1 took 66.45185112953186 seconds. That means the whole run will probably take 199.35555338859558 more seconds and 3.322592556476593 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 189.01534008979797 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.276412  0.033333 -5.257913  0.048707
# std    0.477580  0.028868  3.221967  0.008056
# min    0.000663  0.016667 -8.945035  0.042124
# 25%    0.000681  0.016667 -6.394703  0.044215
# 50%    0.000698  0.016667 -3.844371  0.046306
# 75%    0.414286  0.041667 -3.414351  0.051998
# max    0.827873  0.066667 -2.984331  0.057690
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.276412 &  0.033333 & -5.257913 &  0.048707 \\
# std   &  0.477580 &  0.028868 &  3.221967 &  0.008056 \\
# min   &  0.000663 &  0.016667 & -8.945035 &  0.042124 \\
# 25\%   &  0.000681 &  0.016667 & -6.394703 &  0.044215 \\
# 50\%   &  0.000698 &  0.016667 & -3.844371 &  0.046306 \\
# 75\%   &  0.414286 &  0.041667 & -3.414351 &  0.051998 \\
# max   &  0.827873 &  0.066667 & -2.984331 &  0.057690 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:09:01.561099
# doing a burn in of 3 epochs
# experiment number 1 took 52.73725414276123 seconds. That means the whole run will probably take 158.2117624282837 more seconds and 2.6368627071380617 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 163.48383712768555 seconds with 3 experiments
#          cobeau  coverage       nlpd      rsme
# count  3.000000  3.000000   3.000000  3.000000
# mean   0.469145  0.022222  -8.987616  0.051255
# std    0.437168  0.009623   8.454604  0.008935
# min    0.161686  0.016667 -18.360568  0.045339
# 25%    0.218918  0.016667 -12.513135  0.046116
# 50%    0.276150  0.016667  -6.665702  0.046893
# 75%    0.622874  0.025000  -4.301140  0.054213
# max    0.969599  0.033333  -1.936578  0.061533
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &   3.000000 &  3.000000 \\
# mean  &  0.469145 &  0.022222 &  -8.987616 &  0.051255 \\
# std   &  0.437168 &  0.009623 &   8.454604 &  0.008935 \\
# min   &  0.161686 &  0.016667 & -18.360568 &  0.045339 \\
# 25\%   &  0.218918 &  0.016667 & -12.513135 &  0.046116 \\
# 50\%   &  0.276150 &  0.016667 &  -6.665702 &  0.046893 \\
# 75\%   &  0.622874 &  0.025000 &  -4.301140 &  0.054213 \\
# max   &  0.969599 &  0.033333 &  -1.936578 &  0.061533 \\
# \bottomrule
# \end{tabular}

# %%
pd44 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:11:49.464565
# doing a burn in of 3 epochs
# experiment number 1 took 53.272099018096924 seconds. That means the whole run will probably take 159.81629705429077 more seconds and 2.6636049509048463 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 159.46231698989868 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.596261  0.055556 -6.102754  0.049455
# std    0.185573  0.019245  2.190399  0.009087
# min    0.449126  0.033333 -8.499855  0.039006
# 25%    0.492022  0.050000 -7.051413  0.046423
# 50%    0.534918  0.066667 -5.602972  0.053840
# 75%    0.669829  0.066667 -4.904203  0.054679
# max    0.804740  0.066667 -4.205434  0.055517
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.596261 &  0.055556 & -6.102754 &  0.049455 \\
# std   &  0.185573 &  0.019245 &  2.190399 &  0.009087 \\
# min   &  0.449126 &  0.033333 & -8.499855 &  0.039006 \\
# 25\%   &  0.492022 &  0.050000 & -7.051413 &  0.046423 \\
# 50\%   &  0.534918 &  0.066667 & -5.602972 &  0.053840 \\
# 75\%   &  0.669829 &  0.066667 & -4.904203 &  0.054679 \\
# max   &  0.804740 &  0.066667 & -4.205434 &  0.055517 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(BootstrapEnsemble, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:14:33.176862
# experiment number 1 took 25.23042893409729 seconds. That means the whole run will probably take 75.69128680229187 more seconds and 1.2615214467048645 more minutes.
# overall, it took 93.31186079978943 seconds with 3 experiments
#          cobeau  coverage      nlpd        rsme
# count  3.000000  3.000000  3.000000    3.000000
# mean   0.587316  0.920904 -4.335609  149.321293
# std    0.176957  0.035282  0.201265   21.156729
# min    0.386502  0.881356 -4.454911  130.807172
# 25%    0.520763  0.906780 -4.451795  137.791175
# 50%    0.655025  0.932203 -4.448679  144.775178
# 75%    0.687723  0.940678 -4.275958  158.578354
# max    0.720421  0.949153 -4.103237  172.381530
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &        rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &    3.000000 \\
# mean  &  0.587316 &  0.920904 & -4.335609 &  149.321293 \\
# std   &  0.176957 &  0.035282 &  0.201265 &   21.156729 \\
# min   &  0.386502 &  0.881356 & -4.454911 &  130.807172 \\
# 25\%   &  0.520763 &  0.906780 & -4.451795 &  137.791175 \\
# 50\%   &  0.655025 &  0.932203 & -4.448679 &  144.775178 \\
# 75\%   &  0.687723 &  0.940678 & -4.275958 &  158.578354 \\
# max   &  0.720421 &  0.949153 & -4.103237 &  172.381530 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:16:11.153351
# doing a burn in of 3 epochs
# experiment number 1 took 58.24687623977661 seconds. That means the whole run will probably take 174.74062871932983 more seconds and 2.9123438119888307 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 188.75229907035828 seconds with 3 experiments
#              cobeau  coverage       nlpd       rsme
# count  3.000000e+00  3.000000   3.000000   3.000000
# mean   8.033124e-02  0.694915  -9.852621  25.042961
# std    1.387247e-01  0.426432  12.992016  11.607950
# min    4.318000e-14  0.203390 -24.849184  18.331866
# 25%    2.386156e-04  0.559322 -13.774842  18.341110
# 50%    4.772312e-04  0.915254  -2.700500  18.350354
# 75%    1.204969e-01  0.940678  -2.354340  28.398509
# max    2.405165e-01  0.966102  -2.008181  38.446664
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &       nlpd &       rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &   3.000000 &   3.000000 \\
# mean  &  8.033124e-02 &  0.694915 &  -9.852621 &  25.042961 \\
# std   &  1.387247e-01 &  0.426432 &  12.992016 &  11.607950 \\
# min   &  4.318000e-14 &  0.203390 & -24.849184 &  18.331866 \\
# 25\%   &  2.386156e-04 &  0.559322 & -13.774842 &  18.341110 \\
# 50\%   &  4.772312e-04 &  0.915254 &  -2.700500 &  18.350354 \\
# 75\%   &  1.204969e-01 &  0.940678 &  -2.354340 &  28.398509 \\
# max   &  2.405165e-01 &  0.966102 &  -2.008181 &  38.446664 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:19:24.181887
# doing a burn in of 3 epochs
# experiment number 1 took 62.42206287384033 seconds. That means the whole run will probably take 187.266188621521 more seconds and 3.1211031436920167 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 180.43034768104553 seconds with 3 experiments
#          cobeau  coverage       nlpd       rsme
# count  3.000000  3.000000   3.000000   3.000000
# mean   0.481016  0.672316  -5.493084  11.860598
# std    0.451549  0.465511   5.845806   1.996070
# min    0.007268  0.135593 -12.237041  10.582516
# 25%    0.268281  0.525424  -7.304295  10.710539
# 50%    0.529293  0.915254  -2.371548  10.838561
# 75%    0.717890  0.940678  -2.121105  12.499638
# max    0.906486  0.966102  -1.870662  14.160715
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &   3.000000 &   3.000000 \\
# mean  &  0.481016 &  0.672316 &  -5.493084 &  11.860598 \\
# std   &  0.451549 &  0.465511 &   5.845806 &   1.996070 \\
# min   &  0.007268 &  0.135593 & -12.237041 &  10.582516 \\
# 25\%   &  0.268281 &  0.525424 &  -7.304295 &  10.710539 \\
# 50\%   &  0.529293 &  0.915254 &  -2.371548 &  10.838561 \\
# 75\%   &  0.717890 &  0.940678 &  -2.121105 &  12.499638 \\
# max   &  0.906486 &  0.966102 &  -1.870662 &  14.160715 \\
# \bottomrule
# \end{tabular}

# %%
pd444 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 13:22:28.805847
# doing a burn in of 3 epochs
# experiment number 1 took 52.65674304962158 seconds. That means the whole run will probably take 157.97022914886475 more seconds and 2.632837152481079 more minutes.
# doing a burn in of 3 epochs
# doing a burn in of 3 epochs
# overall, it took 168.41440320014954 seconds with 3 experiments
#          cobeau  coverage       nlpd       rsme
# count  3.000000  3.000000   3.000000   3.000000
# mean   0.841153  0.214689 -30.657111  16.402542
# std    0.094119  0.076428  15.671550   2.711524
# min    0.733431  0.135593 -48.451677  13.370787
# 25%    0.807990  0.177966 -36.529882  15.305963
# 50%    0.882549  0.220339 -24.608087  17.241139
# 75%    0.895014  0.254237 -21.759829  17.918419
# max    0.907480  0.288136 -18.911570  18.595699
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &   3.000000 &   3.000000 \\
# mean  &  0.841153 &  0.214689 & -30.657111 &  16.402542 \\
# std   &  0.094119 &  0.076428 &  15.671550 &   2.711524 \\
# min   &  0.733431 &  0.135593 & -48.451677 &  13.370787 \\
# 25\%   &  0.807990 &  0.177966 & -36.529882 &  15.305963 \\
# 50\%   &  0.882549 &  0.220339 & -24.608087 &  17.241139 \\
# 75\%   &  0.895014 &  0.254237 & -21.759829 &  17.918419 \\
# max   &  0.907480 &  0.288136 & -18.911570 &  18.595699 \\
# \bottomrule
# \end{tabular}
