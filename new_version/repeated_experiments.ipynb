# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

# %%
num_meta_epochs = 10

model_params = {'num_epochs':15}

datset_params = {'num_samples':50}

# %% [markdown]
# # Linear

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 39.76233696937561 seconds. That means the whole run will probably take 397.6233696937561 more seconds and 6.627056161562602 more minutes
# overall, it took 316.66621017456055 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.002062   0.080000 -11.922842  10.331099
# std     0.004865   0.017213   2.086203   0.815784
# min     0.000002   0.050000 -16.733433   9.500097
# 25%     0.000016   0.070833 -12.678919   9.682907
# 50%     0.000054   0.083333 -11.782063  10.090629
# 75%     0.000117   0.083333 -10.865043  10.928229
# max     0.015142   0.116667  -8.884290  11.942580
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.002062 &   0.080000 & -11.922842 &  10.331099 \\
# std   &   0.004865 &   0.017213 &   2.086203 &   0.815784 \\
# min   &   0.000002 &   0.050000 & -16.733433 &   9.500097 \\
# 25\%   &   0.000016 &   0.070833 & -12.678919 &   9.682907 \\
# 50\%   &   0.000054 &   0.083333 & -11.782063 &  10.090629 \\
# 75\%   &   0.000117 &   0.083333 & -10.865043 &  10.928229 \\
# max   &   0.015142 &   0.116667 &  -8.884290 &  11.942580 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 60.22779393196106 seconds. That means the whole run will probably take 602.2779393196106 more seconds and 10.037965655326843 more minutes
# overall, it took 592.2654988765717 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.325888   0.053333 -10.827364   2.008031
# std     0.266817   0.020488   7.106252   0.059744
# min     0.024088   0.016667 -25.389294   1.933451
# 25%     0.120163   0.050000 -14.973970   1.962721
# 50%     0.217672   0.050000  -7.988915   2.016406
# 75%     0.513680   0.062500  -5.360492   2.019459
# max     0.775053   0.083333  -3.822782   2.146179
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.325888 &   0.053333 & -10.827364 &   2.008031 \\
# std   &   0.266817 &   0.020488 &   7.106252 &   0.059744 \\
# min   &   0.024088 &   0.016667 & -25.389294 &   1.933451 \\
# 25\%   &   0.120163 &   0.050000 & -14.973970 &   1.962721 \\
# 50\%   &   0.217672 &   0.050000 &  -7.988915 &   2.016406 \\
# 75\%   &   0.513680 &   0.062500 &  -5.360492 &   2.019459 \\
# max   &   0.775053 &   0.083333 &  -3.822782 &   2.146179 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 72.09895706176758 seconds. That means the whole run will probably take 720.9895706176758 more seconds and 12.01649284362793 more minutes

# %% [markdown]
# # Nonlinear

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)

# %%
pd22 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
