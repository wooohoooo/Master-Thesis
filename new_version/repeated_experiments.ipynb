# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
num_meta_epochs = 10

model_params = {'num_epochs':15}

datset_params = {'num_samples':50}

# %% [markdown]
# # Linear

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 53.296334981918335 seconds. That means the whole run will probably take 532.9633498191833 more seconds and 8.88272249698639 more minutes
# overall, it took 463.39471220970154 seconds with 10 experiments
#              cobeau   coverage       nlpd       rsme
# count  1.000000e+01  10.000000  10.000000  10.000000
# mean   3.014543e-07   0.375000   1.326776   0.015155
# std    7.458016e-07   0.078272   0.112963   0.006210
# min    3.465570e-15   0.283333   1.187871   0.006574
# 25%    4.564384e-11   0.325000   1.261823   0.011037
# 50%    7.936234e-10   0.366667   1.282146   0.014813
# 75%    1.617660e-08   0.395833   1.408711   0.019402
# max    2.347817e-06   0.533333   1.546409   0.023895
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  1.000000e+01 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &  3.014543e-07 &   0.375000 &   1.326776 &   0.015155 \\
# std   &  7.458016e-07 &   0.078272 &   0.112963 &   0.006210 \\
# min   &  3.465570e-15 &   0.283333 &   1.187871 &   0.006574 \\
# 25\%   &  4.564384e-11 &   0.325000 &   1.261823 &   0.011037 \\
# 50\%   &  7.936234e-10 &   0.366667 &   1.282146 &   0.014813 \\
# 75\%   &  1.617660e-08 &   0.395833 &   1.408711 &   0.019402 \\
# max   &  2.347817e-06 &   0.533333 &   1.546409 &   0.023895 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 60.21923279762268 seconds. That means the whole run will probably take 602.1923279762268 more seconds and 10.03653879960378 more minutes
# overall, it took 571.4036200046539 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.495578   0.235000   1.724482   0.005227
# std     0.308359   0.197273   0.268396   0.000323
# min     0.013567   0.033333   1.243085   0.004738
# 25%     0.231932   0.137500   1.558129   0.004931
# 50%     0.547475   0.158333   1.779027   0.005331
# 75%     0.738241   0.300000   1.862811   0.005375
# max     0.941196   0.666667   2.076798   0.005750
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.495578 &   0.235000 &   1.724482 &   0.005227 \\
# std   &   0.308359 &   0.197273 &   0.268396 &   0.000323 \\
# min   &   0.013567 &   0.033333 &   1.243085 &   0.004738 \\
# 25\%   &   0.231932 &   0.137500 &   1.558129 &   0.004931 \\
# 50\%   &   0.547475 &   0.158333 &   1.779027 &   0.005331 \\
# 75\%   &   0.738241 &   0.300000 &   1.862811 &   0.005375 \\
# max   &   0.941196 &   0.666667 &   2.076798 &   0.005750 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 55.560839891433716 seconds. That means the whole run will probably take 555.6083989143372 more seconds and 9.260139981905619 more minutes
# overall, it took 572.2006728649139 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.555609   0.261667   1.624624   0.005767
# std     0.307620   0.064812   0.096930   0.000749
# min     0.139084   0.166667   1.477643   0.004891
# 25%     0.244996   0.204167   1.549249   0.005211
# 50%     0.640889   0.266667   1.624385   0.005568
# 75%     0.832248   0.312500   1.675414   0.006315
# max     0.903168   0.366667   1.785701   0.007042
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.555609 &   0.261667 &   1.624624 &   0.005767 \\
# std   &   0.307620 &   0.064812 &   0.096930 &   0.000749 \\
# min   &   0.139084 &   0.166667 &   1.477643 &   0.004891 \\
# 25\%   &   0.244996 &   0.204167 &   1.549249 &   0.005211 \\
# 50\%   &   0.640889 &   0.266667 &   1.624385 &   0.005568 \\
# 75\%   &   0.832248 &   0.312500 &   1.675414 &   0.006315 \\
# max   &   0.903168 &   0.366667 &   1.785701 &   0.007042 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 35.13448095321655 seconds. That means the whole run will probably take 351.3448095321655 more seconds and 5.855746825536092 more minutes
# overall, it took 369.9646089076996 seconds with 10 experiments
#              cobeau   coverage       nlpd       rsme
# count  1.000000e+01  10.000000  10.000000  10.000000
# mean   3.405424e-01   0.226667   0.172477   0.226544
# std    3.838686e-01   0.066295   0.333772   0.071323
# min    5.590077e-09   0.116667  -0.459326   0.138828
# 25%    2.741307e-02   0.191667   0.017474   0.156646
# 50%    1.763758e-01   0.233333   0.292347   0.226571
# 75%    7.214178e-01   0.250000   0.408682   0.283888
# max    9.294559e-01   0.350000   0.499344   0.333718
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  1.000000e+01 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &  3.405424e-01 &   0.226667 &   0.172477 &   0.226544 \\
# std   &  3.838686e-01 &   0.066295 &   0.333772 &   0.071323 \\
# min   &  5.590077e-09 &   0.116667 &  -0.459326 &   0.138828 \\
# 25\%   &  2.741307e-02 &   0.191667 &   0.017474 &   0.156646 \\
# 50\%   &  1.763758e-01 &   0.233333 &   0.292347 &   0.226571 \\
# 75\%   &  7.214178e-01 &   0.250000 &   0.408682 &   0.283888 \\
# max   &  9.294559e-01 &   0.350000 &   0.499344 &   0.333718 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment number 1 took 70.8147349357605 seconds. That means the whole run will probably take 708.147349357605 more seconds and 11.802455822626749 more minutes

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
