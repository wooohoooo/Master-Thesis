# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed}

datset_params = {'num_samples':num_epochs,'seed':seed,'n_samples':50}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:14:07.238398
# experiment number 1 took 16.064640045166016 seconds. That means the whole run will probably take 48.19392013549805 more seconds and 0.8032320022583008 more minutes.
# overall, it took 37.0946900844574 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   1.781240e-13  0.311111  1.169571  0.028878
# std    2.671222e-13  0.091793  0.049784  0.008405
# min    7.240647e-15  0.250000  1.114399  0.019208
# 25%    2.421255e-14  0.258333  1.148788  0.026105
# 50%    4.118445e-14  0.266667  1.183176  0.033002
# 75%    2.635657e-13  0.341667  1.197158  0.033713
# max    4.859470e-13  0.416667  1.211139  0.034425
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  1.781240e-13 &  0.311111 &  1.169571 &  0.028878 \\
# std   &  2.671222e-13 &  0.091793 &  0.049784 &  0.008405 \\
# min   &  7.240647e-15 &  0.250000 &  1.114399 &  0.019208 \\
# 25\%   &  2.421255e-14 &  0.258333 &  1.148788 &  0.026105 \\
# 50\%   &  4.118445e-14 &  0.266667 &  1.183176 &  0.033002 \\
# 75\%   &  2.635657e-13 &  0.341667 &  1.197158 &  0.033713 \\
# max   &  4.859470e-13 &  0.416667 &  1.211139 &  0.034425 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:14:47.747060
# experiment number 1 took 14.191351890563965 seconds. That means the whole run will probably take 42.574055671691895 more seconds and 0.7095675945281983 more minutes.
# overall, it took 42.65166902542114 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.412451  0.233333  1.716815  0.005180
# std    0.009504  0.142400  0.202997  0.000276
# min    0.402790  0.083333  1.488489  0.004987
# 25%    0.407782  0.166667  1.636775  0.005022
# 50%    0.412774  0.250000  1.785061  0.005056
# 75%    0.417282  0.308333  1.830978  0.005276
# max    0.421790  0.366667  1.876895  0.005496
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.412451 &  0.233333 &  1.716815 &  0.005180 \\
# std   &  0.009504 &  0.142400 &  0.202997 &  0.000276 \\
# min   &  0.402790 &  0.083333 &  1.488489 &  0.004987 \\
# 25\%   &  0.407782 &  0.166667 &  1.636775 &  0.005022 \\
# 50\%   &  0.412774 &  0.250000 &  1.785061 &  0.005056 \\
# 75\%   &  0.417282 &  0.308333 &  1.830978 &  0.005276 \\
# max   &  0.421790 &  0.366667 &  1.876895 &  0.005496 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:15:34.060700
# experiment number 1 took 15.274401903152466 seconds. That means the whole run will probably take 45.8232057094574 more seconds and 0.7637200951576233 more minutes.
# overall, it took 44.30978512763977 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.495523  0.966667  0.230732  0.005591
# std    0.325424  0.057735  0.364449  0.001305
# min    0.212584  0.900000  0.011912  0.004761
# 25%    0.317713  0.950000  0.020374  0.004839
# 50%    0.422842  1.000000  0.028836  0.004917
# 75%    0.636993  1.000000  0.340142  0.006006
# max    0.851143  1.000000  0.651448  0.007095
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.495523 &  0.966667 &  0.230732 &  0.005591 \\
# std   &  0.325424 &  0.057735 &  0.364449 &  0.001305 \\
# min   &  0.212584 &  0.900000 &  0.011912 &  0.004761 \\
# 25\%   &  0.317713 &  0.950000 &  0.020374 &  0.004839 \\
# 50\%   &  0.422842 &  1.000000 &  0.028836 &  0.004917 \\
# 75\%   &  0.636993 &  1.000000 &  0.340142 &  0.006006 \\
# max   &  0.851143 &  1.000000 &  0.651448 &  0.007095 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
num_meta_epochs = 3#10
num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 3]}

datset_params = {'num_samples':num_epochs,'seed':seed,'n_samples':50}

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
# Out:
# experiment started at 2018-08-07 12:16:21.865555
# experiment number 1 took 11.491530179977417 seconds. That means the whole run will probably take 34.47459053993225 more seconds and 0.5745765089988708 more minutes.

# %%
pd22 = repeat_experiment(BootstrapThroughTimeBobStrap, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params)
