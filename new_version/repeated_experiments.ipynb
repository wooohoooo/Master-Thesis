# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline
import tensorflow as tf

from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3, ForcedDiversityBootstrapThroughTime

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#10
num_epochs = 10#50#15#50
seed = 42
num_samples = 150
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]


model_params = {'num_epochs':num_epochs,'seed':seed,'initialisation_scheme':tf.keras.initializers.he_normal,'num_neurons':num_neurons}

dataset_params = {'seed':seed,'num_samples':num_samples}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:35:06.756664
# experiment number 1 took 16.366203784942627 seconds. That means the whole run will probably take 49.09861135482788 more seconds and 0.8183101892471314 more minutes.
# overall, it took 44.400352001190186 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.615093  0.466667  1.429947  0.005792
# std    0.259072  0.080123  0.056075  0.000574
# min    0.326944  0.377778  1.370320  0.005206
# 25%    0.508250  0.433333  1.404111  0.005512
# 50%    0.689557  0.488889  1.437903  0.005819
# 75%    0.759168  0.511111  1.459761  0.006086
# max    0.828778  0.533333  1.481619  0.006353
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.615093 &  0.466667 &  1.429947 &  0.005792 \\
# std   &  0.259072 &  0.080123 &  0.056075 &  0.000574 \\
# min   &  0.326944 &  0.377778 &  1.370320 &  0.005206 \\
# 25\%   &  0.508250 &  0.433333 &  1.404111 &  0.005512 \\
# 50\%   &  0.689557 &  0.488889 &  1.437903 &  0.005819 \\
# 75\%   &  0.759168 &  0.511111 &  1.459761 &  0.006086 \\
# max   &  0.828778 &  0.533333 &  1.481619 &  0.006353 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:35:54.968294
# experiment number 1 took 28.040712118148804 seconds. That means the whole run will probably take 84.12213635444641 more seconds and 1.4020356059074401 more minutes.
# overall, it took 78.98284006118774 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   3.206450e-01  0.755556 -0.015080  1.422536
# std    5.553734e-01  0.423390  1.447247  1.833002
# min    2.199248e-17  0.266667 -1.119885  0.005025
# 25%    3.314889e-15  0.633333 -0.834208  0.387553
# 50%    6.607785e-15  1.000000 -0.548532  0.770082
# 75%    4.809675e-01  1.000000  0.537322  2.131292
# max    9.619349e-01  1.000000  1.623177  3.492502
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  3.206450e-01 &  0.755556 & -0.015080 &  1.422536 \\
# std   &  5.553734e-01 &  0.423390 &  1.447247 &  1.833002 \\
# min   &  2.199248e-17 &  0.266667 & -1.119885 &  0.005025 \\
# 25\%   &  3.314889e-15 &  0.633333 & -0.834208 &  0.387553 \\
# 50\%   &  6.607785e-15 &  1.000000 & -0.548532 &  0.770082 \\
# 75\%   &  4.809675e-01 &  1.000000 &  0.537322 &  2.131292 \\
# max   &  9.619349e-01 &  1.000000 &  1.623177 &  3.492502 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:37:17.816438
# experiment number 1 took 26.68358087539673 seconds. That means the whole run will probably take 80.05074262619019 more seconds and 1.3341790437698364 more minutes.
# overall, it took 81.5070252418518 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.455036  0.785185  0.166290  0.005867
# std    0.312951  0.372070  1.188984  0.001280
# min    0.095637  0.355556 -0.658059  0.004894
# 25%    0.348887  0.677778 -0.515198  0.005142
# 50%    0.602137  1.000000 -0.372336  0.005390
# 75%    0.634735  1.000000  0.578464  0.006354
# max    0.667333  1.000000  1.529264  0.007317
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.455036 &  0.785185 &  0.166290 &  0.005867 \\
# std   &  0.312951 &  0.372070 &  1.188984 &  0.001280 \\
# min   &  0.095637 &  0.355556 & -0.658059 &  0.004894 \\
# 25\%   &  0.348887 &  0.677778 & -0.515198 &  0.005142 \\
# 50\%   &  0.602137 &  1.000000 & -0.372336 &  0.005390 \\
# 75\%   &  0.634735 &  1.000000 &  0.578464 &  0.006354 \\
# max   &  0.667333 &  1.000000 &  1.529264 &  0.007317 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 3#10
#num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':num_neurons_nonlinear}

dataset_params = {'num_samples':num_samples,'seed':seed}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:38:43.256782
# experiment number 1 took 26.146919012069702 seconds. That means the whole run will probably take 78.4407570362091 more seconds and 1.307345950603485 more minutes.
# overall, it took 66.1914439201355 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.003512  0.311111  0.747463  0.067339
# std    0.004399  0.044444  0.087986  0.014036
# min    0.000111  0.266667  0.666363  0.054612
# 25%    0.001028  0.288889  0.700689  0.059812
# 50%    0.001946  0.311111  0.735015  0.065012
# 75%    0.005213  0.333333  0.788012  0.073703
# max    0.008479  0.355556  0.841010  0.082394
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.003512 &  0.311111 &  0.747463 &  0.067339 \\
# std   &  0.004399 &  0.044444 &  0.087986 &  0.014036 \\
# min   &  0.000111 &  0.266667 &  0.666363 &  0.054612 \\
# 25\%   &  0.001028 &  0.288889 &  0.700689 &  0.059812 \\
# 50\%   &  0.001946 &  0.311111 &  0.735015 &  0.065012 \\
# 75\%   &  0.005213 &  0.333333 &  0.788012 &  0.073703 \\
# max   &  0.008479 &  0.355556 &  0.841010 &  0.082394 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:39:54.030820
# experiment number 1 took 34.43952989578247 seconds. That means the whole run will probably take 103.31858968734741 more seconds and 1.7219764947891236 more minutes.
# overall, it took 111.88216090202332 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   4.774651e-07  0.874074  0.203696  0.477735
# std    4.177702e-07  0.109620  0.783889  0.748539
# min    5.179881e-10  0.800000 -0.701188  0.039106
# 25%    3.269111e-07  0.811111 -0.032147  0.045581
# 50%    6.533042e-07  0.822222  0.636894  0.052057
# 75%    7.159386e-07  0.911111  0.656138  0.697049
# max    7.785731e-07  1.000000  0.675381  1.342041
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  4.774651e-07 &  0.874074 &  0.203696 &  0.477735 \\
# std   &  4.177702e-07 &  0.109620 &  0.783889 &  0.748539 \\
# min   &  5.179881e-10 &  0.800000 & -0.701188 &  0.039106 \\
# 25\%   &  3.269111e-07 &  0.811111 & -0.032147 &  0.045581 \\
# 50\%   &  6.533042e-07 &  0.822222 &  0.636894 &  0.052057 \\
# 75\%   &  7.159386e-07 &  0.911111 &  0.656138 &  0.697049 \\
# max   &  7.785731e-07 &  1.000000 &  0.675381 &  1.342041 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:41:50.342884
# experiment number 1 took 48.395573139190674 seconds. That means the whole run will probably take 145.18671941757202 more seconds and 2.419778656959534 more minutes.
# overall, it took 142.44506192207336 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.537276  0.881481  0.312909  0.013229
# std    0.228902  0.111849  0.710416  0.001009
# min    0.362018  0.777778 -0.503877  0.012083
# 25%    0.407788  0.822222  0.075786  0.012850
# 50%    0.453559  0.866667  0.655448  0.013617
# 75%    0.624905  0.933333  0.721301  0.013802
# max    0.796251  1.000000  0.787154  0.013987
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.537276 &  0.881481 &  0.312909 &  0.013229 \\
# std   &  0.228902 &  0.111849 &  0.710416 &  0.001009 \\
# min   &  0.362018 &  0.777778 & -0.503877 &  0.012083 \\
# 25\%   &  0.407788 &  0.822222 &  0.075786 &  0.012850 \\
# 50\%   &  0.453559 &  0.866667 &  0.655448 &  0.013617 \\
# 75\%   &  0.624905 &  0.933333 &  0.721301 &  0.013802 \\
# max   &  0.796251 &  1.000000 &  0.787154 &  0.013987 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(BootstrapEnsemble, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:44:17.644370
# experiment number 1 took 27.492178916931152 seconds. That means the whole run will probably take 82.47653675079346 more seconds and 1.3746089458465576 more minutes.
# overall, it took 80.86176586151123 seconds with 3 experiments
#          cobeau  coverage      nlpd       rsme
# count  3.000000  3.000000  3.000000   3.000000
# mean   0.000223  0.540741 -5.657819  51.312387
# std    0.000120  0.025660  0.552008   5.890984
# min    0.000090  0.511111 -6.261225  47.154871
# 25%    0.000174  0.533333 -5.897607  47.941701
# 50%    0.000258  0.555556 -5.533990  48.728531
# 75%    0.000290  0.555556 -5.356117  53.391146
# max    0.000322  0.555556 -5.178243  58.053761
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &   3.000000 \\
# mean  &  0.000223 &  0.540741 & -5.657819 &  51.312387 \\
# std   &  0.000120 &  0.025660 &  0.552008 &   5.890984 \\
# min   &  0.000090 &  0.511111 & -6.261225 &  47.154871 \\
# 25\%   &  0.000174 &  0.533333 & -5.897607 &  47.941701 \\
# 50\%   &  0.000258 &  0.555556 & -5.533990 &  48.728531 \\
# 75\%   &  0.000290 &  0.555556 & -5.356117 &  53.391146 \\
# max   &  0.000322 &  0.555556 & -5.178243 &  58.053761 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:45:43.221405
# experiment number 1 took 43.3918342590332 seconds. That means the whole run will probably take 130.1755027770996 more seconds and 2.16959171295166 more minutes.
# overall, it took 129.45956468582153 seconds with 3 experiments
#          cobeau  coverage      nlpd       rsme
# count  3.000000  3.000000  3.000000   3.000000
# mean   0.007708  0.748148 -2.336386  16.019622
# std    0.008787  0.055925  0.266010   3.804918
# min    0.002598  0.688889 -2.628723  12.657178
# 25%    0.002635  0.722222 -2.450291  13.954483
# 50%    0.002672  0.755556 -2.271860  15.251788
# 75%    0.010263  0.777778 -2.190217  17.700844
# max    0.017855  0.800000 -2.108575  20.149901
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &   3.000000 \\
# mean  &  0.007708 &  0.748148 & -2.336386 &  16.019622 \\
# std   &  0.008787 &  0.055925 &  0.266010 &   3.804918 \\
# min   &  0.002598 &  0.688889 & -2.628723 &  12.657178 \\
# 25\%   &  0.002635 &  0.722222 & -2.450291 &  13.954483 \\
# 50\%   &  0.002672 &  0.755556 & -2.271860 &  15.251788 \\
# 75\%   &  0.010263 &  0.777778 & -2.190217 &  17.700844 \\
# max   &  0.017855 &  0.800000 & -2.108575 &  20.149901 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:47:57.713488
# experiment number 1 took 50.19078183174133 seconds. That means the whole run will probably take 150.572345495224 more seconds and 2.5095390915870666 more minutes.
# overall, it took 147.0171036720276 seconds with 3 experiments
#          cobeau  coverage      nlpd       rsme
# count  3.000000  3.000000  3.000000   3.000000
# mean   0.756221  0.807407 -2.592577  10.167673
# std    0.182777  0.071434  0.545154   1.552565
# min    0.551405  0.755556 -2.917550   8.629349
# 25%    0.682964  0.766667 -2.907266   9.384461
# 50%    0.814523  0.777778 -2.896981  10.139573
# 75%    0.858629  0.833333 -2.430090  10.936836
# max    0.902735  0.888889 -1.963199  11.734098
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &   3.000000 \\
# mean  &  0.756221 &  0.807407 & -2.592577 &  10.167673 \\
# std   &  0.182777 &  0.071434 &  0.545154 &   1.552565 \\
# min   &  0.551405 &  0.755556 & -2.917550 &   8.629349 \\
# 25\%   &  0.682964 &  0.766667 & -2.907266 &   9.384461 \\
# 50\%   &  0.814523 &  0.777778 & -2.896981 &  10.139573 \\
# 75\%   &  0.858629 &  0.833333 & -2.430090 &  10.936836 \\
# max   &  0.902735 &  0.888889 & -1.963199 &  11.734098 \\
# \bottomrule
# \end{tabular}
