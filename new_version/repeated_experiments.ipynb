# %%
import importlib

from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)


# %matplotlib inline
import tensorflow as tf

from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3, ForcedDiversityBootstrapThroughTime
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 10#10
num_epochs = 50#15#50
seed = 42
num_samples = 150

model_params = {'num_epochs':num_epochs,'seed':seed,'initialisation_scheme':tf.keras.initializers.he_normal}

dataset_params = {'seed':seed,'num_samples':num_samples}

# %%
pd = repeat_experiment(BootstrapEnsemble, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:41:18.348314
# experiment number 1 took 90.55178380012512 seconds. That means the whole run will probably take 905.5178380012512 more seconds and 15.091963966687521 more minutes.
# overall, it took 846.5411899089813 seconds with 10 experiments
#              cobeau   coverage       nlpd       rsme
# count  1.000000e+01  10.000000  10.000000  10.000000
# mean   6.884508e-02   0.555556   1.158333   0.012409
# std    1.215266e-01   0.106831   0.160884   0.004719
# min    6.140093e-08   0.422222   0.973878   0.005616
# 25%    2.375454e-03   0.488889   1.035835   0.010499
# 50%    1.618132e-02   0.533333   1.130559   0.012423
# 75%    7.616850e-02   0.650000   1.229040   0.013955
# max    3.859350e-01   0.711111   1.499572   0.020096
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  1.000000e+01 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &  6.884508e-02 &   0.555556 &   1.158333 &   0.012409 \\
# std   &  1.215266e-01 &   0.106831 &   0.160884 &   0.004719 \\
# min   &  6.140093e-08 &   0.422222 &   0.973878 &   0.005616 \\
# 25\%   &  2.375454e-03 &   0.488889 &   1.035835 &   0.010499 \\
# 50\%   &  1.618132e-02 &   0.533333 &   1.130559 &   0.012423 \\
# 75\%   &  7.616850e-02 &   0.650000 &   1.229040 &   0.013955 \\
# max   &  3.859350e-01 &   0.711111 &   1.499572 &   0.020096 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 19:55:28.734806
# experiment number 1 took 108.64112305641174 seconds. That means the whole run will probably take 1086.4112305641174 more seconds and 18.10685384273529 more minutes.
# overall, it took 1039.9753980636597 seconds with 10 experiments
#              cobeau   coverage       nlpd       rsme
# count  1.000000e+01  10.000000  10.000000  10.000000
# mean   1.427042e-01   0.755556   0.784067   0.049367
# std    2.677040e-01   0.359240   0.736390   0.052297
# min    1.230946e-16   0.044444  -0.033869   0.004788
# 25%    2.482119e-05   0.744444   0.188034   0.008245
# 50%    4.447917e-03   0.922222   0.588325   0.032958
# 75%    9.305468e-02   1.000000   1.058528   0.075785
# max    7.369096e-01   1.000000   2.051928   0.158333
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  1.000000e+01 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &  1.427042e-01 &   0.755556 &   0.784067 &   0.049367 \\
# std   &  2.677040e-01 &   0.359240 &   0.736390 &   0.052297 \\
# min   &  1.230946e-16 &   0.044444 &  -0.033869 &   0.004788 \\
# 25\%   &  2.482119e-05 &   0.744444 &   0.188034 &   0.008245 \\
# 50\%   &  4.447917e-03 &   0.922222 &   0.588325 &   0.032958 \\
# 75\%   &  9.305468e-02 &   1.000000 &   1.058528 &   0.075785 \\
# max   &  7.369096e-01 &   1.000000 &   2.051928 &   0.158333 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 20:12:52.465115
# experiment number 1 took 103.845134973526 seconds. That means the whole run will probably take 1038.45134973526 more seconds and 17.307522495587666 more minutes.
# overall, it took 1035.5688650608063 seconds with 10 experiments
#           cobeau   coverage       nlpd       rsme
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.490441   0.926667   0.516068   0.004976
# std     0.272388   0.088301   0.424621   0.000216
# min     0.096173   0.800000   0.010635   0.004755
# 25%     0.359336   0.844444   0.115279   0.004807
# 50%     0.490074   0.966667   0.512307   0.004880
# 75%     0.553002   1.000000   0.913488   0.005176
# max     0.950682   1.000000   1.118603   0.005334
# \begin{tabular}{lrrrr}
# \toprule
# {} &     cobeau &   coverage &       nlpd &       rsme \\
# \midrule
# count &  10.000000 &  10.000000 &  10.000000 &  10.000000 \\
# mean  &   0.490441 &   0.926667 &   0.516068 &   0.004976 \\
# std   &   0.272388 &   0.088301 &   0.424621 &   0.000216 \\
# min   &   0.096173 &   0.800000 &   0.010635 &   0.004755 \\
# 25\%   &   0.359336 &   0.844444 &   0.115279 &   0.004807 \\
# 50\%   &   0.490074 &   0.966667 &   0.512307 &   0.004880 \\
# 75\%   &   0.553002 &   1.000000 &   0.913488 &   0.005176 \\
# max   &   0.950682 &   1.000000 &   1.118603 &   0.005334 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
num_meta_epochs = 3#10
#num_epochs = 5#50
seed = 42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 3]}

dataset_params = {'num_samples':num_samples,'seed':seed}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(BootstrapEnsemble, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 20:30:11.801867
# experiment number 1 took 71.59547090530396 seconds. That means the whole run will probably take 214.78641271591187 more seconds and 3.5797735452651978 more minutes.
# overall, it took 213.79745411872864 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   6.383949e-07  0.355556  0.521535  0.160957
# std    1.090580e-06  0.096864  0.070557  0.032819
# min    9.975406e-10  0.288889  0.448576  0.126685
# 25%    8.764512e-09  0.300000  0.487594  0.145387
# 50%    1.653148e-08  0.311111  0.526612  0.164088
# 75%    9.570936e-07  0.388889  0.558014  0.178094
# max    1.897656e-06  0.466667  0.589417  0.192099
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  6.383949e-07 &  0.355556 &  0.521535 &  0.160957 \\
# std   &  1.090580e-06 &  0.096864 &  0.070557 &  0.032819 \\
# min   &  9.975406e-10 &  0.288889 &  0.448576 &  0.126685 \\
# 25\%   &  8.764512e-09 &  0.300000 &  0.487594 &  0.145387 \\
# 50\%   &  1.653148e-08 &  0.311111 &  0.526612 &  0.164088 \\
# 75\%   &  9.570936e-07 &  0.388889 &  0.558014 &  0.178094 \\
# max   &  1.897656e-06 &  0.466667 &  0.589417 &  0.192099 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 20:33:49.908924
# experiment number 1 took 103.0597620010376 seconds. That means the whole run will probably take 309.1792860031128 more seconds and 5.15298810005188 more minutes.
# overall, it took 323.72191405296326 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.068470  0.614815  0.827280  0.054950
# std    0.117949  0.368067  0.688175  0.054216
# min    0.000009  0.266667  0.097943  0.012942
# 25%    0.000373  0.422222  0.508349  0.024349
# 50%    0.000737  0.577778  0.918754  0.035756
# 75%    0.102701  0.788889  1.191949  0.075954
# max    0.204666  1.000000  1.465143  0.116152
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.068470 &  0.614815 &  0.827280 &  0.054950 \\
# std   &  0.117949 &  0.368067 &  0.688175 &  0.054216 \\
# min   &  0.000009 &  0.266667 &  0.097943 &  0.012942 \\
# 25\%   &  0.000373 &  0.422222 &  0.508349 &  0.024349 \\
# 50\%   &  0.000737 &  0.577778 &  0.918754 &  0.035756 \\
# 75\%   &  0.102701 &  0.788889 &  1.191949 &  0.075954 \\
# max   &  0.204666 &  1.000000 &  1.465143 &  0.116152 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 20:39:18.586756
# experiment number 1 took 120.27597117424011 seconds. That means the whole run will probably take 360.82791352272034 more seconds and 6.013798558712006 more minutes.
# overall, it took 364.5209939479828 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.702620  0.577778  0.850535  0.015047
# std    0.272365  0.373836  0.623045  0.000707
# min    0.398636  0.288889  0.132370  0.014245
# 25%    0.591702  0.366667  0.652525  0.014780
# 50%    0.784767  0.444444  1.172681  0.015315
# 75%    0.854612  0.722222  1.209618  0.015448
# max    0.924457  1.000000  1.246555  0.015581
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.702620 &  0.577778 &  0.850535 &  0.015047 \\
# std   &  0.272365 &  0.373836 &  0.623045 &  0.000707 \\
# min   &  0.398636 &  0.288889 &  0.132370 &  0.014245 \\
# 25\%   &  0.591702 &  0.366667 &  0.652525 &  0.014780 \\
# 50\%   &  0.784767 &  0.444444 &  1.172681 &  0.015315 \\
# 75\%   &  0.854612 &  0.722222 &  1.209618 &  0.015448 \\
# max   &  0.924457 &  1.000000 &  1.246555 &  0.015581 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(BootstrapEnsemble, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 20:45:27.460796
# experiment number 1 took 94.69139194488525 seconds. That means the whole run will probably take 284.07417583465576 more seconds and 4.7345695972442625 more minutes.
# overall, it took 301.8347260951996 seconds with 3 experiments
#              cobeau  coverage       nlpd        rsme
# count  3.000000e+00  3.000000   3.000000    3.000000
# mean   3.152553e-04  0.437037 -10.159001  140.314853
# std    5.459658e-04  0.071434   4.094502   29.102392
# min    1.358678e-12  0.355556 -14.130602  106.710412
# 25%    4.181341e-08  0.411111 -12.262614  131.877055
# 50%    8.362545e-08  0.466667 -10.394626  157.043697
# 75%    4.728830e-04  0.477778  -8.173200  157.117073
# max    9.456823e-04  0.488889  -5.951775  157.190448
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &       nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &   3.000000 &    3.000000 \\
# mean  &  3.152553e-04 &  0.437037 & -10.159001 &  140.314853 \\
# std   &  5.459658e-04 &  0.071434 &   4.094502 &   29.102392 \\
# min   &  1.358678e-12 &  0.355556 & -14.130602 &  106.710412 \\
# 25\%   &  4.181341e-08 &  0.411111 & -12.262614 &  131.877055 \\
# 50\%   &  8.362545e-08 &  0.466667 & -10.394626 &  157.043697 \\
# 75\%   &  4.728830e-04 &  0.477778 &  -8.173200 &  157.117073 \\
# max   &  9.456823e-04 &  0.488889 &  -5.951775 &  157.190448 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(ForcedDiversityBootstrapThroughTime, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-07 20:50:34.108211
# experiment number 1 took 158.41077089309692 seconds. That means the whole run will probably take 475.23231267929077 more seconds and 7.920538544654846 more minutes.

# %%
pd333 = repeat_experiment(ForcedDiversityBootstrapThroughTime3, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,
                        dataset_params=dataset_params)
