# %% [markdown]
# # basic Network

# %%
#imports
import tensorflow as tf
import numpy as np
#tf.reset_default_graph()
import matplotlib.pyplot as plt
#get_ipython().magic('matplotlib inline')
from os import system
from helpers import lazy_property
#from datasets import unison_shuffled_copies

#from global_vars import ADVERSARIAL


import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 5]

from sklearn.model_selection import train_test_split

from sklearn.datasets import make_regression


n_samples = 200
seed = 50 #50 is cool

num_epochs = 10
num_meta_epochs = 15 #also numplots
learning_rate = 1/num_epochs


import time



from base import EnsembleNetwork

# %%
import dataset_creation 
import importlib
importlib.reload(dataset_creation)
# %matplotlib inline

# %%
ld = dataset_creation.LinearDataset()
ld.plot_dataset()

# %%
nd = dataset_creation.NonlinearDataset()
nd.plot_dataset()

# %% [markdown]
# # Vanilla Network

# %%
import visualisation 
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %% [markdown]
# ## Linear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.LinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 10.986144781112671s'

# %% [markdown]
# ## Nonlinear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.NonlinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 11.403639078140259s'

# %% [markdown]
# # dropout Network

# %%
from networks import DropoutNetwork

# %% [markdown]
# ## Linear

# %%
import visualisation
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.LinearDataset)
# Out:
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:21: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# [(-0.2881396787152303, 0.025578554888769273), (-0.2881396787152303, 0.025578554888769273), (0.2252639340763998, 0.08354098778969553), (0.10999740916292917, 0.40278604263943507)]
# 'this run of 10 epochs and 3 metaepochs took 3.293045997619629s'

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.NonlinearDataset)
# Out:
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:21: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# [(0.23873285450328854, 0.06621329575360979), (0.23873285450328854, 0.06621329575360979), (-0.09356535153030167, 0.4770406545065089), (0.3289431251542545, 0.010281009606503563)]
# 'this run of 10 epochs and 3 metaepochs took 4.764603853225708s'

# %% [markdown]
# # NLPD Network

# %% [markdown]
# ## linear

# %%
from networks import NlpdNetwork

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.LinearDataset)
# Out:
# [(0.9802169339989869, 1.6746424295434033e-42), (0.9802169339989869, 1.6746424295434033e-42), (-0.030684666907000616, 0.8159654166503416), (0.12444782861221393, 0.34344500296465963)]
# 'this run of 10 epochs and 3 metaepochs took 3.3561549186706543s'

# %% [markdown]
# ## Nonlinear

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.NonlinearDataset)
# Out:
# [(0.9874364712212779, 3.535100731176724e-48), (0.9874364712212779, 3.535100731176724e-48), (-0.07244429230738736, 0.5822711571919648), (-0.05920116232027775, 0.6532021385710175)]
# 'this run of 10 epochs and 3 metaepochs took 5.001662015914917s'

# %% [markdown]
# # LR

# %% [markdown]
# ## Linear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.LinearDataset)
# Out:
# [(-0.04629578193217454, 0.7254005154000824), (-0.04629578193217454, 0.7254005154000824), (-0.09863539589874416, 0.4533838648309285), (-0.04603353076074993, 0.7268952231803387)]
# 'this run of 10 epochs and 3 metaepochs took 4.48308801651001s'

# %% [markdown]
# ## Nonlinear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.NonlinearDataset)
# Out:
# [(0.4409084314953296, 0.00042201951459236767), (0.4409084314953296, 0.00042201951459236767), (0.23049197889690043, 0.07643325655510569), (0.5218088628381429, 1.905999906232558e-05)]
# 'this run of 10 epochs and 3 metaepochs took 4.9648120403289795s'
