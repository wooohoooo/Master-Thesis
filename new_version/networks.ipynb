# %% [markdown]
# # basic Network

# %%
#imports
import tensorflow as tf
import numpy as np
#tf.reset_default_graph()
import matplotlib.pyplot as plt
#get_ipython().magic('matplotlib inline')
from os import system
from helpers import lazy_property
#from datasets import unison_shuffled_copies

#from global_vars import ADVERSARIAL


import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 5]

from sklearn.model_selection import train_test_split

from sklearn.datasets import make_regression


n_samples = 200
seed = 50 #50 is cool

num_epochs = 100
num_meta_epochs = 15 #also numplots
learning_rate = 1/num_epochs


import time



from base import EnsembleNetwork

# %%
import dataset_creation 
import importlib
importlib.reload(dataset_creation)
# %matplotlib inline

# %%
ld = dataset_creation.LinearDataset()
ld.plot_dataset()

# %%
nd = dataset_creation.NonlinearDataset()
nd.plot_dataset()

# %% [markdown]
# # Vanilla Network

# %%
import visualisation 
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %% [markdown]
# ## Linear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.LinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 10.076949834823608s'

# %% [markdown]
# ## Nonlinear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.NonlinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 10.033199071884155s'

# %% [markdown]
# # dropout Network

# %%
from networks import DropoutNetwork

# %% [markdown]
# ## Linear

# %%
import visualisation
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.LinearDataset)
# Out:
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:21: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# [(0.6508825906392011, 1.8006738645813848e-08), (0.6508825906392011, 1.8006738645813848e-08), (0.4010503384365667, 0.0014951326432342644), (0.36635145407829783, 0.003991023313973078)]
# 'this run of 10 epochs and 3 metaepochs took 2.941901922225952s'

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.NonlinearDataset)
# Out:
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:21: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# [(-0.08988510516939079, 0.4946161800909151), (-0.08988510516939079, 0.4946161800909151), (-0.2984138815703465, 0.020562627064481614), (-0.1049683683317774, 0.4247625117078805)]
# 'this run of 10 epochs and 3 metaepochs took 3.2273318767547607s'

# %% [markdown]
# # NLPD Network

# %% [markdown]
# ## linear

# %%
from networks import NlpdNetwork

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.LinearDataset)
# Out:
# [(-0.11073620119573305, 0.3996144836949448), (-0.11073620119573305, 0.3996144836949448), (0.11828661885180831, 0.36804799284630574), (-0.3358610427558013, 0.008702394055232274)]
# 'this run of 10 epochs and 3 metaepochs took 4.060328006744385s'

# %% [markdown]
# ## Nonlinear

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.NonlinearDataset)
# Out:
# [(-0.05469180414184758, 0.6781125740867726), (-0.05469180414184758, 0.6781125740867726), (1.9525740345621372e-16, 1.0), (1.9525740345621372e-16, 1.0)]
# 'this run of 10 epochs and 3 metaepochs took 4.0940940380096436s'

# %% [markdown]
# # LR

# %% [markdown]
# ## Linear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.LinearDataset)
# Out:
# [(0.1311392059817637, 0.31791433038091543), (0.1311392059817637, 0.31791433038091543), (-0.13891547969890852, 0.28980842468628204), (0.4280288429243121, 0.0006460015050882067)]
# 'this run of 10 epochs and 3 metaepochs took 3.5548110008239746s'

# %% [markdown]
# ## Nonlinear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.NonlinearDataset)
# Out:
# [(0.043030591708373214, 0.744081490232994), (0.043030591708373214, 0.744081490232994), (0.1870374639298342, 0.15243825015006107), (0.5967042329090048, 4.863379302114317e-07)]
# 'this run of 10 epochs and 3 metaepochs took 4.270618915557861s'
