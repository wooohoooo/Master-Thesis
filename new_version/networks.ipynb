# %% [markdown]
# # basic Network

# %%
#imports
import tensorflow as tf
import numpy as np
#tf.reset_default_graph()
import matplotlib.pyplot as plt
#get_ipython().magic('matplotlib inline')
from os import system
from helpers import lazy_property
#from datasets import unison_shuffled_copies

#from global_vars import ADVERSARIAL


import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 5]

from sklearn.model_selection import train_test_split

from sklearn.datasets import make_regression


n_samples = 200
seed = 50 #50 is cool

num_epochs = 10
num_meta_epochs = 15 #also numplots
learning_rate = 1/num_epochs


import time



from base import EnsembleNetwork

# %%
import dataset_creation 
import importlib
importlib.reload(dataset_creation)
# %matplotlib inline

# %%
ld = dataset_creation.LinearDataset()
ld.plot_dataset()

# %%
nd = dataset_creation.NonlinearDataset()
nd.plot_dataset()

# %% [markdown]
# # Vanilla Network

# %%
import visualisation 
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %% [markdown]
# ## Linear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.LinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 14.214479923248291s'

# %% [markdown]
# ## Nonlinear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.NonlinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 11.545863151550293s'

# %% [markdown]
# # dropout Network

# %%
from networks import DropoutNetwork

# %% [markdown]
# ## Linear

# %%
import visualisation
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.LinearDataset)
# Out:
# [(-0.2742078304427163, 0.033993696341857824), (-0.2742078304427163, 0.033993696341857824), (0.3809833841524777, 0.002671968701077646), (0.17370775442763386, 0.1843941477114884)]
# 'this run of 10 epochs and 3 metaepochs took 3.9537060260772705s'

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.NonlinearDataset)
# Out:
# [(0.1271580424451076, 0.33295458167585656), (0.1271580424451076, 0.33295458167585656), (-0.2911587780057535, 0.02400767050579603), (-0.057511162151271535, 0.6624957581908697)]
# 'this run of 10 epochs and 3 metaepochs took 4.053326845169067s'

# %% [markdown]
# # NLPD Network

# %% [markdown]
# ## linear

# %%
from networks import NlpdNetwork

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.LinearDataset)
# Out:
# [(0.9743389732901817, 2.9203528697443925e-39), (0.9743389732901817, 2.9203528697443925e-39), (-0.6058631332095864, 2.9078797170014623e-07), (0.1212451682713645, 0.3561034078771733)]
# 'this run of 10 epochs and 3 metaepochs took 4.853562831878662s'

# %% [markdown]
# ## Nonlinear

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.NonlinearDataset)
# Out:
# [(0.9916323460451226, 2.8474396064197776e-53), (0.9916323460451226, 2.8474396064197776e-53), (-0.05363237590611403, 0.6840163230331444), (-0.09572540626565003, 0.46688225509776304)]
# 'this run of 10 epochs and 3 metaepochs took 4.330770969390869s'

# %% [markdown]
# # LR

# %% [markdown]
# ## Linear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.LinearDataset)
# Out:
# [(0.44099992486020334, 0.0004207196321897066), (0.44099992486020334, 0.0004207196321897066), (0.33913340278700266, 0.008032243154340568), (0.40790591213257876, 0.0012159259606258966)]
# 'this run of 10 epochs and 3 metaepochs took 3.459484100341797s'

# %% [markdown]
# ## Nonlinear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.NonlinearDataset)
# Out:
# [(0.5407591386326747, 8.180205496101927e-06), (0.5407591386326747, 8.180205496101927e-06), (0.6588812065478282, 1.0458479384220558e-08), (0.5291371682560543, 1.3825319970174124e-05)]
# 'this run of 10 epochs and 3 metaepochs took 3.9521899223327637s'
