# %% [markdown]
# # basic Network

# %%
#imports
import tensorflow as tf
import numpy as np
#tf.reset_default_graph()
import matplotlib.pyplot as plt
#get_ipython().magic('matplotlib inline')
from os import system
from helpers import lazy_property
#from datasets import unison_shuffled_copies

#from global_vars import ADVERSARIAL


import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [15, 5]

from sklearn.model_selection import train_test_split

from sklearn.datasets import make_regression


n_samples = 200
seed = 42 #50 is cool

num_epochs = 500#100
num_meta_epochs = 15 #also numplots
learning_rate = 1/num_epochs


import time



from base import EnsembleNetwork

# %%
import dataset_creation 
import importlib
importlib.reload(dataset_creation)
# %matplotlib inline

# %%
ld = dataset_creation.LinearDataset()
ld.plot_dataset()

# %%
nd = dataset_creation.NonlinearDataset()
nd.plot_dataset()

# %% [markdown]
# # Vanilla Network

# %%
import visualisation 
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %% [markdown]
# ## Linear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.LinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 12.011584043502808s'

# %% [markdown]
# ## Nonlinear

# %%
net = EnsembleNetwork(num_epochs=25)#num_epochs = num_epochs,learning_rate=learning_rate,adversarial=False,num_neurons=num_neurons)
visualisation.visualise(net,dataset_creation.NonlinearDataset)
# Out:
# 'this run of 25 epochs and 3 metaepochs took 11.888118982315063s'

# %% [markdown]
# # dropout Network

# %%
from networks import DropoutNetwork

# %% [markdown]
# ## Linear

# %%
import visualisation
importlib.reload(visualisation)
# Out:
# <module 'visualisation' from '/Users/thomas/Documents/Master-Thesis/new_version/visualisation.py'>

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.LinearDataset)
# Out:
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:21: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# [(0.16433636383903613, 0.20958145380234625), (0.16433636383903613, 0.20958145380234625), (0.2455379740949358, 0.05862697254798755), (0.2270400847009661, 0.0810700166222649)]
# 'this run of 10 epochs and 3 metaepochs took 3.917304039001465s'

# %%
dropnet = DropoutNetwork()

visualisation.visualise_uncertainty(dropnet,dataset_creation.NonlinearDataset)
# Out:
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:21: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# [(-0.025831298864353668, 0.844679077104774), (-0.025831298864353668, 0.844679077104774), (-0.3514257824473411, 0.0059000337097321965), (-0.40973987259493916, 0.0011496608927110978)]
# 'this run of 10 epochs and 3 metaepochs took 3.798933982849121s'

# %% [markdown]
# # NLPD Network

# %% [markdown]
# ## linear

# %%
from networks import NlpdNetwork

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.LinearDataset)
# Out:
# [(-0.14831490598017905, 0.25807883636825135), (-0.14831490598017905, 0.25807883636825135), (0.5344267729411277, 1.0914136427457458e-05), (0.3129803845401274, 0.01489790457101151)]
# 'this run of 10 epochs and 3 metaepochs took 3.8754031658172607s'

# %% [markdown]
# ## Nonlinear

# %%
nlpd = NlpdNetwork()
visualisation.visualise_uncertainty(nlpd,dataset_creation.NonlinearDataset)
# Out:
# [(0.07226353626531354, 0.5832153219989591), (0.07226353626531354, 0.5832153219989591), (-0.019969483962478152, 0.879625409032296), (-0.04362612543479426, 0.7406629729645873)]
# 'this run of 10 epochs and 3 metaepochs took 4.539444923400879s'

# %% [markdown]
# # LR

# %% [markdown]
# ## Linear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.LinearDataset)
# Out:
# [(0.4650823140344641, 0.00018111386387922353), (0.4650823140344641, 0.00018111386387922353), (0.28869866283950446, 0.025281345380406297), (-0.03691971320580862, 0.7794326319712255)]
# 'this run of 10 epochs and 3 metaepochs took 6.923163890838623s'

# %% [markdown]
# ## Nonlinear

# %%
from networks import LrNetwork
lr = LrNetwork()
visualisation.visualise_uncertainty(lr,dataset_creation.NonlinearDataset)
# Out:
# [(0.18087918452080495, 0.16664982327487202), (0.18087918452080495, 0.16664982327487202), (0.5491975892082533, 5.519449014955015e-06), (0.5485449108749688, 5.692167259353062e-06)]
# 'this run of 10 epochs and 3 metaepochs took 6.709769010543823s'
