# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3# 100#100#10
num_epochs = 10#15#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 200
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons,
               'l2':True}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:09:32.633804
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 12.418370962142944 seconds. That means the whole run will probably take 37.25511288642883 more seconds and 0.6209185481071472 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 44.3792359828949 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.185263  0.755556  0.891718  0.018194
# std    0.241836  0.110972  0.031658  0.007988
# min    0.001367  0.683333  0.868166  0.008982
# 25%    0.048293  0.691667  0.873724  0.015690
# 50%    0.095218  0.700000  0.879282  0.022398
# 75%    0.277211  0.791667  0.903494  0.022800
# max    0.459204  0.883333  0.927706  0.023202
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.185263 &  0.755556 &  0.891718 &  0.018194 \\
# std   &  0.241836 &  0.110972 &  0.031658 &  0.007988 \\
# min   &  0.001367 &  0.683333 &  0.868166 &  0.008982 \\
# 25\%   &  0.048293 &  0.691667 &  0.873724 &  0.015690 \\
# 50\%   &  0.095218 &  0.700000 &  0.879282 &  0.022398 \\
# 75\%   &  0.277211 &  0.791667 &  0.903494 &  0.022800 \\
# max   &  0.459204 &  0.883333 &  0.927706 &  0.023202 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:10:29.306923
# experiment number 1 took 11.329601049423218 seconds. That means the whole run will probably take 33.98880314826965 more seconds and 0.5664800524711608 more minutes.
# overall, it took 44.787960052490234 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.198440  0.072222  1.595086  0.015368
# std    0.217044  0.034694  0.474779  0.012708
# min    0.000006  0.033333  1.087470  0.006395
# 25%    0.082545  0.058333  1.378517  0.008097
# 50%    0.165083  0.083333  1.669563  0.009800
# 75%    0.297658  0.091667  1.848894  0.019855
# max    0.430232  0.100000  2.028225  0.029910
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.198440 &  0.072222 &  1.595086 &  0.015368 \\
# std   &  0.217044 &  0.034694 &  0.474779 &  0.012708 \\
# min   &  0.000006 &  0.033333 &  1.087470 &  0.006395 \\
# 25\%   &  0.082545 &  0.058333 &  1.378517 &  0.008097 \\
# 50\%   &  0.165083 &  0.083333 &  1.669563 &  0.009800 \\
# 75\%   &  0.297658 &  0.091667 &  1.848894 &  0.019855 \\
# max   &  0.430232 &  0.100000 &  2.028225 &  0.029910 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:11:30.492191
# experiment number 1 took 18.756387948989868 seconds. That means the whole run will probably take 56.269163846969604 more seconds and 0.9378193974494934 more minutes.
# overall, it took 53.337454080581665 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.298356  0.088889  1.949315  0.007230
# std    0.208728  0.009623  0.095915  0.001795
# min    0.103948  0.083333  1.854439  0.005908
# 25%    0.188067  0.083333  1.900854  0.006208
# 50%    0.272186  0.083333  1.947270  0.006507
# 75%    0.395561  0.091667  1.996753  0.007890
# max    0.518936  0.100000  2.046236  0.009273
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.298356 &  0.088889 &  1.949315 &  0.007230 \\
# std   &  0.208728 &  0.009623 &  0.095915 &  0.001795 \\
# min   &  0.103948 &  0.083333 &  1.854439 &  0.005908 \\
# 25\%   &  0.188067 &  0.083333 &  1.900854 &  0.006208 \\
# 50\%   &  0.272186 &  0.083333 &  1.947270 &  0.006507 \\
# 75\%   &  0.395561 &  0.091667 &  1.996753 &  0.007890 \\
# max   &  0.518936 &  0.100000 &  2.046236 &  0.009273 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed,
               'l2':True}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:12:34.637362
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 18.794070959091187 seconds. That means the whole run will probably take 56.38221287727356 more seconds and 0.9397035479545593 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 48.20073485374451 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.308940  0.144444 -0.032511  0.296572
# std    0.508477  0.058531  0.350241  0.104316
# min    0.008215  0.083333 -0.426650  0.216106
# 25%    0.015400  0.116667 -0.170288  0.237643
# 50%    0.022584  0.150000  0.086074  0.259180
# 75%    0.459302  0.175000  0.164558  0.336806
# max    0.896020  0.200000  0.243042  0.414431
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.308940 &  0.144444 & -0.032511 &  0.296572 \\
# std   &  0.508477 &  0.058531 &  0.350241 &  0.104316 \\
# min   &  0.008215 &  0.083333 & -0.426650 &  0.216106 \\
# 25\%   &  0.015400 &  0.116667 & -0.170288 &  0.237643 \\
# 50\%   &  0.022584 &  0.150000 &  0.086074 &  0.259180 \\
# 75\%   &  0.459302 &  0.175000 &  0.164558 &  0.336806 \\
# max   &  0.896020 &  0.200000 &  0.243042 &  0.414431 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:13:30.171583
# experiment number 1 took 12.555231094360352 seconds. That means the whole run will probably take 37.665693283081055 more seconds and 0.6277615547180175 more minutes.
# overall, it took 39.403438091278076 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   1.659281e-01  0.405556  0.501261  0.720102
# std    1.808439e-01  0.242861  0.667830  1.129309
# min    5.378985e-45  0.133333 -0.190469  0.035747
# 25%    6.954754e-02  0.308333  0.180739  0.068367
# 50%    1.390951e-01  0.483333  0.551948  0.100987
# 75%    2.488922e-01  0.541667  0.847126  1.062279
# max    3.586893e-01  0.600000  1.142304  2.023571
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  1.659281e-01 &  0.405556 &  0.501261 &  0.720102 \\
# std   &  1.808439e-01 &  0.242861 &  0.667830 &  1.129309 \\
# min   &  5.378985e-45 &  0.133333 & -0.190469 &  0.035747 \\
# 25\%   &  6.954754e-02 &  0.308333 &  0.180739 &  0.068367 \\
# 50\%   &  1.390951e-01 &  0.483333 &  0.551948 &  0.100987 \\
# 75\%   &  2.488922e-01 &  0.541667 &  0.847126 &  1.062279 \\
# max   &  3.586893e-01 &  0.600000 &  1.142304 &  2.023571 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:14:16.697792
# experiment number 1 took 12.292346000671387 seconds. That means the whole run will probably take 36.87703800201416 more seconds and 0.6146173000335693 more minutes.
# overall, it took 45.50061893463135 seconds with 3 experiments
#          cobeau  coverage       nlpd      rsme
# count  3.000000  3.000000   3.000000  3.000000
# mean   0.339997  0.238889 -26.841544  0.137352
# std    0.288041  0.091793  25.270354  0.048709
# min    0.067670  0.133333 -49.321230  0.099500
# 25%    0.189232  0.208333 -40.517342  0.109875
# 50%    0.310794  0.283333 -31.713454  0.120250
# 75%    0.476161  0.291667 -15.601701  0.156278
# max    0.641528  0.300000   0.510052  0.192306
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &   3.000000 &  3.000000 \\
# mean  &  0.339997 &  0.238889 & -26.841544 &  0.137352 \\
# std   &  0.288041 &  0.091793 &  25.270354 &  0.048709 \\
# min   &  0.067670 &  0.133333 & -49.321230 &  0.099500 \\
# 25\%   &  0.189232 &  0.208333 & -40.517342 &  0.109875 \\
# 50\%   &  0.310794 &  0.283333 & -31.713454 &  0.120250 \\
# 75\%   &  0.476161 &  0.291667 & -15.601701 &  0.156278 \\
# max   &  0.641528 &  0.300000 &   0.510052 &  0.192306 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:15:17.165913
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 21.58503007888794 seconds. That means the whole run will probably take 64.75509023666382 more seconds and 1.079251503944397 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 49.4796621799469 seconds with 3 experiments
#              cobeau  coverage       nlpd        rsme
# count  3.000000e+00  3.000000   3.000000    3.000000
# mean   3.313438e-07  0.833333 -44.837056  410.981988
# std    5.706681e-07  0.016667  34.982254   36.686213
# min    9.682047e-12  0.816667 -84.827869  372.294371
# 25%    1.870151e-09  0.825000 -57.299981  393.837978
# 50%    3.730620e-09  0.833333 -29.772093  415.381585
# 75%    4.970108e-07  0.841667 -24.841650  430.325796
# max    9.902910e-07  0.850000 -19.911207  445.270008
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &       nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &   3.000000 &    3.000000 \\
# mean  &  3.313438e-07 &  0.833333 & -44.837056 &  410.981988 \\
# std   &  5.706681e-07 &  0.016667 &  34.982254 &   36.686213 \\
# min   &  9.682047e-12 &  0.816667 & -84.827869 &  372.294371 \\
# 25\%   &  1.870151e-09 &  0.825000 & -57.299981 &  393.837978 \\
# 50\%   &  3.730620e-09 &  0.833333 & -29.772093 &  415.381585 \\
# 75\%   &  4.970108e-07 &  0.841667 & -24.841650 &  430.325796 \\
# max   &  9.902910e-07 &  0.850000 & -19.911207 &  445.270008 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:16:17.931964
# experiment number 1 took 12.65532112121582 seconds. That means the whole run will probably take 37.96596336364746 more seconds and 0.6327660560607911 more minutes.
# overall, it took 41.13217568397522 seconds with 3 experiments
#              cobeau  coverage           nlpd         rsme
# count  3.000000e+00  3.000000       3.000000     3.000000
# mean   6.343251e-05  0.550000 -189067.102155  1098.207189
# std    1.098560e-04  0.251661  327424.639220   686.333077
# min    2.527580e-12  0.283333 -567144.509143   422.039634
# 25%    7.099731e-09  0.433333 -283591.737874   750.174259
# 50%    1.419693e-08  0.583333     -38.966605  1078.308885
# 75%    9.514876e-05  0.683333     -28.398660  1436.290966
# max    1.902833e-04  0.783333     -17.830716  1794.273048
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &           nlpd &         rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &       3.000000 &     3.000000 \\
# mean  &  6.343251e-05 &  0.550000 & -189067.102155 &  1098.207189 \\
# std   &  1.098560e-04 &  0.251661 &  327424.639220 &   686.333077 \\
# min   &  2.527580e-12 &  0.283333 & -567144.509143 &   422.039634 \\
# 25\%   &  7.099731e-09 &  0.433333 & -283591.737874 &   750.174259 \\
# 50\%   &  1.419693e-08 &  0.583333 &     -38.966605 &  1078.308885 \\
# 75\%   &  9.514876e-05 &  0.683333 &     -28.398660 &  1436.290966 \\
# max   &  1.902833e-04 &  0.783333 &     -17.830716 &  1794.273048 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-16 14:17:11.336513
# experiment number 1 took 11.229857921600342 seconds. That means the whole run will probably take 33.689573764801025 more seconds and 0.5614928960800171 more minutes.
# overall, it took 38.4069082736969 seconds with 3 experiments
#              cobeau  coverage      nlpd        rsme
# count  3.000000e+00       3.0  3.000000    3.000000
# mean   1.561193e-07       1.0 -4.319044  573.971705
# std    1.937741e-07       0.0  1.744377  212.546955
# min    2.276881e-08       1.0 -6.274583  328.911857
# 25%    4.498122e-08       1.0 -5.016945  506.887357
# 50%    6.719362e-08       1.0 -3.759307  684.862858
# 75%    2.227945e-07       1.0 -3.341274  696.501630
# max    3.783954e-07       1.0 -2.923241  708.140401
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &       3.0 &  3.000000 &    3.000000 \\
# mean  &  1.561193e-07 &       1.0 & -4.319044 &  573.971705 \\
# std   &  1.937741e-07 &       0.0 &  1.744377 &  212.546955 \\
# min   &  2.276881e-08 &       1.0 & -6.274583 &  328.911857 \\
# 25\%   &  4.498122e-08 &       1.0 & -5.016945 &  506.887357 \\
# 50\%   &  6.719362e-08 &       1.0 & -3.759307 &  684.862858 \\
# 75\%   &  2.227945e-07 &       1.0 & -3.341274 &  696.501630 \\
# max   &  3.783954e-07 &       1.0 & -2.923241 &  708.140401 \\
# \bottomrule
# \end{tabular}
