# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3# 100#100#10
num_epochs = 5#15#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 150
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons,
               'l2':True}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:01:33.423595
# experiment number 1 took 1.9732961654663086 seconds. That means the whole run will probably take 5.919888496398926 more seconds and 0.09866480827331543 more minutes.
# overall, it took 6.072815179824829 seconds with 3 experiments
#              cobeau  coverage       nlpd      rsme
# count  3.000000e+00  3.000000   3.000000  3.000000
# mean   3.149400e-01  0.214815 -18.206102  0.043412
# std    5.454920e-01  0.100206  16.277136  0.035189
# min    9.432320e-13  0.111111 -36.554733  0.008636
# 25%    1.172391e-11  0.166667 -24.556846  0.025618
# 50%    2.250458e-11  0.222222 -12.558959  0.042600
# 75%    4.724099e-01  0.266667  -9.031786  0.060800
# max    9.448199e-01  0.311111  -5.504613  0.079000
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &   3.000000 &  3.000000 \\
# mean  &  3.149400e-01 &  0.214815 & -18.206102 &  0.043412 \\
# std   &  5.454920e-01 &  0.100206 &  16.277136 &  0.035189 \\
# min   &  9.432320e-13 &  0.111111 & -36.554733 &  0.008636 \\
# 25\%   &  1.172391e-11 &  0.166667 & -24.556846 &  0.025618 \\
# 50\%   &  2.250458e-11 &  0.222222 & -12.558959 &  0.042600 \\
# 75\%   &  4.724099e-01 &  0.266667 &  -9.031786 &  0.060800 \\
# max   &  9.448199e-01 &  0.311111 &  -5.504613 &  0.079000 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:01:43.338005
# experiment number 1 took 2.080335855484009 seconds. That means the whole run will probably take 6.241007566452026 more seconds and 0.10401679277420044 more minutes.
# overall, it took 6.61207389831543 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.500678  0.074074  0.873865  0.017415
# std    0.446671  0.033945  0.746718  0.008958
# min    0.000514  0.044444  0.174665  0.008762
# 25%    0.321111  0.055556  0.480588  0.012798
# 50%    0.641708  0.066667  0.786512  0.016834
# 75%    0.750760  0.088889  1.223465  0.021742
# max    0.859812  0.111111  1.660417  0.026650
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.500678 &  0.074074 &  0.873865 &  0.017415 \\
# std   &  0.446671 &  0.033945 &  0.746718 &  0.008958 \\
# min   &  0.000514 &  0.044444 &  0.174665 &  0.008762 \\
# 25\%   &  0.321111 &  0.055556 &  0.480588 &  0.012798 \\
# 50\%   &  0.641708 &  0.066667 &  0.786512 &  0.016834 \\
# 75\%   &  0.750760 &  0.088889 &  1.223465 &  0.021742 \\
# max   &  0.859812 &  0.111111 &  1.660417 &  0.026650 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:01:53.817604
# experiment number 1 took 2.2332520484924316 seconds. That means the whole run will probably take 6.699756145477295 more seconds and 0.11166260242462159 more minutes.
# overall, it took 6.9041290283203125 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.260209  0.348148  1.609718  0.006963
# std    0.103835  0.180990  0.215620  0.001930
# min    0.160007  0.222222  1.442631  0.005791
# 25%    0.206647  0.244444  1.488019  0.005850
# 50%    0.253288  0.266667  1.533407  0.005909
# 75%    0.310310  0.411111  1.693262  0.007550
# max    0.367331  0.555556  1.853116  0.009191
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.260209 &  0.348148 &  1.609718 &  0.006963 \\
# std   &  0.103835 &  0.180990 &  0.215620 &  0.001930 \\
# min   &  0.160007 &  0.222222 &  1.442631 &  0.005791 \\
# 25\%   &  0.206647 &  0.244444 &  1.488019 &  0.005850 \\
# 50\%   &  0.253288 &  0.266667 &  1.533407 &  0.005909 \\
# 75\%   &  0.310310 &  0.411111 &  1.693262 &  0.007550 \\
# max   &  0.367331 &  0.555556 &  1.853116 &  0.009191 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed,
               'l2':True}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:02:04.564816
# experiment number 1 took 1.7885627746582031 seconds. That means the whole run will probably take 5.365688323974609 more seconds and 0.08942813873291015 more minutes.
# overall, it took 5.524508953094482 seconds with 3 experiments
#          cobeau  coverage         nlpd      rsme
# count  3.000000  3.000000     3.000000  3.000000
# mean   0.118194  0.051852  -748.693808  0.708074
# std    0.200065  0.033945   328.805124  0.240326
# min    0.001649  0.022222 -1114.600496  0.444321
# 25%    0.002688  0.033333  -884.036844  0.604778
# 50%    0.003727  0.044444  -653.473192  0.765234
# 75%    0.176466  0.066667  -565.740464  0.839950
# max    0.349206  0.088889  -478.007737  0.914666
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &         nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &     3.000000 &  3.000000 \\
# mean  &  0.118194 &  0.051852 &  -748.693808 &  0.708074 \\
# std   &  0.200065 &  0.033945 &   328.805124 &  0.240326 \\
# min   &  0.001649 &  0.022222 & -1114.600496 &  0.444321 \\
# 25\%   &  0.002688 &  0.033333 &  -884.036844 &  0.604778 \\
# 50\%   &  0.003727 &  0.044444 &  -653.473192 &  0.765234 \\
# 75\%   &  0.176466 &  0.066667 &  -565.740464 &  0.839950 \\
# max   &  0.349206 &  0.088889 &  -478.007737 &  0.914666 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:02:14.562946
# experiment number 1 took 2.7372488975524902 seconds. That means the whole run will probably take 8.21174669265747 more seconds and 0.1368624448776245 more minutes.
# overall, it took 9.491114139556885 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   1.089330e-01  0.607407 -0.255578  3.136904
# std    1.147031e-01  0.233422  0.633272  4.940370
# min    2.881057e-22  0.377778 -0.986796  0.269714
# 25%    4.907693e-02  0.488889 -0.440817  0.284594
# 50%    9.815385e-02  0.600000  0.105163  0.299473
# 75%    1.633996e-01  0.722222  0.110030  4.570500
# max    2.286453e-01  0.844444  0.114898  8.841526
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  1.089330e-01 &  0.607407 & -0.255578 &  3.136904 \\
# std   &  1.147031e-01 &  0.233422 &  0.633272 &  4.940370 \\
# min   &  2.881057e-22 &  0.377778 & -0.986796 &  0.269714 \\
# 25\%   &  4.907693e-02 &  0.488889 & -0.440817 &  0.284594 \\
# 50\%   &  9.815385e-02 &  0.600000 &  0.105163 &  0.299473 \\
# 75\%   &  1.633996e-01 &  0.722222 &  0.110030 &  4.570500 \\
# max   &  2.286453e-01 &  0.844444 &  0.114898 &  8.841526 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:02:28.965218
# experiment number 1 took 3.7968320846557617 seconds. That means the whole run will probably take 11.390496253967285 more seconds and 0.1898416042327881 more minutes.
# overall, it took 11.63598108291626 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.311785  0.429630 -2.133766  0.243970
# std    0.187429  0.046259  3.165940  0.047675
# min    0.110841  0.377778 -5.752970  0.192488
# 25%    0.226743  0.411111 -3.261729  0.222656
# 50%    0.342646  0.444444 -0.770488  0.252824
# 75%    0.412257  0.455556 -0.324165  0.269710
# max    0.481868  0.466667  0.122158  0.286596
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.311785 &  0.429630 & -2.133766 &  0.243970 \\
# std   &  0.187429 &  0.046259 &  3.165940 &  0.047675 \\
# min   &  0.110841 &  0.377778 & -5.752970 &  0.192488 \\
# 25\%   &  0.226743 &  0.411111 & -3.261729 &  0.222656 \\
# 50\%   &  0.342646 &  0.444444 & -0.770488 &  0.252824 \\
# 75\%   &  0.412257 &  0.455556 & -0.324165 &  0.269710 \\
# max   &  0.481868 &  0.466667 &  0.122158 &  0.286596 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:02:46.838932
# experiment number 1 took 3.297808885574341 seconds. That means the whole run will probably take 9.893426656723022 more seconds and 0.16489044427871705 more minutes.
# overall, it took 8.92342495918274 seconds with 3 experiments
#          cobeau  coverage          nlpd         rsme
# count  3.000000  3.000000  3.000000e+00     3.000000
# mean   0.301169  0.177778 -6.414353e+06  2294.431082
# std    0.065422  0.022222  5.347910e+06   318.483632
# min    0.253483  0.155556 -9.957824e+06  2058.420076
# 25%    0.263878  0.166667 -9.490141e+06  2113.305515
# 50%    0.274273  0.177778 -9.022457e+06  2168.190955
# 75%    0.325013  0.188889 -4.642617e+06  2412.436584
# max    0.375752  0.200000 -2.627775e+05  2656.682214
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &          nlpd &         rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000e+00 &     3.000000 \\
# mean  &  0.301169 &  0.177778 & -6.414353e+06 &  2294.431082 \\
# std   &  0.065422 &  0.022222 &  5.347910e+06 &   318.483632 \\
# min   &  0.253483 &  0.155556 & -9.957824e+06 &  2058.420076 \\
# 25\%   &  0.263878 &  0.166667 & -9.490141e+06 &  2113.305515 \\
# 50\%   &  0.274273 &  0.177778 & -9.022457e+06 &  2168.190955 \\
# 75\%   &  0.325013 &  0.188889 & -4.642617e+06 &  2412.436584 \\
# max   &  0.375752 &  0.200000 & -2.627775e+05 &  2656.682214 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:03:01.205310
# experiment number 1 took 4.4097740650177 seconds. That means the whole run will probably take 13.2293221950531 more seconds and 0.22048870325088502 more minutes.
# overall, it took 10.90489912033081 seconds with 3 experiments
#          cobeau  coverage           nlpd         rsme
# count  3.000000  3.000000       3.000000     3.000000
# mean   0.456387  0.325926  -76017.411320  2916.750045
# std    0.437540  0.188998  131228.708261   230.994171
# min    0.000051  0.111111 -227547.241683  2666.068972
# 25%    0.248415  0.255556 -113940.961659  2814.622342
# 50%    0.496780  0.400000    -334.681636  2963.175712
# 75%    0.684555  0.433333    -252.496138  3042.090582
# max    0.872330  0.466667    -170.310640  3121.005452
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &           nlpd &         rsme \\
# \midrule
# count &  3.000000 &  3.000000 &       3.000000 &     3.000000 \\
# mean  &  0.456387 &  0.325926 &  -76017.411320 &  2916.750045 \\
# std   &  0.437540 &  0.188998 &  131228.708261 &   230.994171 \\
# min   &  0.000051 &  0.111111 & -227547.241683 &  2666.068972 \\
# 25\%   &  0.248415 &  0.255556 & -113940.961659 &  2814.622342 \\
# 50\%   &  0.496780 &  0.400000 &    -334.681636 &  2963.175712 \\
# 75\%   &  0.684555 &  0.433333 &    -252.496138 &  3042.090582 \\
# max   &  0.872330 &  0.466667 &    -170.310640 &  3121.005452 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 11:03:16.453095
# experiment number 1 took 2.1898202896118164 seconds. That means the whole run will probably take 6.569460868835449 more seconds and 0.10949101448059081 more minutes.
# overall, it took 6.622530698776245 seconds with 3 experiments
#          cobeau  coverage        nlpd         rsme
# count  3.000000  3.000000    3.000000     3.000000
# mean   0.235492  0.866667  -46.132888  2241.933544
# std    0.407780  0.192450   62.975319   565.847333
# min    0.000003  0.644444 -118.850416  1851.784609
# 25%    0.000060  0.811111  -64.366107  1917.448596
# 50%    0.000117  0.977778   -9.881797  1983.112583
# 75%    0.353237  0.977778   -9.774123  2437.008012
# max    0.706357  0.977778   -9.666449  2890.903442
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &        nlpd &         rsme \\
# \midrule
# count &  3.000000 &  3.000000 &    3.000000 &     3.000000 \\
# mean  &  0.235492 &  0.866667 &  -46.132888 &  2241.933544 \\
# std   &  0.407780 &  0.192450 &   62.975319 &   565.847333 \\
# min   &  0.000003 &  0.644444 & -118.850416 &  1851.784609 \\
# 25\%   &  0.000060 &  0.811111 &  -64.366107 &  1917.448596 \\
# 50\%   &  0.000117 &  0.977778 &   -9.881797 &  1983.112583 \\
# 75\%   &  0.353237 &  0.977778 &   -9.774123 &  2437.008012 \\
# max   &  0.706357 &  0.977778 &   -9.666449 &  2890.903442 \\
# \bottomrule
# \end{tabular}
