# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)


# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3#100#10
num_epochs = 50#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 150
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:19:46.710283
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 17.34041690826416 seconds. That means the whole run will probably take 52.02125072479248 more seconds and 0.867020845413208 more minutes.
# overall, it took 46.50943994522095 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.379546  0.281481       inf  0.008010
# std    0.395032  0.067890       NaN  0.001508
# min    0.006479  0.222222       inf  0.006847
# 25%    0.172629  0.244444       inf  0.007158
# 50%    0.338779  0.266667       NaN  0.007469
# 75%    0.566080  0.311111       inf  0.008591
# max    0.793381  0.355556       inf  0.009714
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.379546 &  0.281481 &       inf &  0.008010 \\
# std   &  0.395032 &  0.067890 &       NaN &  0.001508 \\
# min   &  0.006479 &  0.222222 &       inf &  0.006847 \\
# 25\%   &  0.172629 &  0.244444 &       inf &  0.007158 \\
# 50\%   &  0.338779 &  0.266667 &       NaN &  0.007469 \\
# 75\%   &  0.566080 &  0.311111 &       inf &  0.008591 \\
# max   &  0.793381 &  0.355556 &       inf &  0.009714 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:20:37.351021
# experiment number 1 took 15.362598896026611 seconds. That means the whole run will probably take 46.087796688079834 more seconds and 0.7681299448013306 more minutes.
# overall, it took 55.82585382461548 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.327758  0.074074  1.265669  0.012296
# std    0.374320  0.067890  0.830723  0.007274
# min    0.029998  0.000000  0.322008  0.005379
# 25%    0.117654  0.044444  0.955208  0.008503
# 50%    0.205311  0.088889  1.588408  0.011628
# 75%    0.476639  0.111111  1.737500  0.015754
# max    0.747967  0.133333  1.886592  0.019881
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.327758 &  0.074074 &  1.265669 &  0.012296 \\
# std   &  0.374320 &  0.067890 &  0.830723 &  0.007274 \\
# min   &  0.029998 &  0.000000 &  0.322008 &  0.005379 \\
# 25\%   &  0.117654 &  0.044444 &  0.955208 &  0.008503 \\
# 50\%   &  0.205311 &  0.088889 &  1.588408 &  0.011628 \\
# 75\%   &  0.476639 &  0.111111 &  1.737500 &  0.015754 \\
# max   &  0.747967 &  0.133333 &  1.886592 &  0.019881 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:21:37.806609
# experiment number 1 took 21.287184953689575 seconds. That means the whole run will probably take 63.861554861068726 more seconds and 1.0643592476844788 more minutes.
# overall, it took 65.56186509132385 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.376546  0.014815  0.799324  0.007038
# std    0.358273  0.025660  1.636526  0.001082
# min    0.153945  0.000000 -1.089515  0.006119
# 25%    0.169903  0.000000  0.302440  0.006442
# 50%    0.185861  0.000000  1.694394  0.006764
# 75%    0.487847  0.022222  1.743743  0.007497
# max    0.789834  0.044444  1.793091  0.008230
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.376546 &  0.014815 &  0.799324 &  0.007038 \\
# std   &  0.358273 &  0.025660 &  1.636526 &  0.001082 \\
# min   &  0.153945 &  0.000000 & -1.089515 &  0.006119 \\
# 25\%   &  0.169903 &  0.000000 &  0.302440 &  0.006442 \\
# 50\%   &  0.185861 &  0.000000 &  1.694394 &  0.006764 \\
# 75\%   &  0.487847 &  0.022222 &  1.743743 &  0.007497 \\
# max   &  0.789834 &  0.044444 &  1.793091 &  0.008230 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:22:48.001768
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 16.47641086578369 seconds. That means the whole run will probably take 49.429232597351074 more seconds and 0.8238205432891845 more minutes.
# overall, it took 51.253318071365356 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.438486  0.377778       inf  0.053028
# std    0.449347  0.096864       NaN  0.020770
# min    0.066787  0.266667       inf  0.029049
# 25%    0.188803  0.344444       inf  0.046828
# 50%    0.310820  0.422222       NaN  0.064607
# 75%    0.624336  0.433333       inf  0.065017
# max    0.937852  0.444444       inf  0.065428
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.438486 &  0.377778 &       inf &  0.053028 \\
# std   &  0.449347 &  0.096864 &       NaN &  0.020770 \\
# min   &  0.066787 &  0.266667 &       inf &  0.029049 \\
# 25\%   &  0.188803 &  0.344444 &       inf &  0.046828 \\
# 50\%   &  0.310820 &  0.422222 &       NaN &  0.064607 \\
# 75\%   &  0.624336 &  0.433333 &       inf &  0.065017 \\
# max   &  0.937852 &  0.444444 &       inf &  0.065428 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:23:45.112118
# experiment number 1 took 31.789144039154053 seconds. That means the whole run will probably take 95.36743211746216 more seconds and 1.5894572019577027 more minutes.
# overall, it took 85.83315086364746 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.321359  0.081481 -0.853950  0.038487
# std    0.315318  0.025660  3.828751  0.028968
# min    0.047350  0.066667 -5.273661  0.019707
# 25%    0.149036  0.066667 -2.006177  0.021806
# 50%    0.250723  0.066667  1.261307  0.023906
# 75%    0.458363  0.088889  1.355905  0.047877
# max    0.666004  0.111111  1.450503  0.071848
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.321359 &  0.081481 & -0.853950 &  0.038487 \\
# std   &  0.315318 &  0.025660 &  3.828751 &  0.028968 \\
# min   &  0.047350 &  0.066667 & -5.273661 &  0.019707 \\
# 25\%   &  0.149036 &  0.066667 & -2.006177 &  0.021806 \\
# 50\%   &  0.250723 &  0.066667 &  1.261307 &  0.023906 \\
# 75\%   &  0.458363 &  0.088889 &  1.355905 &  0.047877 \\
# max   &  0.666004 &  0.111111 &  1.450503 &  0.071848 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:25:15.842128
# experiment number 1 took 22.99868083000183 seconds. That means the whole run will probably take 68.9960424900055 more seconds and 1.1499340415000916 more minutes.
# overall, it took 65.39834809303284 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.631417  0.022222 -1.603620  0.020339
# std    0.460469  0.022222  1.221479  0.004781
# min    0.110037  0.000000 -2.438889  0.016031
# 25%    0.455924  0.011111 -2.304564  0.017767
# 50%    0.801811  0.022222 -2.170240  0.019503
# 75%    0.892108  0.033333 -1.185985  0.022493
# max    0.982405  0.044444 -0.201731  0.025483
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.631417 &  0.022222 & -1.603620 &  0.020339 \\
# std   &  0.460469 &  0.022222 &  1.221479 &  0.004781 \\
# min   &  0.110037 &  0.000000 & -2.438889 &  0.016031 \\
# 25\%   &  0.455924 &  0.011111 & -2.304564 &  0.017767 \\
# 50\%   &  0.801811 &  0.022222 & -2.170240 &  0.019503 \\
# 75\%   &  0.892108 &  0.033333 & -1.185985 &  0.022493 \\
# max   &  0.982405 &  0.044444 & -0.201731 &  0.025483 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:26:26.554764
# /Users/thomas/Documents/Master-Thesis/new_version/evaluation.py:24: RuntimeWarning: divide by zero encountered in log
#   logs = np.log(x)
# experiment number 1 took 17.065099954605103 seconds. That means the whole run will probably take 51.19529986381531 more seconds and 0.8532549977302551 more minutes.
# overall, it took 49.229565143585205 seconds with 3 experiments
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#          cobeau  coverage      nlpd       rsme
# count  3.000000  3.000000  3.000000   3.000000
# mean   0.000140  0.266667       inf  53.337032
# std    0.000127  0.038490       NaN  10.089771
# min    0.000002  0.244444       inf  42.830594
# 25%    0.000084  0.244444       inf  48.530139
# 50%    0.000166  0.244444       NaN  54.229683
# 75%    0.000209  0.277778       inf  58.590251
# max    0.000252  0.311111       inf  62.950819
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &   3.000000 \\
# mean  &  0.000140 &  0.266667 &       inf &  53.337032 \\
# std   &  0.000127 &  0.038490 &       NaN &  10.089771 \\
# min   &  0.000002 &  0.244444 &       inf &  42.830594 \\
# 25\%   &  0.000084 &  0.244444 &       inf &  48.530139 \\
# 50\%   &  0.000166 &  0.244444 &       NaN &  54.229683 \\
# 75\%   &  0.000209 &  0.277778 &       inf &  58.590251 \\
# max   &  0.000252 &  0.311111 &       inf &  62.950819 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:27:20.394683
# experiment number 1 took 25.121585845947266 seconds. That means the whole run will probably take 75.3647575378418 more seconds and 1.2560792922973634 more minutes.
# overall, it took 75.47618794441223 seconds with 3 experiments
#              cobeau  coverage          nlpd        rsme
# count  3.000000e+00  3.000000      3.000000    3.000000
# mean   1.611001e-04  0.866667  -3542.670743  172.874318
# std    2.790133e-04  0.230940   6131.210896  166.215461
# min    2.455981e-11  0.600000 -10622.383245   41.644622
# 25%    1.165745e-08  0.800000  -5312.831213   79.421089
# 50%    2.329035e-08  1.000000     -3.279180  117.197556
# 75%    2.416501e-04  1.000000     -2.814491  238.489166
# max    4.832769e-04  1.000000     -2.349803  359.780775
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &          nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &      3.000000 &    3.000000 \\
# mean  &  1.611001e-04 &  0.866667 &  -3542.670743 &  172.874318 \\
# std   &  2.790133e-04 &  0.230940 &   6131.210896 &  166.215461 \\
# min   &  2.455981e-11 &  0.600000 & -10622.383245 &   41.644622 \\
# 25\%   &  1.165745e-08 &  0.800000 &  -5312.831213 &   79.421089 \\
# 50\%   &  2.329035e-08 &  1.000000 &     -3.279180 &  117.197556 \\
# 75\%   &  2.416501e-04 &  1.000000 &     -2.814491 &  238.489166 \\
# max   &  4.832769e-04 &  1.000000 &     -2.349803 &  359.780775 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-08 23:28:42.196819
# experiment number 1 took 25.464298009872437 seconds. That means the whole run will probably take 76.39289402961731 more seconds and 1.2732149004936217 more minutes.
# overall, it took 71.27569484710693 seconds with 3 experiments
#          cobeau  coverage      nlpd       rsme
# count  3.000000  3.000000  3.000000   3.000000
# mean   0.457860  0.977778 -2.202687  27.998114
# std    0.403275  0.022222  0.126506  14.570261
# min    0.000064  0.955556 -2.347623  18.485734
# 25%    0.306505  0.966667 -2.246811  19.611098
# 50%    0.612947  0.977778 -2.146000  20.736462
# 75%    0.686758  0.988889 -2.130219  32.754303
# max    0.760569  1.000000 -2.114439  44.772144
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &       rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &   3.000000 \\
# mean  &  0.457860 &  0.977778 & -2.202687 &  27.998114 \\
# std   &  0.403275 &  0.022222 &  0.126506 &  14.570261 \\
# min   &  0.000064 &  0.955556 & -2.347623 &  18.485734 \\
# 25\%   &  0.306505 &  0.966667 & -2.246811 &  19.611098 \\
# 50\%   &  0.612947 &  0.977778 & -2.146000 &  20.736462 \\
# 75\%   &  0.686758 &  0.988889 & -2.130219 &  32.754303 \\
# max   &  0.760569 &  1.000000 & -2.114439 &  44.772144 \\
# \bottomrule
# \end{tabular}
