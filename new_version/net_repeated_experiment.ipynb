# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3# 100#100#10
num_epochs = 10#15#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 200
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons,
               'l2':True}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:05:12.283560
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 6.4106268882751465 seconds. That means the whole run will probably take 19.23188066482544 more seconds and 0.3205313444137573 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 18.440726041793823 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.526841  0.772222  0.900914  0.015156
# std    0.379691  0.050918  0.014703  0.003828
# min    0.132056  0.716667  0.887822  0.011843
# 25%    0.345570  0.750000  0.892961  0.013060
# 50%    0.559083  0.783333  0.898099  0.014278
# 75%    0.724233  0.800000  0.907460  0.016812
# max    0.889383  0.816667  0.916821  0.019347
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.526841 &  0.772222 &  0.900914 &  0.015156 \\
# std   &  0.379691 &  0.050918 &  0.014703 &  0.003828 \\
# min   &  0.132056 &  0.716667 &  0.887822 &  0.011843 \\
# 25\%   &  0.345570 &  0.750000 &  0.892961 &  0.013060 \\
# 50\%   &  0.559083 &  0.783333 &  0.898099 &  0.014278 \\
# 75\%   &  0.724233 &  0.800000 &  0.907460 &  0.016812 \\
# max   &  0.889383 &  0.816667 &  0.916821 &  0.019347 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:05:34.685958
# experiment number 1 took 5.220384120941162 seconds. That means the whole run will probably take 15.661152362823486 more seconds and 0.2610192060470581 more minutes.
# overall, it took 16.129615783691406 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.136160  0.055556  1.666629  0.013115
# std    0.171366  0.034694  0.258224  0.007464
# min    0.000259  0.016667  1.372806  0.008257
# 25%    0.039906  0.041667  1.571206  0.008818
# 50%    0.079554  0.066667  1.769607  0.009378
# 75%    0.204110  0.075000  1.813541  0.015544
# max    0.328667  0.083333  1.857475  0.021710
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.136160 &  0.055556 &  1.666629 &  0.013115 \\
# std   &  0.171366 &  0.034694 &  0.258224 &  0.007464 \\
# min   &  0.000259 &  0.016667 &  1.372806 &  0.008257 \\
# 25\%   &  0.039906 &  0.041667 &  1.571206 &  0.008818 \\
# 50\%   &  0.079554 &  0.066667 &  1.769607 &  0.009378 \\
# 75\%   &  0.204110 &  0.075000 &  1.813541 &  0.015544 \\
# max   &  0.328667 &  0.083333 &  1.857475 &  0.021710 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:05:55.397404
# experiment number 1 took 7.0514209270477295 seconds. That means the whole run will probably take 21.15426278114319 more seconds and 0.35257104635238645 more minutes.
# overall, it took 21.498087882995605 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.221933  0.077778  1.915401  0.007501
# std    0.092002  0.019245  0.001831  0.000966
# min    0.142853  0.066667  1.913309  0.006791
# 25%    0.171445  0.066667  1.914746  0.006951
# 50%    0.200038  0.066667  1.916184  0.007111
# 75%    0.261473  0.083333  1.916447  0.007856
# max    0.322907  0.100000  1.916710  0.008601
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.221933 &  0.077778 &  1.915401 &  0.007501 \\
# std   &  0.092002 &  0.019245 &  0.001831 &  0.000966 \\
# min   &  0.142853 &  0.066667 &  1.913309 &  0.006791 \\
# 25\%   &  0.171445 &  0.066667 &  1.914746 &  0.006951 \\
# 50\%   &  0.200038 &  0.066667 &  1.916184 &  0.007111 \\
# 75\%   &  0.261473 &  0.083333 &  1.916447 &  0.007856 \\
# max   &  0.322907 &  0.100000 &  1.916710 &  0.008601 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed,
               'l2':True}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:06:20.835975
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 6.388416051864624 seconds. That means the whole run will probably take 19.165248155593872 more seconds and 0.3194208025932312 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 19.827319145202637 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.068110  0.177778 -0.226461  0.349064
# std    0.116894  0.069389  0.241501  0.071794
# min    0.000311  0.100000 -0.432758  0.270966
# 25%    0.000621  0.150000 -0.359282  0.317500
# 50%    0.000931  0.200000 -0.285806  0.364034
# 75%    0.102009  0.216667 -0.123313  0.388114
# max    0.203087  0.233333  0.039179  0.412193
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.068110 &  0.177778 & -0.226461 &  0.349064 \\
# std   &  0.116894 &  0.069389 &  0.241501 &  0.071794 \\
# min   &  0.000311 &  0.100000 & -0.432758 &  0.270966 \\
# 25\%   &  0.000621 &  0.150000 & -0.359282 &  0.317500 \\
# 50\%   &  0.000931 &  0.200000 & -0.285806 &  0.364034 \\
# 75\%   &  0.102009 &  0.216667 & -0.123313 &  0.388114 \\
# max   &  0.203087 &  0.233333 &  0.039179 &  0.412193 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:06:45.828647
# experiment number 1 took 8.245351791381836 seconds. That means the whole run will probably take 24.736055374145508 more seconds and 0.4122675895690918 more minutes.
# overall, it took 24.543291807174683 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   2.130196e-01  0.366667  0.540684  0.379188
# std    3.684866e-01  0.189297  0.533993  0.534369
# min    3.841421e-32  0.233333 -0.062390  0.049075
# 25%    2.738126e-04  0.258333  0.334295  0.070928
# 50%    5.476251e-04  0.283333  0.730980  0.092780
# 75%    3.195293e-01  0.433333  0.842222  0.544244
# max    6.385111e-01  0.583333  0.953463  0.995708
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  2.130196e-01 &  0.366667 &  0.540684 &  0.379188 \\
# std   &  3.684866e-01 &  0.189297 &  0.533993 &  0.534369 \\
# min   &  3.841421e-32 &  0.233333 & -0.062390 &  0.049075 \\
# 25\%   &  2.738126e-04 &  0.258333 &  0.334295 &  0.070928 \\
# 50\%   &  5.476251e-04 &  0.283333 &  0.730980 &  0.092780 \\
# 75\%   &  3.195293e-01 &  0.433333 &  0.842222 &  0.544244 \\
# max   &  6.385111e-01 &  0.583333 &  0.953463 &  0.995708 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:07:14.712287
# experiment number 1 took 5.283062219619751 seconds. That means the whole run will probably take 15.849186658859253 more seconds and 0.26415311098098754 more minutes.
# overall, it took 16.239469051361084 seconds with 3 experiments
#          cobeau  coverage       nlpd      rsme
# count  3.000000  3.000000   3.000000  3.000000
# mean   0.276641  0.294444 -24.441668  0.100053
# std    0.145974  0.041944  23.368336  0.053160
# min    0.126885  0.250000 -45.205058  0.050290
# 25%    0.205705  0.275000 -37.094759  0.072050
# 50%    0.284526  0.300000 -28.984460  0.093811
# 75%    0.351519  0.316667 -14.059972  0.124935
# max    0.418513  0.333333   0.864515  0.156059
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &   3.000000 &  3.000000 \\
# mean  &  0.276641 &  0.294444 & -24.441668 &  0.100053 \\
# std   &  0.145974 &  0.041944 &  23.368336 &  0.053160 \\
# min   &  0.126885 &  0.250000 & -45.205058 &  0.050290 \\
# 25\%   &  0.205705 &  0.275000 & -37.094759 &  0.072050 \\
# 50\%   &  0.284526 &  0.300000 & -28.984460 &  0.093811 \\
# 75\%   &  0.351519 &  0.316667 & -14.059972 &  0.124935 \\
# max   &  0.418513 &  0.333333 &   0.864515 &  0.156059 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:07:35.917457
# initialising Network <class 'networks.DropoutNetwork'>
# experiment number 1 took 8.018808841705322 seconds. That means the whole run will probably take 24.056426525115967 more seconds and 0.40094044208526614 more minutes.
# initialising Network <class 'networks.DropoutNetwork'>
# initialising Network <class 'networks.DropoutNetwork'>
# overall, it took 25.37214207649231 seconds with 3 experiments
#              cobeau  coverage        nlpd        rsme
# count  3.000000e+00  3.000000    3.000000    3.000000
# mean   3.595235e-07  0.811111  -58.726204  423.516926
# std    5.715661e-07  0.025459   56.424530   39.733852
# min    3.629627e-12  0.783333 -123.876137  385.194047
# 25%    2.998395e-08  0.800000  -75.306181  403.012645
# 50%    5.996427e-08  0.816667  -26.736224  420.831242
# 75%    5.392834e-07  0.825000  -26.151238  442.678365
# max    1.018603e-06  0.833333  -25.566252  464.525488
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &        nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &    3.000000 &    3.000000 \\
# mean  &  3.595235e-07 &  0.811111 &  -58.726204 &  423.516926 \\
# std   &  5.715661e-07 &  0.025459 &   56.424530 &   39.733852 \\
# min   &  3.629627e-12 &  0.783333 & -123.876137 &  385.194047 \\
# 25\%   &  2.998395e-08 &  0.800000 &  -75.306181 &  403.012645 \\
# 50\%   &  5.996427e-08 &  0.816667 &  -26.736224 &  420.831242 \\
# 75\%   &  5.392834e-07 &  0.825000 &  -26.151238 &  442.678365 \\
# max   &  1.018603e-06 &  0.833333 &  -25.566252 &  464.525488 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:08:06.482296
# experiment number 1 took 9.08763599395752 seconds. That means the whole run will probably take 27.26290798187256 more seconds and 0.45438179969787595 more minutes.
# overall, it took 25.62914800643921 seconds with 3 experiments
#              cobeau  coverage           nlpd         rsme
# count  3.000000e+00  3.000000       3.000000     3.000000
# mean   6.208257e-04  0.527778 -233382.980661  1211.914624
# std    1.074985e-03  0.227507  404177.038223   836.992932
# min    2.533234e-11  0.283333 -700086.424144   438.931627
# 25%    1.829886e-07  0.425000 -350064.031023   767.456747
# 50%    3.659518e-07  0.566667     -41.637903  1095.981868
# 75%    9.312385e-04  0.650000     -31.258920  1598.406123
# max    1.862111e-03  0.733333     -20.879936  2100.830378
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &           nlpd &         rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &       3.000000 &     3.000000 \\
# mean  &  6.208257e-04 &  0.527778 & -233382.980661 &  1211.914624 \\
# std   &  1.074985e-03 &  0.227507 &  404177.038223 &   836.992932 \\
# min   &  2.533234e-11 &  0.283333 & -700086.424144 &   438.931627 \\
# 25\%   &  1.829886e-07 &  0.425000 & -350064.031023 &   767.456747 \\
# 50\%   &  3.659518e-07 &  0.566667 &     -41.637903 &  1095.981868 \\
# 75\%   &  9.312385e-04 &  0.650000 &     -31.258920 &  1598.406123 \\
# max   &  1.862111e-03 &  0.733333 &     -20.879936 &  2100.830378 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-15 14:08:36.918536
# experiment number 1 took 7.02928614616394 seconds. That means the whole run will probably take 21.08785843849182 more seconds and 0.351464307308197 more minutes.
# overall, it took 21.65432071685791 seconds with 3 experiments
#              cobeau  coverage      nlpd        rsme
# count  3.000000e+00       3.0  3.000000    3.000000
# mean   7.890074e-04       1.0 -3.440095  401.941375
# std    1.365984e-03       0.0  0.498035   46.159905
# min    3.123713e-09       1.0 -3.994455  353.600297
# 25%    3.562129e-07       1.0 -3.644928  380.133813
# 50%    7.093020e-07       1.0 -3.295401  406.667328
# 75%    1.183510e-03       1.0 -3.162915  426.111915
# max    2.366310e-03       1.0 -3.030429  445.556501
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &       3.0 &  3.000000 &    3.000000 \\
# mean  &  7.890074e-04 &       1.0 & -3.440095 &  401.941375 \\
# std   &  1.365984e-03 &       0.0 &  0.498035 &   46.159905 \\
# min   &  3.123713e-09 &       1.0 & -3.994455 &  353.600297 \\
# 25\%   &  3.562129e-07 &       1.0 & -3.644928 &  380.133813 \\
# 50\%   &  7.093020e-07 &       1.0 & -3.295401 &  406.667328 \\
# 75\%   &  1.183510e-03 &       1.0 & -3.162915 &  426.111915 \\
# max   &  2.366310e-03 &       1.0 & -3.030429 &  445.556501 \\
# \bottomrule
# \end{tabular}
