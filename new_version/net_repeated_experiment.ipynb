# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3# 100#100#10
num_epochs = 5#15#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 150
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:15:22.742117
# experiment number 1 took 3.345486879348755 seconds. That means the whole run will probably take 10.036460638046265 more seconds and 0.16727434396743773 more minutes.
# overall, it took 12.464048862457275 seconds with 3 experiments
#              cobeau  coverage       nlpd      rsme
# count  3.000000e+00  3.000000   3.000000  3.000000
# mean   2.309624e-01  0.200000 -26.830660  0.055227
# std    4.000386e-01  0.101835  16.973270  0.041814
# min    2.949578e-11  0.088889 -44.141631  0.007050
# 25%    1.693274e-10  0.155556 -35.137711  0.041803
# 50%    3.091590e-10  0.222222 -26.133792  0.076556
# 75%    3.464436e-01  0.255556 -18.175174  0.079316
# max    6.928871e-01  0.288889 -10.216557  0.082076
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &   3.000000 &  3.000000 \\
# mean  &  2.309624e-01 &  0.200000 & -26.830660 &  0.055227 \\
# std   &  4.000386e-01 &  0.101835 &  16.973270 &  0.041814 \\
# min   &  2.949578e-11 &  0.088889 & -44.141631 &  0.007050 \\
# 25\%   &  1.693274e-10 &  0.155556 & -35.137711 &  0.041803 \\
# 50\%   &  3.091590e-10 &  0.222222 & -26.133792 &  0.076556 \\
# 75\%   &  3.464436e-01 &  0.255556 & -18.175174 &  0.079316 \\
# max   &  6.928871e-01 &  0.288889 & -10.216557 &  0.082076 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:15:43.093725
# experiment number 1 took 3.5332047939300537 seconds. That means the whole run will probably take 10.599614381790161 more seconds and 0.17666023969650269 more minutes.
# overall, it took 11.180332660675049 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.503529  0.214815  1.803111  0.006765
# std    0.389787  0.012830  0.184602  0.001675
# min    0.056008  0.200000  1.603834  0.005128
# 25%    0.370865  0.211111  1.720527  0.005910
# 50%    0.685723  0.222222  1.837219  0.006691
# 75%    0.727289  0.222222  1.902750  0.007584
# max    0.768855  0.222222  1.968281  0.008477
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.503529 &  0.214815 &  1.803111 &  0.006765 \\
# std   &  0.389787 &  0.012830 &  0.184602 &  0.001675 \\
# min   &  0.056008 &  0.200000 &  1.603834 &  0.005128 \\
# 25\%   &  0.370865 &  0.211111 &  1.720527 &  0.005910 \\
# 50\%   &  0.685723 &  0.222222 &  1.837219 &  0.006691 \\
# 75\%   &  0.727289 &  0.222222 &  1.902750 &  0.007584 \\
# max   &  0.768855 &  0.222222 &  1.968281 &  0.008477 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:16:01.081857
# experiment number 1 took 4.323601961135864 seconds. That means the whole run will probably take 12.970805883407593 more seconds and 0.21618009805679322 more minutes.
# overall, it took 13.598856925964355 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.259117  0.274074  1.519061  0.010128
# std    0.281297  0.130210  0.334973  0.004692
# min    0.049322  0.177778  1.178084  0.005540
# 25%    0.099293  0.200000  1.354747  0.007732
# 50%    0.149265  0.222222  1.531409  0.009925
# 75%    0.364014  0.322222  1.689549  0.012421
# max    0.578764  0.422222  1.847690  0.014918
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.259117 &  0.274074 &  1.519061 &  0.010128 \\
# std   &  0.281297 &  0.130210 &  0.334973 &  0.004692 \\
# min   &  0.049322 &  0.177778 &  1.178084 &  0.005540 \\
# 25\%   &  0.099293 &  0.200000 &  1.354747 &  0.007732 \\
# 50\%   &  0.149265 &  0.222222 &  1.531409 &  0.009925 \\
# 75\%   &  0.364014 &  0.322222 &  1.689549 &  0.012421 \\
# max   &  0.578764 &  0.422222 &  1.847690 &  0.014918 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:16:21.807847
# experiment number 1 took 3.7526330947875977 seconds. That means the whole run will probably take 11.257899284362793 more seconds and 0.18763165473937987 more minutes.
# overall, it took 9.097491025924683 seconds with 3 experiments
#          cobeau  coverage        nlpd      rsme
# count  3.000000  3.000000    3.000000  3.000000
# mean   0.307689  0.022222 -730.222435  0.736443
# std    0.510051  0.022222  154.610429  0.276900
# min    0.012770  0.000000 -866.551081  0.477844
# 25%    0.013211  0.011111 -814.217670  0.590371
# 50%    0.013652  0.022222 -761.884260  0.702897
# 75%    0.455149  0.033333 -662.058111  0.865743
# max    0.896645  0.044444 -562.231963  1.028589
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &        nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &    3.000000 &  3.000000 \\
# mean  &  0.307689 &  0.022222 & -730.222435 &  0.736443 \\
# std   &  0.510051 &  0.022222 &  154.610429 &  0.276900 \\
# min   &  0.012770 &  0.000000 & -866.551081 &  0.477844 \\
# 25\%   &  0.013211 &  0.011111 & -814.217670 &  0.590371 \\
# 50\%   &  0.013652 &  0.022222 & -761.884260 &  0.702897 \\
# 75\%   &  0.455149 &  0.033333 & -662.058111 &  0.865743 \\
# max   &  0.896645 &  0.044444 & -562.231963 &  1.028589 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:16:38.975620
# experiment number 1 took 5.091844081878662 seconds. That means the whole run will probably take 15.275532245635986 more seconds and 0.2545922040939331 more minutes.
# overall, it took 15.031538963317871 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   2.515002e-01  0.644444 -0.290795  3.163395
# std    3.306808e-01  0.138778  0.595987  4.952536
# min    2.367476e-22  0.533333 -0.965301  0.234690
# 25%    6.421603e-02  0.566667 -0.518545  0.304330
# 50%    1.284321e-01  0.600000 -0.071790  0.373970
# 75%    3.772503e-01  0.700000  0.046457  4.627748
# max    6.260686e-01  0.800000  0.164705  8.881526
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  2.515002e-01 &  0.644444 & -0.290795 &  3.163395 \\
# std   &  3.306808e-01 &  0.138778 &  0.595987 &  4.952536 \\
# min   &  2.367476e-22 &  0.533333 & -0.965301 &  0.234690 \\
# 25\%   &  6.421603e-02 &  0.566667 & -0.518545 &  0.304330 \\
# 50\%   &  1.284321e-01 &  0.600000 & -0.071790 &  0.373970 \\
# 75\%   &  3.772503e-01 &  0.700000 &  0.046457 &  4.627748 \\
# max   &  6.260686e-01 &  0.800000 &  0.164705 &  8.881526 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:17:02.536092
# experiment number 1 took 3.3712730407714844 seconds. That means the whole run will probably take 10.113819122314453 more seconds and 0.1685636520385742 more minutes.
# overall, it took 11.089745998382568 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.528999  0.377778 -2.771976  0.263711
# std    0.233999  0.096864  4.658489  0.089159
# min    0.280898  0.311111 -8.146065  0.177786
# 25%    0.420633  0.322222 -4.216604  0.217674
# 50%    0.560367  0.333333 -0.287142  0.257562
# 75%    0.653050  0.411111 -0.084931  0.306674
# max    0.745732  0.488889  0.117281  0.355786
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.528999 &  0.377778 & -2.771976 &  0.263711 \\
# std   &  0.233999 &  0.096864 &  4.658489 &  0.089159 \\
# min   &  0.280898 &  0.311111 & -8.146065 &  0.177786 \\
# 25\%   &  0.420633 &  0.322222 & -4.216604 &  0.217674 \\
# 50\%   &  0.560367 &  0.333333 & -0.287142 &  0.257562 \\
# 75\%   &  0.653050 &  0.411111 & -0.084931 &  0.306674 \\
# max   &  0.745732 &  0.488889 &  0.117281 &  0.355786 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-09 10:17:24.212483
# experiment number 1 took 2.470538854598999 seconds. That means the whole run will probably take 7.411616563796997 more seconds and 0.12352694272994995 more minutes.

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
