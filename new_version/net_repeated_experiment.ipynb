# %%
import importlib
import tensorflow as tf
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

#import ensembles
#importlib.reload(ensembles)

import networks
importlib.reload(networks)
from evaluation import repeat_experiment

import dataset_creation 
importlib.reload(dataset_creation)

import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline


from ensembles import BootstrapThroughTimeBobStrap,BootstrapEnsemble, ForcedDiversityBootstrapThroughTime3

from base import EnsembleNetwork
from networks import DropoutNetwork, NlpdNetwork, LrNetwork
# Out:
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/thomas/anaconda/envs/tfdeeplearning/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# # Linear

# %%
num_meta_epochs = 3# 100#100#10
num_epochs = 10#15#10#3#50#50#15#5#25#50
seed = 4200#50#430#45#42

num_samples = 200
dataset_params = {'seed':seed,'num_samples':num_samples}
num_neurons = [10,10,10]
num_neurons_nonlinear = [10,10,10,10,5]
learning_rate = None#1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,
               'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'num_neurons':num_neurons,
               'l2':True}#{'num_epochs':num_epochs,'seed':seed,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}

# %%
pd = repeat_experiment(DropoutNetwork, dataset_creation.LinearDataset,
                       num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:43:14.965340
# initialising Network
# experiment number 1 took 14.076810359954834 seconds. That means the whole run will probably take 42.2304310798645 more seconds and 0.7038405179977417 more minutes.
# initialising Network
# initialising Network
# overall, it took 45.593536138534546 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.400666  0.811111  0.913643  0.011734
# std    0.489978  0.067358  0.013875  0.003129
# min    0.002355  0.733333  0.897644  0.009571
# 25%    0.127098  0.791667  0.909274  0.009940
# 50%    0.251841  0.850000  0.920905  0.010310
# 75%    0.599821  0.850000  0.921642  0.012816
# max    0.947802  0.850000  0.922379  0.015322
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.400666 &  0.811111 &  0.913643 &  0.011734 \\
# std   &  0.489978 &  0.067358 &  0.013875 &  0.003129 \\
# min   &  0.002355 &  0.733333 &  0.897644 &  0.009571 \\
# 25\%   &  0.127098 &  0.791667 &  0.909274 &  0.009940 \\
# 50\%   &  0.251841 &  0.850000 &  0.920905 &  0.010310 \\
# 75\%   &  0.599821 &  0.850000 &  0.921642 &  0.012816 \\
# max   &  0.947802 &  0.850000 &  0.922379 &  0.015322 \\
# \bottomrule
# \end{tabular}

# %%
pd1 = repeat_experiment(NlpdNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:44:10.994989
# experiment number 1 took 17.73764181137085 seconds. That means the whole run will probably take 53.21292543411255 more seconds and 0.8868820905685425 more minutes.
# overall, it took 56.85497808456421 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.470967  0.105556  1.846767  0.007796
# std    0.270742  0.041944  0.124985  0.001035
# min    0.293446  0.066667  1.709975  0.007095
# 25%    0.315157  0.083333  1.792648  0.007202
# 50%    0.336868  0.100000  1.875322  0.007310
# 75%    0.559727  0.125000  1.915163  0.008147
# max    0.782586  0.150000  1.955004  0.008985
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.470967 &  0.105556 &  1.846767 &  0.007796 \\
# std   &  0.270742 &  0.041944 &  0.124985 &  0.001035 \\
# min   &  0.293446 &  0.066667 &  1.709975 &  0.007095 \\
# 25\%   &  0.315157 &  0.083333 &  1.792648 &  0.007202 \\
# 50\%   &  0.336868 &  0.100000 &  1.875322 &  0.007310 \\
# 75\%   &  0.559727 &  0.125000 &  1.915163 &  0.008147 \\
# max   &  0.782586 &  0.150000 &  1.955004 &  0.008985 \\
# \bottomrule
# \end{tabular}

# %%
pd2 = repeat_experiment(LrNetwork, dataset_creation.LinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:45:24.243146
# experiment number 1 took 17.46291494369507 seconds. That means the whole run will probably take 52.388744831085205 more seconds and 0.8731457471847535 more minutes.
# overall, it took 54.344632148742676 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.429327  0.061111  1.796435  0.007953
# std    0.106577  0.009623  0.104071  0.001599
# min    0.312299  0.050000  1.688702  0.006677
# 25%    0.383587  0.058333  1.746447  0.007057
# 50%    0.454875  0.066667  1.804192  0.007437
# 75%    0.487842  0.066667  1.850301  0.008591
# max    0.520809  0.066667  1.896411  0.009746
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.429327 &  0.061111 &  1.796435 &  0.007953 \\
# std   &  0.106577 &  0.009623 &  0.104071 &  0.001599 \\
# min   &  0.312299 &  0.050000 &  1.688702 &  0.006677 \\
# 25\%   &  0.383587 &  0.058333 &  1.746447 &  0.007057 \\
# 50\%   &  0.454875 &  0.066667 &  1.804192 &  0.007437 \\
# 75\%   &  0.487842 &  0.066667 &  1.850301 &  0.008591 \\
# max   &  0.520809 &  0.066667 &  1.896411 &  0.009746 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Nonlinear

# %%
#num_meta_epochs = 5#10
#num_epochs = 10#15#50 #10
seed = 42+42

model_params = {'num_epochs':num_epochs,'seed':seed,'num_neurons':[4, 5,5, 4, 2]}#[5,5,5]}#

dataset_params = {'num_samples':num_samples,'seed':seed}

learning_rate = 1/num_epochs
model_params = {'initialisation_scheme':tf.keras.initializers.he_normal,'num_epochs':num_epochs,'seed':seed,
               'l2':True}#{'num_epochs':num_epochs,'learning_rate':learning_rate,'initialisation_scheme':tf.keras.initializers.he_normal}
importlib.reload(dataset_creation)
# Out:
# <module 'dataset_creation' from '/Users/thomas/Documents/Master-Thesis/new_version/dataset_creation.py'>

# %%
pd11 = repeat_experiment(DropoutNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:46:31.590535
# initialising Network
# experiment number 1 took 16.57644271850586 seconds. That means the whole run will probably take 49.72932815551758 more seconds and 0.828822135925293 more minutes.
# initialising Network
# initialising Network
# overall, it took 47.83000087738037 seconds with 3 experiments
#          cobeau  coverage      nlpd      rsme
# count  3.000000  3.000000  3.000000  3.000000
# mean   0.457035  0.333333  0.528221  0.122836
# std    0.444577  0.044096  0.044419  0.010418
# min    0.025944  0.283333  0.482657  0.113527
# 25%    0.228567  0.316667  0.506633  0.117209
# 50%    0.431190  0.350000  0.530608  0.120892
# 75%    0.672581  0.358333  0.551003  0.127491
# max    0.913972  0.366667  0.571398  0.134089
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  0.457035 &  0.333333 &  0.528221 &  0.122836 \\
# std   &  0.444577 &  0.044096 &  0.044419 &  0.010418 \\
# min   &  0.025944 &  0.283333 &  0.482657 &  0.113527 \\
# 25\%   &  0.228567 &  0.316667 &  0.506633 &  0.117209 \\
# 50\%   &  0.431190 &  0.350000 &  0.530608 &  0.120892 \\
# 75\%   &  0.672581 &  0.358333 &  0.551003 &  0.127491 \\
# max   &  0.913972 &  0.366667 &  0.571398 &  0.134089 \\
# \bottomrule
# \end{tabular}

# %%
pd22 = repeat_experiment(NlpdNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:47:34.711868
# experiment number 1 took 22.733179092407227 seconds. That means the whole run will probably take 68.19953727722168 more seconds and 1.1366589546203614 more minutes.
# overall, it took 65.97720193862915 seconds with 3 experiments
#              cobeau  coverage      nlpd      rsme
# count  3.000000e+00  3.000000  3.000000  3.000000
# mean   1.644172e-04  0.272222  0.520103  0.553166
# std    2.847789e-04  0.096225  0.587308  0.841335
# min    6.309977e-43  0.216667 -0.152396  0.062453
# 25%    2.257286e-18  0.216667  0.314098  0.067429
# 50%    4.514572e-18  0.216667  0.780593  0.072405
# 75%    2.466258e-04  0.300000  0.856353  0.798522
# max    4.932516e-04  0.383333  0.932113  1.524639
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &      nlpd &      rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &  3.000000 &  3.000000 \\
# mean  &  1.644172e-04 &  0.272222 &  0.520103 &  0.553166 \\
# std   &  2.847789e-04 &  0.096225 &  0.587308 &  0.841335 \\
# min   &  6.309977e-43 &  0.216667 & -0.152396 &  0.062453 \\
# 25\%   &  2.257286e-18 &  0.216667 &  0.314098 &  0.067429 \\
# 50\%   &  4.514572e-18 &  0.216667 &  0.780593 &  0.072405 \\
# 75\%   &  2.466258e-04 &  0.300000 &  0.856353 &  0.798522 \\
# max   &  4.932516e-04 &  0.383333 &  0.932113 &  1.524639 \\
# \bottomrule
# \end{tabular}

# %%
pd33 = repeat_experiment(LrNetwork, dataset_creation.NonlinearDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:48:57.046966
# experiment number 1 took 18.82643723487854 seconds. That means the whole run will probably take 56.47931170463562 more seconds and 0.941321861743927 more minutes.
# overall, it took 54.97551989555359 seconds with 3 experiments
#          cobeau  coverage       nlpd      rsme
# count  3.000000  3.000000   3.000000  3.000000
# mean   0.366991  0.355556 -18.602327  0.131940
# std    0.271127  0.050918  30.652671  0.077486
# min    0.140865  0.300000 -53.940049  0.060795
# 25%    0.216704  0.333333 -28.305703  0.090660
# 50%    0.292543  0.366667  -2.671356  0.120524
# 75%    0.480053  0.383333  -0.933466  0.167512
# max    0.667564  0.400000   0.804424  0.214500
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &       nlpd &      rsme \\
# \midrule
# count &  3.000000 &  3.000000 &   3.000000 &  3.000000 \\
# mean  &  0.366991 &  0.355556 & -18.602327 &  0.131940 \\
# std   &  0.271127 &  0.050918 &  30.652671 &  0.077486 \\
# min   &  0.140865 &  0.300000 & -53.940049 &  0.060795 \\
# 25\%   &  0.216704 &  0.333333 & -28.305703 &  0.090660 \\
# 50\%   &  0.292543 &  0.366667 &  -2.671356 &  0.120524 \\
# 75\%   &  0.480053 &  0.383333 &  -0.933466 &  0.167512 \\
# max   &  0.667564 &  0.400000 &   0.804424 &  0.214500 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # X3

# %%
importlib.reload(dataset_creation)

dataset_params = {'seed':seed,'num_samples':num_samples,'scope':7}

# %%
pd111 = repeat_experiment(DropoutNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,
                          model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:50:04.587912
# initialising Network
# experiment number 1 took 12.7569100856781 seconds. That means the whole run will probably take 38.2707302570343 more seconds and 0.6378455042839051 more minutes.
# initialising Network
# initialising Network
# overall, it took 43.249464988708496 seconds with 3 experiments
#              cobeau  coverage        nlpd        rsme
# count  3.000000e+00  3.000000    3.000000    3.000000
# mean   2.360667e-07  0.768362  -68.492128  296.303388
# std    4.045915e-07  0.068499   57.779870   17.670625
# min    6.006162e-10  0.728814 -117.056937  280.836656
# 25%    2.478250e-09  0.728814 -100.442469  286.673978
# 50%    4.355884e-09  0.728814  -83.828002  292.511299
# 75%    3.537998e-07  0.788136  -44.209724  304.036755
# max    7.032437e-07  0.847458   -4.591446  315.562210
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &        nlpd &        rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &    3.000000 &    3.000000 \\
# mean  &  2.360667e-07 &  0.768362 &  -68.492128 &  296.303388 \\
# std   &  4.045915e-07 &  0.068499 &   57.779870 &   17.670625 \\
# min   &  6.006162e-10 &  0.728814 & -117.056937 &  280.836656 \\
# 25\%   &  2.478250e-09 &  0.728814 & -100.442469 &  286.673978 \\
# 50\%   &  4.355884e-09 &  0.728814 &  -83.828002 &  292.511299 \\
# 75\%   &  3.537998e-07 &  0.788136 &  -44.209724 &  304.036755 \\
# max   &  7.032437e-07 &  0.847458 &   -4.591446 &  315.562210 \\
# \bottomrule
# \end{tabular}

# %%
pd222 = repeat_experiment(NlpdNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:51:04.467085
# experiment number 1 took 20.78298282623291 seconds. That means the whole run will probably take 62.34894847869873 more seconds and 1.0391491413116456 more minutes.
# overall, it took 63.06783628463745 seconds with 3 experiments
#              cobeau  coverage           nlpd         rsme
# count  3.000000e+00  3.000000       3.000000     3.000000
# mean   4.093286e-04  0.446328 -250550.421332  1241.179214
# std    7.089780e-04  0.373779  433917.615280   728.388042
# min    2.133407e-17  0.033898 -751595.325236   654.875479
# 25%    3.754491e-12  0.288136 -375815.339724   833.483056
# 50%    7.508960e-12  0.542373     -35.354211  1012.090633
# 75%    6.139929e-04  0.652542     -27.969380  1534.331082
# max    1.227986e-03  0.762712     -20.584550  2056.571532
# \begin{tabular}{lrrrr}
# \toprule
# {} &        cobeau &  coverage &           nlpd &         rsme \\
# \midrule
# count &  3.000000e+00 &  3.000000 &       3.000000 &     3.000000 \\
# mean  &  4.093286e-04 &  0.446328 & -250550.421332 &  1241.179214 \\
# std   &  7.089780e-04 &  0.373779 &  433917.615280 &   728.388042 \\
# min   &  2.133407e-17 &  0.033898 & -751595.325236 &   654.875479 \\
# 25\%   &  3.754491e-12 &  0.288136 & -375815.339724 &   833.483056 \\
# 50\%   &  7.508960e-12 &  0.542373 &     -35.354211 &  1012.090633 \\
# 75\%   &  6.139929e-04 &  0.652542 &     -27.969380 &  1534.331082 \\
# max   &  1.227986e-03 &  0.762712 &     -20.584550 &  2056.571532 \\
# \bottomrule
# \end{tabular}

# %%
pd333 = repeat_experiment(LrNetwork, dataset_creation.XThreeDataset,num_meta_epochs=num_meta_epochs,model_params=model_params,dataset_params=dataset_params)
# Out:
# experiment started at 2018-08-12 09:52:23.924925
# experiment number 1 took 17.42615580558777 seconds. That means the whole run will probably take 52.278467416763306 more seconds and 0.8713077902793884 more minutes.
# overall, it took 54.618257999420166 seconds with 3 experiments
#          cobeau  coverage      nlpd        rsme
# count  3.000000       3.0  3.000000    3.000000
# mean   0.004993       1.0 -3.287121  231.969687
# std    0.008621       0.0  0.725866  144.033407
# min    0.000003       1.0 -4.098789   87.582927
# 25%    0.000015       1.0 -3.580560  160.130970
# 50%    0.000028       1.0 -3.062331  232.679013
# 75%    0.007488       1.0 -2.881287  304.163067
# max    0.014948       1.0 -2.700243  375.647121
# \begin{tabular}{lrrrr}
# \toprule
# {} &    cobeau &  coverage &      nlpd &        rsme \\
# \midrule
# count &  3.000000 &       3.0 &  3.000000 &    3.000000 \\
# mean  &  0.004993 &       1.0 & -3.287121 &  231.969687 \\
# std   &  0.008621 &       0.0 &  0.725866 &  144.033407 \\
# min   &  0.000003 &       1.0 & -4.098789 &   87.582927 \\
# 25\%   &  0.000015 &       1.0 & -3.580560 &  160.130970 \\
# 50\%   &  0.000028 &       1.0 & -3.062331 &  232.679013 \\
# 75\%   &  0.007488 &       1.0 & -2.881287 &  304.163067 \\
# max   &  0.014948 &       1.0 & -2.700243 &  375.647121 \\
# \bottomrule
# \end{tabular}
